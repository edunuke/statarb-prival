# %%
# ==============================================================================
# S&P 500 STAT-ARB PIPELINE: ROBUST 2-STAGE PURE PARAMETRIC ARCHITECTURE
# ==============================================================================
import os
import gc
import pickle
import warnings
from typing import Dict, List, Tuple, Optional
from collections import deque
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint
from scipy.stats import chi2
from scipy.optimize import minimize as scipy_minimize
import vectorbt as vbt
from joblib import Parallel, delayed

warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 250)
from datetime import datetime

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
model_id = "model_A_parametric"

# ==============================================================================
# 1. INSTITUTIONAL PARAMETER CONFIGURATION
# ==============================================================================
run_params = {
    "price_csv": "data/universe_daily_train.csv",
    "oos_price_csv": "data/universe_daily_val.csv",
    "constituents_path": "data/constituents.csv",
    "state_persistence_file": f"artifacts/{model_id}/stat_arb_state_{timestamp}.pkl",

    "lookback_days": 504,             
    "min_history_days": 100,          
    "weight_drift_threshold": 0.05,     
    "screening_freq_days": 20,          
    "quarantine_days": 42,             
    
    "kalman_delta": 1e-4,              
    "kalman_obs_noise": 1e-3,          
    "kalman_z_window": 42,             
    "max_hurst_exponent": 0.45,        
    
    "min_correlation": 0.40,           
    "p_value_threshold": 0.20,         
    
    "min_half_life": 2.0,             
    "max_half_life": 45.0,            
    "tau_hl_penalty": 5.0,             
    
    "exit_z_spread": 0.50,             # Widened from 0.10 to reduce churn rate & fees
    "stop_loss_z": 3.00,               
    "bocpd_cp_threshold": 0.35,        
    
    # PARAMETRIC TRUNCATION PARAMS
    "promote_top_n": 30,               
    "ghost_truncation_quantile": 0.50, # Drops bottom 50% of pairs by expected Alpha
    
    # SLSQP RISK BOUNDS
    "max_net_dollar_exposure": 0.05,   
    "max_sector_exposure": 0.10,       
    "max_gross_exposure": 1.80,        
    "max_sleeve_weight": 0.25,        

    "max_adv_participation": 0.015,    
    "initial_capital": 250_000.0,
    "exec_fee": 0.00015,              
    "borrow_bps": 50.0
}

# ==============================================================================
# 2. STATE PERSISTENCE ENGINE
# ==============================================================================
class StatePersistenceEngine:
    @staticmethod
    def save_checkpoint(filepath: str, state_dict: dict):
        try:
            os.makedirs(os.path.dirname(filepath), exist_ok=True)
            with open(filepath, "wb") as f:
                pickle.dump(state_dict, f)
        except Exception:
            pass

    @staticmethod
    def load_checkpoint(filepath: str) -> Optional[dict]:
        if not os.path.exists(filepath): return None
        try:
            with open(filepath, "rb") as f:
                return pickle.load(f)
        except Exception:
            return None

# ==============================================================================
# 3. MATH & KALMAN UTILITIES
# ==============================================================================
def calculate_half_life_fast(spread: np.ndarray) -> float:
    if len(spread) < 30: return 25.0
    s_lag, s_diff = spread[:-1], spread[1:] - spread[:-1]
    var_x = np.sum((s_lag - np.mean(s_lag))**2)
    if var_x < 1e-12: return 25.0
    gamma = np.sum((s_lag - np.mean(s_lag)) * (s_diff - np.mean(s_diff))) / var_x
    if gamma <= -1.0: return 1.0
    if gamma >= 0.0: return np.inf
    return float(-0.6931471805599453 / np.log(1.0 + gamma))

def compute_hurst_exponent_fast(time_series: np.ndarray, max_lag: int = 20) -> float:
    N = len(time_series)
    if N < max_lag * 2: return 0.50
    lags = np.arange(2, max_lag)
    tau = [np.std(time_series[lag:] - time_series[:-lag]) for lag in lags]
    slope = np.polyfit(np.log(lags), np.log(np.maximum(tau, 1e-8)), 1)[0]
    return float(slope * 2.0)

def compute_sortino_ratio(returns: pd.Series, target_return: float = 0.0) -> float:
    if len(returns) < 5 or returns.std() < 1e-8: return 0.0
    downside_std = np.sqrt(np.mean(returns[returns < target_return]**2)) * np.sqrt(252.0)
    return float((returns.mean() * 252.0) / max(downside_std, 1e-6))

class FastKalmanFilter:
    def __init__(self, delta: float = 1e-4, obs_noise: float = 1e-3, z_window: int = 21):
        self.delta, self.obs_noise, self.z_window = delta, obs_noise, z_window
        self.Q = (delta / (1.0 - delta)) * np.eye(2, dtype=np.float64)

    def filter_series(self, y: np.ndarray, x: np.ndarray) -> Dict[str, np.ndarray]:
        N = len(y)
        state_mean, state_cov = np.zeros(2, dtype=np.float64), np.eye(2, dtype=np.float64)
        betas, alphas, v_arr = np.empty(N), np.empty(N), np.empty(N)
        H = np.ones((2, 1), dtype=np.float64)
        for t in range(N):
            H[1, 0] = x[t]
            pred_cov = state_cov + self.Q
            v = y[t] - (H.T @ state_mean).item()
            F = (H.T @ pred_cov @ H).item() + self.obs_noise
            K = (pred_cov @ H) / F
            state_mean += (K.flatten() * v)
            state_cov = (np.eye(2) - K @ H.T) @ pred_cov
            alphas[t], betas[t], v_arr[t] = state_mean[0], state_mean[1], v

        F_emp = pd.Series(v_arr).rolling(self.z_window, min_periods=5).std().bfill().values**2
        e_t = v_arr / np.sqrt(np.maximum(F_emp, 1e-4))
        return {"Beta": betas, "Innovation": v_arr, "Innovation_Var": F_emp, "Innovation_Z": e_t, "Final_State_Mean": state_mean, "Final_State_Cov": state_cov}

    def step_update(self, state_mean: np.ndarray, state_cov: np.ndarray, y_val: float, x_val: float):
        H = np.array([1.0, x_val], dtype=np.float64)
        pred_cov = state_cov + self.Q
        v_t = y_val - float(H @ state_mean)
        F_t = float(H @ pred_cov @ H.T) + self.obs_noise
        K = (pred_cov @ H) / F_t
        return state_mean + K * v_t, (np.eye(2) - np.outer(K, H)) @ pred_cov, v_t, F_t

class FastBOCPDEngine:
    def __init__(self, hazard_rate: float = 1.0 / 200.0, max_K: int = 64):
        self.H, self.max_K = hazard_rate, max_K

    def eval_change_point_prob(self, innovations: np.ndarray) -> float:
        T_len = min(len(innovations), self.max_K)
        if T_len < 5: return 0.0
        recent_std, hist_std = np.std(innovations[-5:]), np.std(innovations)
        return float(min(1.0, (recent_std / (hist_std + 1e-5)) - 1.0)) if recent_std > hist_std else 0.0

class UniverseScreener:
    def __init__(self, constituents_path: str):
        self.constituents_path = constituents_path

    def get_sectors(self, tickers: List[str]) -> pd.Series:
        if os.path.exists(self.constituents_path):
            const = pd.read_csv(self.constituents_path)
            sym_col = "Symbol" if "Symbol" in const.columns else "Ticker"
            return pd.Series(tickers, index=tickers).map(dict(zip(const[sym_col], const["GICS Sector"]))).fillna("Unknown")
        return pd.Series("Unknown", index=tickers)

# ==============================================================================
# 4. FAST PAIR COINTEGRATION & PARAMETRIC ALPHA ENGINE
# ==============================================================================
class PairCointegrationEngine:
    def __init__(self, params: dict):
        self.params = params
        self.kalman_engine = FastKalmanFilter(delta=params.get("kalman_delta", 1e-4), z_window=params.get("kalman_z_window", 21))
        self.bocpd_engine = FastBOCPDEngine()

    def _screen_single_pair_fast(self, t1: str, t2: str, p1: np.ndarray, p2: np.ndarray) -> Optional[Tuple[str, str]]:
        mask = ~np.isnan(p1) & ~np.isnan(p2)
        if np.sum(mask) < self.params["min_history_days"]: return None
        if coint(p1[mask], p2[mask])[1] <= self.params["p_value_threshold"]: return (t1, t2)
        return None

    def screen_universe_cointegration(self, price_df: pd.DataFrame, sectors: pd.Series, parallel) -> List[Tuple[str, str]]:
        valid_df = price_df.ffill().dropna(axis=1)
        valid_tickers = list(valid_df.columns)
        if len(valid_tickers) < 2:
            return []
        log_prices = np.log(valid_df.values)
        corr_matrix = np.corrcoef(np.diff(log_prices, axis=0), rowvar=False)
        sector_arr = sectors.reindex(valid_tickers).values
        sec_match = sector_arr[:, None] == sector_arr[None, :]
        mask = np.triu(sec_match & (corr_matrix >= self.params["min_correlation"]), k=1)
        candidates = [(valid_tickers[i], valid_tickers[j], log_prices[:, i], log_prices[:, j]) for i, j in zip(*np.where(mask))]
        results = parallel(delayed(self._screen_single_pair_fast)(*c) for c in candidates)
        return [r for r in results if r is not None]

    def _test_pair(self, t1: str, t2: str, price_df: pd.DataFrame, active_data: dict = None):
        s1, s2 = price_df[t1].dropna(), price_df[t2].dropna()
        idx = s1.index.intersection(s2.index)
        if len(idx) < self.params["min_history_days"]: return None

        is_active = active_data is not None
        kf_out = self.kalman_engine.filter_series(np.log(s1.loc[idx].values), np.log(s2.loc[idx].values))
        beta, e_t, F_t = kf_out["Beta"][-1], kf_out["Innovation_Z"][-1], kf_out["Innovation_Var"][-1]
        
        static_spread = np.log(s1.loc[idx].values) - (beta * np.log(s2.loc[idx].values))
        
        hurst_val = compute_hurst_exponent_fast(static_spread[-126:])
        if not is_active and hurst_val >= self.params["max_hurst_exponent"]: return None

        recent_v = kf_out["Innovation"][-self.kalman_engine.z_window:]
        S_t = np.sum((recent_v**2) / kf_out["Innovation_Var"][-self.kalman_engine.z_window:])
        is_break = (S_t > chi2.ppf(0.99, df=self.kalman_engine.z_window)) or (self.bocpd_engine.eval_change_point_prob(recent_v) > self.params["bocpd_cp_threshold"])

        hl = float(np.clip(calculate_half_life_fast(static_spread), self.params["min_half_life"], self.params["max_half_life"]))
        if not is_active and (is_break or hl == self.params["max_half_life"]): return None

        # Fully Parametric Alpha Score (Expected Yield Calculation)
        exp_yield = max(0.0, abs(e_t) - self.params["exit_z_spread"]) * np.sqrt(max(F_t, 1e-6))
        parametric_alpha = exp_yield * (252.0 / hl) * (1.0 - np.exp(-hl / self.params["tau_hl_penalty"]))

        return {
            "Asset_A": t1, "Asset_B": t2, "Beta": beta, "Half_Life_Days": hl, "Z_Spread": e_t,
            "Parametric_Alpha": parametric_alpha, "Spread_Vol": np.sqrt(max(F_t, 1e-6)), 
            "Days_Held": active_data.get("Days_Held", 0) + 1 if is_active else 0,
            "Is_Active": is_active, "Entry_Z": active_data["Entry_Z"] if is_active else e_t,
            "Ghost_Returns": pd.Series(static_spread).diff().fillna(0).values[-63:],
            "State_Mean": kf_out["Final_State_Mean"], "State_Cov": kf_out["Final_State_Cov"],
            "Recent_V_Buffer": deque(recent_v, maxlen=42), "CUSUM_S_t": S_t
        }

    def find_pairs(self, price_df: pd.DataFrame, sectors: pd.Series, active_pairs: dict, cached_keys: List[Tuple[str, str]], parallel):
        tests = [(k[0], k[1], act) for k, act in active_pairs.items()]
        seen = set(active_pairs.keys())
        tests += [(t1, t2, None) for t1, t2 in cached_keys if (t1, t2) not in seen and (t2, t1) not in seen]
        results = parallel(delayed(self._test_pair)(t1, t2, price_df, act) for t1, t2, act in tests)
        return pd.DataFrame([r for r in results if r is not None])

# ==============================================================================
# 5. PARAMETRIC-BOUNDED SLSQP OPTIMIZER (STRICT NEUTRALITY)
# ==============================================================================
class ConvexPortfolioOptimizer:
    def __init__(self, params: dict):
        self.params = params

    @staticmethod
    def calculate_max_weight_drift(current_sleeve_weights: Dict[Tuple[str, str], float], target_sleeve_weights: Dict[Tuple[str, str], float]) -> float:
        all_keys = set(current_sleeve_weights.keys()).union(target_sleeve_weights.keys())
        if not all_keys: return 0.0
        return float(max([abs(current_sleeve_weights.get(pk, 0.0) - target_sleeve_weights.get(pk, 0.0)) for pk in all_keys]))

    def allocate(self, live_df: pd.DataFrame, sectors: pd.Series, current_weights: dict):
        if live_df.empty: return {}, {}, {}

        N = len(live_df)
        pair_keys = [(r["Asset_A"], r["Asset_B"]) for _, r in live_df.iterrows()]
        
        returns_mat = np.column_stack([live_df.iloc[i]["Ghost_Returns"] for i in range(N)])
        cov_matrix = np.cov(returns_mat, rowvar=False) * 252.0 + np.eye(N) * 1e-5
        
        pair_betas, pair_zs = live_df["Beta"].values, live_df["Z_Spread"].values
        spread_vols = live_df["Spread_Vol"].values
        alphas = live_df["Parametric_Alpha"].values

        w_prev = np.array([current_weights.get(pk, 0.0) for pk in pair_keys])
        turnover_bps = (self.params["exec_fee"] * 2.0) + 0.0005 

        dollar_mults = np.where(pair_zs > 0, pair_betas - 1.0, 1.0 - pair_betas)
        pair_secs = np.array([sectors.get(live_df.iloc[i]["Asset_A"], "Unknown") for i in range(N)])
        unique_secs = np.unique(pair_secs)

        # Pure Risk + Turnover Minimization
        def objective(w):
            risk = np.dot(w.T, np.dot(cov_matrix, w))
            turnover = np.sum(np.abs(w - w_prev)) * turnover_bps
            return risk + turnover

        target_gross = min(self.params["max_gross_exposure"], N * self.params["max_sleeve_weight"])
        min_gross = min(1.0, target_gross * 0.5) 
        max_net = self.params["max_net_dollar_exposure"]
        max_sec = self.params["max_sector_exposure"]
        
        # Relaxed Gross target to Inequality to ensure Neutrality bounds mathematically solve
        constraints = [
            {'type': 'ineq', 'fun': lambda w: target_gross - np.sum(w)}, 
            {'type': 'ineq', 'fun': lambda w: np.sum(w) - min_gross},    
            {'type': 'ineq', 'fun': lambda w: max_net - np.abs(np.sum(w * dollar_mults))}
        ]
        for s in unique_secs:
            constraints.append({'type': 'ineq', 'fun': lambda w, sec=s: max_sec - np.abs(np.sum(w[pair_secs == sec] * dollar_mults[pair_secs == sec]))})

        base_cap = self.params["max_sleeve_weight"]
        alpha_median = max(float(np.median(alphas)), 1e-6)
        
        # Dynamic Upper Bounds scaled purely by Parametric Alpha
        bounds = [(0.0, base_cap * np.clip(float(alphas[i]) / alpha_median, 0.20, 1.00)) for i in range(N)]
        
        init_w = (1.0 / np.maximum(spread_vols, 1e-4))
        init_w = np.minimum((init_w / np.sum(init_w)) * target_gross, [b[1] for b in bounds])

        res = scipy_minimize(objective, init_w, method='SLSQP', bounds=bounds, constraints=constraints)
        best_w = res.x if res.success else init_w
        best_w[best_w < 0.01] = 0.0

        allocs, memory = {}, {}
        for i, pk in enumerate(pair_keys):
            if best_w[i] > 0:
                row = live_df.iloc[i]
                w_a = -best_w[i] if row["Z_Spread"] > 0 else best_w[i]
                w_b = best_w[i] * row["Beta"] if row["Z_Spread"] > 0 else -best_w[i] * row["Beta"]
                allocs[pk] = {row["Asset_A"]: w_a, row["Asset_B"]: w_b, "Sleeve_Weight": best_w[i]}
                memory[pk] = {
                    "Beta": row["Beta"], "Entry_Z": row["Entry_Z"] if row["Is_Active"] else row["Z_Spread"],
                    "CUSUM_S_t": row.get("CUSUM_S_t", 0.0),
                    "Parametric_Alpha": row["Parametric_Alpha"], 
                    "Half_Life_Days": row["Half_Life_Days"], "Days_Held": row.get("Days_Held", 0),
                    "State_Mean": row["State_Mean"], "State_Cov": row["State_Cov"], "Recent_V_Buffer": row["Recent_V_Buffer"]
                }

        metrics = {"Portfolio_Variance": np.dot(best_w.T, np.dot(cov_matrix, best_w)), "Turnover_Cost": np.sum(np.abs(best_w - w_prev)) * turnover_bps, "Effective_Gross": np.sum(best_w)}
        return allocs, memory, metrics

# ==============================================================================
# 6. BACKTEST ENGINES & DIAGNOSTICS
# ==============================================================================
class CommitteeTearsheetEngine:
    def __init__(self, params: dict):
        self.initial_capital = params.get("initial_capital", 250_000.0)
        self.exec_fee = params.get("exec_fee", 0.00015)
        self.daily_borrow_rate = (params.get("borrow_bps", 50.0) / 10000.0) / 252.0

    def generate_tearsheets(self, prices_df: pd.DataFrame, pair_weight_matrices: Dict[Tuple[str, str], pd.DataFrame]) -> pd.DataFrame:
        results = []
        for pair_key, w_df in pair_weight_matrices.items():
            a, b = pair_key
            active_dates = w_df.dropna(how='all').index
            if len(active_dates) == 0: continue
            start_date = active_dates[0]
            p_oos = prices_df[[a, b]].loc[start_date:]
            w_target = w_df.loc[start_date:].copy()
            w_target.iloc[-1] = 0.0 
            
            pf_gross = vbt.Portfolio.from_orders(
                close=p_oos, size=w_target, size_type='targetpercent',
                group_by=True, cash_sharing=True, init_cash=self.initial_capital, fees=self.exec_fee
            )
            asset_values = pf_gross.asset_value(group_by=False)
            short_exposure = asset_values.where(asset_values < 0, 0).abs()
            daily_short_cost = short_exposure.sum(axis=1) * self.daily_borrow_rate
            net_val = pf_gross.value() - daily_short_cost.cumsum()
            net_ret = net_val.pct_change().fillna(0)
            
            tot_ret = (net_val.iloc[-1] / self.initial_capital) - 1.0
            mean_ret, std_ret = net_ret.mean(), net_ret.std()
            down_std = np.sqrt((net_ret[net_ret < 0] ** 2).mean())
            sharpe = (mean_ret / std_ret) * np.sqrt(252) if std_ret > 0 else 0.0
            sortino = (mean_ret / down_std) * np.sqrt(252) if down_std > 0 else 0.0
            max_dd = (1 - net_val / net_val.cummax()).max() if not net_val.empty else 0.0
            trades = pf_gross.trades.count()
            win_rate = (pf_gross.trades.winning.count() / trades) if trades > 0 else 0.0
            
            results.append({
                "Pair_Legs": f"{a} / {b}", "Total_Return_[%]": tot_ret * 100,
                "Sharpe_Ratio": sharpe, "Sortino_Ratio": sortino,
                "Max_DD_[%]": max_dd * 100, "Win_Rate_[%]": win_rate * 100, "Total_Trades": trades
            })
            del pf_gross
            gc.collect()

        if not results: return pd.DataFrame()
        return pd.DataFrame(results).sort_values("Sharpe_Ratio", ascending=False).reset_index(drop=True)

class VectorbtBacktestEngine:
    def __init__(self, params: dict):
        self.initial_capital = params.get("initial_capital", 250_000.0)
        self.exec_fee = params.get("exec_fee", 0.00015)
        self.daily_borrow_rate = (params.get("borrow_bps", 50.0) / 10000.0) / 252.0

    def run_backtest(self, close_prices_df: pd.DataFrame, open_prices_df: pd.DataFrame, weights_df: pd.DataFrame) -> Tuple[vbt.Portfolio, pd.Series, pd.Series]:
        tradable_assets = weights_df.columns.intersection(close_prices_df.columns)
        p_close_oos, p_open_oos = close_prices_df[tradable_assets].ffill(), open_prices_df[tradable_assets].ffill()
        sparse_weights = weights_df[tradable_assets]

        pf_gross = vbt.Portfolio.from_orders(
            close=p_close_oos, price=p_open_oos, size=sparse_weights, size_type='targetpercent',
            group_by=True, cash_sharing=True, init_cash=self.initial_capital, fees=self.exec_fee
        )
        
        asset_values = pf_gross.asset_value(group_by=False)
        short_exposure = asset_values.where(asset_values < 0, 0).abs()
        daily_short_cost = short_exposure.sum(axis=1) * self.daily_borrow_rate
        net_portfolio_value = pf_gross.value() - daily_short_cost.cumsum()
        
        total_abs_asset_val = asset_values.abs().sum(axis=1)
        true_gross_exposure = (total_abs_asset_val / net_portfolio_value.replace(0.0, np.nan)).fillna(0.0)
        return pf_gross, net_portfolio_value, true_gross_exposure

class MarketNeutralityDiagnosticEngine:
    def __init__(self, max_beta: float = 0.03, max_r2: float = 0.01):
        self.max_beta, self.max_r2 = max_beta, max_r2

    def analyze(self, strategy_returns: pd.Series, benchmark_returns: pd.Series) -> Tuple[pd.DataFrame, dict]:
        aligned_df = pd.concat([strategy_returns, benchmark_returns], axis=1).dropna()
        aligned_df.columns = ["Strategy", "Benchmark"]
        r_p, r_m = aligned_df["Strategy"], aligned_df["Benchmark"]
        
        capm_model = sm.OLS(r_p, sm.add_constant(r_m)).fit()
        alpha_ann = capm_model.params.get("const", 0.0) * 252.0
        beta_m = capm_model.params.get("Benchmark", 0.0)
        p_val_beta = capm_model.pvalues.get("Benchmark", 1.0)
        t_stat_beta = capm_model.tvalues.get("Benchmark", 0.0)
        r2_capm = capm_model.rsquared

        bull_mask, bear_mask = r_m > 0, r_m < 0
        beta_bull = sm.OLS(r_p[bull_mask], sm.add_constant(r_m[bull_mask])).fit().params.get("Benchmark", 0.0) if bull_mask.sum() > 10 else 0.0
        beta_bear = sm.OLS(r_p[bear_mask], sm.add_constant(r_m[bear_mask])).fit().params.get("Benchmark", 0.0) if bear_mask.sum() > 10 else 0.0

        metrics = [
            {"Metric": "Annualized Alpha", "Value": f"{alpha_ann:.2%}", "Threshold": "N/A", "Status": "INFO"},
            {"Metric": "Market Beta (β_m)", "Value": f"{beta_m:.4f}", "Threshold": f"< |{self.max_beta}|", "Status": "PASS" if abs(beta_m) <= self.max_beta else "FAIL"},
            {"Metric": "Beta p-value", "Value": f"{p_val_beta:.4f}", "Threshold": ">= 0.05", "Status": "PASS" if p_val_beta >= 0.05 else "FAIL"},
            {"Metric": "Beta t-statistic", "Value": f"{t_stat_beta:.4f}", "Threshold": "< |1.96|", "Status": "PASS" if abs(t_stat_beta) < 1.96 else "FAIL"},
            {"Metric": "Variance Explained (R²)", "Value": f"{r2_capm:.2%}", "Threshold": f"< {self.max_r2:.1%}", "Status": "PASS" if r2_capm <= self.max_r2 else "FAIL"},
            {"Metric": "Bull Market Beta (R_m > 0)", "Value": f"{beta_bull:.4f}", "Threshold": f"< |{self.max_beta}|", "Status": "PASS" if abs(beta_bull) <= self.max_beta else "FAIL"},
            {"Metric": "Bear Market Beta (R_m < 0)", "Value": f"{beta_bear:.4f}", "Threshold": f"< |{self.max_beta}|", "Status": "PASS" if abs(beta_bear) <= self.max_beta else "FAIL"}
        ]
        metrics_df = pd.DataFrame(metrics)
        all_passed = (metrics_df["Status"] != "FAIL").all()
        verdict = {"Market_Neutral": "TRUE" if all_passed else "FALSE", "Core_Failure_Reason": "None" if all_passed else ", ".join(metrics_df[metrics_df["Status"] == "FAIL"]["Metric"].tolist())}
        return metrics_df, verdict

class LiveMOOOrderGenerator:
    def __init__(self, min_order_usd: float = 250.0, max_adv_part: float = 0.015, round_lots: bool = False):
        self.min_order_usd, self.max_adv_part, self.round_lots = min_order_usd, max_adv_part, round_lots

    def generate_blotter(self, target_weights: pd.Series, current_positions: Dict[str, int], latest_prices: pd.Series, rolling_adv_shares: pd.Series, portfolio_nav: float) -> pd.DataFrame:
        blotter = []
        all_tickers = set(target_weights.index).union(current_positions.keys())
        for ticker in all_tickers:
            t_weight, price, adv_shares = float(target_weights.get(ticker, 0.0)), float(latest_prices.get(ticker, np.nan)), float(rolling_adv_shares.get(ticker, 1_000_000.0))
            if np.isnan(price) or price <= 0: continue

            curr_shares = int(current_positions.get(ticker, 0))
            raw_target_shares = int((t_weight * portfolio_nav) / price)
            max_allowed_delta = int(adv_shares * self.max_adv_part)
            desired_delta = raw_target_shares - curr_shares
            
            target_shares = curr_shares + (max_allowed_delta if desired_delta > max_allowed_delta else (-max_allowed_delta if desired_delta < -max_allowed_delta else desired_delta))
            if self.round_lots: target_shares = (target_shares // 100) * 100

            delta_shares = target_shares - curr_shares
            delta_value = delta_shares * price

            if abs(delta_value) < self.min_order_usd and target_shares != 0: continue

            if delta_shares != 0:
                blotter.append({
                    "Ticker": ticker, "Action": "BUY" if delta_shares > 0 else "SELL", "Order_Type": "MOO",
                    "Delta_Shares": abs(delta_shares), "Target_Shares": target_shares, "Current_Shares": curr_shares,
                    "Est_Order_USD": round(abs(delta_value), 2), "Target_Weight_%": round((target_shares * price / portfolio_nav) * 100, 2),
                    "ADV_Participation_%": round((abs(delta_shares) / max(1.0, adv_shares)) * 100, 3), "Price_Ref": round(price, 2)
                })

        df_blotter = pd.DataFrame(blotter)
        if df_blotter.empty: return pd.DataFrame(columns=["Ticker", "Action", "Order_Type", "Delta_Shares", "Target_Shares", "Current_Shares", "Est_Order_USD", "Target_Weight_%", "ADV_Participation_%", "Price_Ref"])
        return df_blotter.sort_values("Est_Order_USD", ascending=False).reset_index(drop=True)

# ==============================================================================
# 7. UNIFIED 2-STAGE ORCHESTRATOR
# ==============================================================================
def run_unified_pipeline(params: dict):
    print("=" * 85, flush=True)
    print("STARTING ROBUST 2-STAGE STAT-ARB ENGINE (PARAMETRIC ALPHA -> BOUNDED SLSQP)", flush=True)
    print("=" * 85, flush=True)
    
    try:
        prices_train = pd.read_csv(params["price_csv"], index_col=0, parse_dates=True)
        prices_val = pd.read_csv(params["oos_price_csv"], index_col=0, parse_dates=True)
        prices_full = pd.concat([prices_train, prices_val]).dropna(axis=1, how="all").ffill()
    except Exception:
        prices_train = pd.read_csv(params["price_csv"], index_col=0, parse_dates=True)
        prices_full = prices_train.ffill()

    prices_full = prices_full[~prices_full.index.duplicated()].sort_index()

    try:
        open_train = pd.read_csv(params["price_csv"].replace("close", "open"), index_col=0, parse_dates=True)
        open_val = pd.read_csv(params["oos_price_csv"].replace("close", "open"), index_col=0, parse_dates=True)
        open_full = pd.concat([open_train, open_val]).dropna(axis=1, how="all").ffill()
        open_full = open_full[~open_full.index.duplicated(keep='first')].sort_index()
    except FileNotFoundError:
        open_full = prices_full.copy()

    screener = UniverseScreener(params["constituents_path"])
    engine_coint = PairCointegrationEngine(params)
    engine_alloc = ConvexPortfolioOptimizer(params)
    
    state = StatePersistenceEngine.load_checkpoint(params["state_persistence_file"]) or {}
    active_pairs, cooldown_tracker = state.get("active_pairs", {}), state.get("cooldown_tracker", {})
    
    sectors = screener.get_sectors(prices_full.columns.tolist())
    market_ret = prices_full.pct_change().mean(axis=1)
    
    start_idx = min(params["lookback_days"], len(prices_train))
    total_steps = len(prices_full) - start_idx

    master_weights = pd.DataFrame(np.nan, index=prices_full.index, columns=prices_full.columns, dtype=np.float64)
    ghost_weights = pd.DataFrame(np.nan, index=prices_full.index, columns=prices_full.columns, dtype=np.float64)
    promoted_weights = pd.DataFrame(np.nan, index=prices_full.index, columns=prices_full.columns, dtype=np.float64)
    
    pair_weight_matrices, current_sleeve_weights, target_sleeve_weights = {}, {}, {}
    metrics_history, cached_keys = [], []
    days_since_screening = 0

    with Parallel(n_jobs=-1, backend="loky") as parallel:
        for i in range(start_idx, len(prices_full)):
            current_date = prices_full.index[i]
            step_num = i - start_idx + 1
            progress_pct = (step_num / total_steps) * 100.0

            lookback_prices = prices_full.iloc[i - start_idx : i]

            has_exit = False
            for p in list(active_pairs.keys()):
                y, x = np.log(prices_full[p[0]].iloc[i]), np.log(prices_full[p[1]].iloc[i])
                mem = active_pairs[p]
                
                mean, cov, v_t, F_t = engine_coint.kalman_engine.step_update(mem["State_Mean"], mem["State_Cov"], y, x)
                mem["Recent_V_Buffer"].append(v_t)
                
                e_t = v_t / np.sqrt(max(F_t, 1e-4))
                mem.update({"State_Mean": mean, "State_Cov": cov, "Days_Held": mem["Days_Held"] + 1})

                if abs(e_t) <= params["exit_z_spread"] or abs(e_t) >= params["stop_loss_z"] or mem["Days_Held"] > (mem["Half_Life_Days"] * 2.5):
                    has_exit = True
                    master_weights.loc[current_date, p[0]], master_weights.loc[current_date, p[1]] = 0.0, 0.0
                    if p in pair_weight_matrices:
                        pair_weight_matrices[p].loc[current_date, p[0]] = 0.0
                        pair_weight_matrices[p].loc[current_date, p[1]] = 0.0

                    if abs(e_t) >= params["stop_loss_z"]: cooldown_tracker[p] = params["quarantine_days"]
                    
                    del active_pairs[p]
                    if p in current_sleeve_weights: del current_sleeve_weights[p]

            for p in list(cooldown_tracker.keys()):
                cooldown_tracker[p] -= 1
                if cooldown_tracker[p] <= 0: del cooldown_tracker[p]

            if days_since_screening >= params["screening_freq_days"] or not cached_keys:
                print(f"\n[Screening Pass @ {current_date.date()} | Progress: {progress_pct:5.1f}% ({step_num}/{total_steps})] SciPy C-Accelerated Search...", flush=True)
                cached_keys = engine_coint.screen_universe_cointegration(lookback_prices, sectors, parallel)
                days_since_screening = 0
            days_since_screening += 1

            ghost_df = engine_coint.find_pairs(lookback_prices, sectors, active_pairs, cached_keys, parallel)
            
            promoted_ghosts = pd.DataFrame()
            if not ghost_df.empty:
                ghost_df = ghost_df[~ghost_df.apply(lambda r: (r["Asset_A"], r["Asset_B"]) in cooldown_tracker and not r["Is_Active"], axis=1)]
                ghost_pool = ghost_df[~ghost_df["Is_Active"]]
                
                if not ghost_pool.empty:
                    min_score = max(1e-6, ghost_pool["Parametric_Alpha"].quantile(params["ghost_truncation_quantile"]))
                    promoted_ghosts = ghost_pool[ghost_pool["Parametric_Alpha"] >= min_score]
                    promoted_ghosts = promoted_ghosts.sort_values("Parametric_Alpha", ascending=False).head(params["promote_top_n"])

                if len(ghost_pool) > 0:
                    g_alloc = 1.0 / len(ghost_pool)
                    for _, r in ghost_pool.iterrows():
                        ghost_weights.loc[current_date, r["Asset_A"]] = -g_alloc if r["Z_Spread"] > 0 else g_alloc
                        ghost_weights.loc[current_date, r["Asset_B"]] = g_alloc * r["Beta"] if r["Z_Spread"] > 0 else -g_alloc * r["Beta"]
                
                if len(promoted_ghosts) > 0:
                    p_alloc = 1.0 / len(promoted_ghosts)
                    for _, r in promoted_ghosts.iterrows():
                        promoted_weights.loc[current_date, r["Asset_A"]] = -p_alloc if r["Z_Spread"] > 0 else p_alloc
                        promoted_weights.loc[current_date, r["Asset_B"]] = p_alloc * r["Beta"] if r["Z_Spread"] > 0 else -p_alloc * r["Beta"]

            current_max_drift = ConvexPortfolioOptimizer.calculate_max_weight_drift(current_sleeve_weights, target_sleeve_weights)
            has_drift_trigger = current_max_drift >= params["weight_drift_threshold"]
            is_initial_day = (i == start_idx)

            should_rebalance = has_exit or len(promoted_ghosts) > 0 or has_drift_trigger or is_initial_day

            if should_rebalance:
                trigger_cause = (
                    "INITIAL_ENTRY" if is_initial_day else
                    ("SIGNAL_EXIT" if has_exit else
                    ("SIGNAL_ENTRY" if not promoted_ghosts.empty else f"WEIGHT_DRIFT ({current_max_drift:.1%})"))
                )

                print(f"\n[Dynamic Rebalance @ {current_date.date()} | Progress: {progress_pct:5.1f}% ({step_num}/{total_steps})] Cause: {trigger_cause}", flush=True)
                
                if ghost_df.empty:
                    print(f"  --> Pipeline Funnel : Ghost=0 | Promoted=0 | Live={len(active_pairs)}", flush=True)
                    metrics_history.append({"Date": current_date, "Ghost_Size": 0, "Promoted_Size": 0, "Live_Size": len(active_pairs), "Opt_Exp_Variance": 0.0, "Effective_Gross": 0.0, "Mean_Innovation_Z": 0.0, "Mean_CUSUM_S_t": 0.0, "Mean_Parametric_Alpha": 0.0, "rebalanced": 1})
                    continue

                live_candidates = ghost_df[ghost_df["Is_Active"]]
                live_df = pd.concat([live_candidates, promoted_ghosts]).drop_duplicates(subset=["Asset_A", "Asset_B"])
                
                allocs, active_pairs_updates, opt = engine_alloc.allocate(live_df, sectors, current_sleeve_weights)
                
                dropped = set(active_pairs.keys()) - set(allocs.keys())
                for p in dropped:
                    master_weights.loc[current_date, p[0]], master_weights.loc[current_date, p[1]] = 0.0, 0.0
                    if p in pair_weight_matrices:
                        pair_weight_matrices[p].loc[current_date, p[0]] = 0.0
                        pair_weight_matrices[p].loc[current_date, p[1]] = 0.0
                    cooldown_tracker[p] = params["quarantine_days"]

                active_pairs = active_pairs_updates
                current_sleeve_weights = {p: w["Sleeve_Weight"] for p, w in allocs.items()}
                target_sleeve_weights = current_sleeve_weights.copy()

                for p, w in allocs.items():
                    if p not in pair_weight_matrices: pair_weight_matrices[p] = pd.DataFrame(np.nan, index=prices_full.index, columns=[p[0], p[1]])
                    pair_weight_matrices[p].loc[current_date, p[0]] = w[p[0]]
                    pair_weight_matrices[p].loc[current_date, p[1]] = w[p[1]]
                    prev_w0 = 0.0 if pd.isna(master_weights.at[current_date, p[0]]) else master_weights.at[current_date, p[0]]
                    prev_w1 = 0.0 if pd.isna(master_weights.at[current_date, p[1]]) else master_weights.at[current_date, p[1]]
                    master_weights.loc[current_date, p[0]] = prev_w0 + w[p[0]]
                    master_weights.loc[current_date, p[1]] = prev_w1 + w[p[1]]

                avg_inno_z = np.mean([abs(mem['Entry_Z']) for mem in active_pairs.values()]) if active_pairs else 0.0
                avg_cusum = np.mean([mem.get('CUSUM_S_t', 0.0) for mem in active_pairs.values()]) if active_pairs else 0.0
                avg_alpha = live_df["Parametric_Alpha"].mean() if not live_df.empty else 0.0
                
                metrics_history.append({"Date": current_date, "Ghost_Size": len(ghost_pool) if 'ghost_pool' in locals() else 0, "Promoted_Size": len(promoted_ghosts), "Live_Size": len(active_pairs), "Opt_Exp_Variance": opt.get("Portfolio_Variance", 0.0), "Effective_Gross": opt.get("Effective_Gross", 0.0), "Mean_Innovation_Z": avg_inno_z, "Mean_CUSUM_S_t": avg_cusum, "Mean_Parametric_Alpha": avg_alpha, "rebalanced": 1})

                print(f"  --> Pipeline Funnel : Ghost={len(ghost_pool) if 'ghost_pool' in locals() else 0} | Promoted={len(promoted_ghosts)} | Live={len(active_pairs)}", flush=True)
                if active_pairs:
                    print(f"  --> SLSQP Metrics   : Eff Gross={opt.get('Effective_Gross', 0):.2f} | Port Vol={np.sqrt(max(0, opt.get('Portfolio_Variance', 0))):.4f} | Turnover Drag={opt.get('Turnover_Cost', 0):.6f}", flush=True)
                    print(f"  --> Top Allocations :", flush=True)
                    sorted_allocs = sorted(active_pairs.keys(), key=lambda x: abs(allocs[x]['Sleeve_Weight']), reverse=True)[:3]
                    for p in sorted_allocs:
                        w_data = allocs[p]
                        mem = active_pairs[p]
                        print(f"      {p[0]}/{p[1]} | W_A: {w_data[p[0]]:.1%} | W_B: {w_data[p[1]]:.1%} | Inno Z: {mem['Entry_Z']:.2f} | Parametric Alpha: {mem['Parametric_Alpha']:.4f}", flush=True)
                print("-" * 60, flush=True)

                StatePersistenceEngine.save_checkpoint(params["state_persistence_file"], {
                    "active_pairs": active_pairs,
                    "cooldown_tracker": cooldown_tracker
                })

    # ==============================================================================
    # EXHAUSTIVE BACKTEST & FUNNEL ATTRIBUTION LOGIC
    # ==============================================================================
    cap = params["max_gross_exposure"]
    for df_w in [master_weights, ghost_weights, promoted_weights]:
        abs_sum = df_w.abs().sum(axis=1)
        exceed_mask = abs_sum > cap
        if exceed_mask.any(): 
            df_w.loc[exceed_mask] = df_w.loc[exceed_mask].div(abs_sum[exceed_mask], axis=0) * cap

    exec_weights = master_weights.shift(1).iloc[start_idx:]
    exec_ghost_weights = ghost_weights.shift(1).iloc[start_idx:]
    exec_promoted_weights = promoted_weights.shift(1).iloc[start_idx:]

    for p in pair_weight_matrices: 
        pair_weight_matrices[p] = pair_weight_matrices[p].ffill().fillna(0.0).shift(1)

    rebalance_metrics_df = pd.DataFrame(metrics_history).set_index("Date")

    exec_close_prices = prices_full.iloc[start_idx:]
    exec_open_prices = open_full.iloc[start_idx:]

    metrics_df = pd.DataFrame(index=exec_close_prices.index)
    metrics_df = metrics_df.join(rebalance_metrics_df, how="left")
    metrics_df["rebalanced"] = metrics_df["rebalanced"].fillna(0).astype(int)

    ffill_cols = ["Ghost_Size", "Promoted_Size", "Live_Size", "Opt_Exp_Variance", "Effective_Gross", "Mean_Innovation_Z", "Mean_CUSUM_S_t", "Mean_Parametric_Alpha"]
    metrics_df[ffill_cols] = metrics_df[ffill_cols].ffill().fillna(0.0)

    global_engine = VectorbtBacktestEngine(params)
    net_portfolio_live, val_live, true_gross_exp_series = global_engine.run_backtest(exec_close_prices, exec_open_prices, exec_weights)
    _, val_ghost, _ = global_engine.run_backtest(exec_close_prices, exec_open_prices, exec_ghost_weights)
    _, val_promoted, _ = global_engine.run_backtest(exec_close_prices, exec_open_prices, exec_promoted_weights)

    ret_live = val_live.pct_change().fillna(0.0)
    ret_ghost = val_ghost.pct_change().fillna(0.0)
    ret_promoted = val_promoted.pct_change().fillna(0.0)

    metrics_df["Live_Realized_Return"] = ret_live
    metrics_df["Ghost_Realized_Return"] = ret_ghost
    metrics_df["Promoted_Realized_Return"] = ret_promoted

    n_days = max(1, len(ret_live))
    ann_factor = 252.0 / n_days

    tot_ret_ghost = (val_ghost.iloc[-1] / params["initial_capital"]) - 1.0
    tot_ret_promoted = (val_promoted.iloc[-1] / params["initial_capital"]) - 1.0
    tot_ret_live = (val_live.iloc[-1] / params["initial_capital"]) - 1.0

    ann_ret_ghost = (((1.0 + tot_ret_ghost) ** ann_factor) - 1.0) * 100.0
    ann_ret_promoted = (((1.0 + tot_ret_promoted) ** ann_factor) - 1.0) * 100.0
    ann_ret_live = (((1.0 + tot_ret_live) ** ann_factor) - 1.0) * 100.0

    sortino_ghost = compute_sortino_ratio(ret_ghost)
    sortino_promoted = compute_sortino_ratio(ret_promoted)
    sortino_live = compute_sortino_ratio(ret_live)

    ret_delta_parametric = ann_ret_promoted - ann_ret_ghost
    ret_delta_optimizer = ann_ret_live - ann_ret_promoted

    sortino_delta_parametric = sortino_promoted - sortino_ghost
    sortino_delta_optimizer = sortino_live - sortino_promoted

    benchmark_returns = market_ret.iloc[start_idx:]
    neutrality_engine = MarketNeutralityDiagnosticEngine(max_beta=0.03, max_r2=0.01)
    neutrality_metrics_df, verdict = neutrality_engine.analyze(strategy_returns=ret_live, benchmark_returns=benchmark_returns)

    tearsheet_engine = CommitteeTearsheetEngine(params)
    committee_report = tearsheet_engine.generate_tearsheets(prices_full, pair_weight_matrices)

    stats_df = net_portfolio_live.stats()
    stats_df["Max Gross Exposure [%]"] = float(true_gross_exp_series.max() * 100.0)

    order_gen = LiveMOOOrderGenerator(min_order_usd=500.0, max_adv_part=params.get("max_adv_participation", 0.015))
    rolling_adv_shares = (prices_full.iloc[-20:].mean() * 50_000).fillna(1_000_000) 
    final_target_weights = master_weights.ffill().fillna(0.0).iloc[-1]
    
    moo_blotter = order_gen.generate_blotter(
        target_weights=final_target_weights,
        current_positions={},
        latest_prices=prices_full.iloc[-1],
        rolling_adv_shares=rolling_adv_shares,
        portfolio_nav=params["initial_capital"]
    )

    summary_data = {
        "stats_df": stats_df,
        "ann_ret_ghost": ann_ret_ghost,
        "sortino_ghost": sortino_ghost,
        "ann_ret_promoted": ann_ret_promoted,
        "sortino_promoted": sortino_promoted,
        "ann_ret_live": ann_ret_live,
        "sortino_live": sortino_live,
        "ret_delta_parametric": ret_delta_parametric,
        "sortino_delta_parametric": sortino_delta_parametric,
        "ret_delta_optimizer": ret_delta_optimizer,
        "sortino_delta_optimizer": sortino_delta_optimizer,
        "verdict": verdict,
        "neutrality_metrics_df": neutrality_metrics_df
    }

    return committee_report, net_portfolio_live, metrics_df, moo_blotter, summary_data

# ==============================================================================
# 8. DIAGNOSTIC TEARSHEET PLOTTER & REPORTING ENGINE
# ==============================================================================
def _get_next_run_dir(base_dir: str = "results") -> str:
    os.makedirs(base_dir, exist_ok=True)
    existing_ids = [int(d) for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d)) and d.isdigit()]
    run_id = max(existing_ids) + 1 if existing_ids else 1
    run_dir = os.path.join(base_dir, str(run_id))
    os.makedirs(run_dir, exist_ok=True)
    return run_dir

def format_independent_axis(ax, rebalance_dates):
    for r_date in rebalance_dates:
        ax.axvline(x=r_date, color="red", linestyle=":", alpha=0.4, linewidth=1.2)
    ax.grid(True, linestyle=":", alpha=0.6)
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
    ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right")

def print_execution_summary(
    metrics_df: pd.DataFrame, 
    stats_df: pd.DataFrame, 
    committee_report: pd.DataFrame, 
    moo_blotter: pd.DataFrame,
    ann_ret_ghost: float, sortino_ghost: float,
    ann_ret_promoted: float, sortino_promoted: float,
    ann_ret_live: float, sortino_live: float,
    ret_delta_parametric: float, sortino_delta_parametric: float,
    ret_delta_optimizer: float, sortino_delta_optimizer: float,
    verdict: dict, neutrality_metrics_df: pd.DataFrame
):
    print("\n" + "=" * 85, flush=True)
    print("FUNNEL CONVERSION ATTRIBUTION & MARGINAL PERFORMANCE REPORT", flush=True)
    print("=" * 85, flush=True)
    print(f"  {'Funnel Tier / Portfolio Stage':<38} | {'Ann. Return [%]':<18} | {'Sortino Ratio':<18}", flush=True)
    print("-" * 85, flush=True)
    print(f"  {'Ghost Portfolio (Raw Universe)':<38} | {ann_ret_ghost:17.2f}% | {sortino_ghost:18.4f}", flush=True)
    print(f"  {'Promoted Portfolio (Parametric Gated)':<38} | {ann_ret_promoted:17.2f}% | {sortino_promoted:18.4f}", flush=True)
    print(f"  {'Live Portfolio (SLSQP Optimized)':<38} | {ann_ret_live:17.2f}% | {sortino_live:18.4f}", flush=True)
    print("-" * 85, flush=True)
    print(f"  {'--> Parametric Selection Delta':<38} | {ret_delta_parametric:+17.2f}% | {sortino_delta_parametric:+18.4f}", flush=True)
    print(f"  {'--> Optimizer Allocation Delta':<38} | {ret_delta_optimizer:+17.2f}% | {sortino_delta_optimizer:+18.4f}", flush=True)
    print("=" * 85, flush=True)

    print("\n" + "=" * 85, flush=True)
    print("QUANTITATIVE MARKET NEUTRALITY & FACTOR DIAGNOSTIC AUDIT", flush=True)
    print("=" * 85, flush=True)
    print(neutrality_metrics_df.to_string(index=False), flush=True)
    print("-" * 85, flush=True)
    print(f"  VERDICT: Market Neutral = {verdict['Market_Neutral']} | Failures: {verdict['Core_Failure_Reason']}", flush=True)
    print("=" * 85, flush=True)

    print("\n" + "=" * 85, flush=True)
    if not committee_report.empty:
        print("INVESTMENT COMMITTEE PAIR REVIEW TEARSHEET", flush=True)
        print("=" * 85, flush=True)
        print(committee_report.to_string(index=False), flush=True)
    else:
        print("INVESTMENT COMMITTEE PAIR REVIEW TEARSHEET: NO TRADES COMPLETED.", flush=True)

    print("\n" + "=" * 85, flush=True)
    print("WALK-FORWARD NET PORTFOLIO STATS (POST-FEES & EXECUTION LAG)", flush=True)
    print("=" * 85, flush=True)
    print(stats_df.to_string(), flush=True)

    print("\n" + "=" * 85, flush=True)
    print("ACTIONABLE MARKET-ON-OPEN (MOO) ORDER BLOTTER FOR NEXT SESSION", flush=True)
    print("=" * 85, flush=True)
    print(moo_blotter.to_string(index=False), flush=True)

def plot_diagnostic_tearsheet(
    metrics_df: pd.DataFrame,
    initial_capital: float = 250_000.0,
    committee_report: Optional[pd.DataFrame] = None,
    net_portfolio: Optional[vbt.Portfolio] = None,
    moo_blotter: Optional[pd.DataFrame] = None,
    save: bool = True,
    prefix: str = "dev_"
):
    if metrics_df.empty: return
    df = metrics_df.copy()
    if not isinstance(df.index, pd.DatetimeIndex): df.index = pd.to_datetime(df.index)
    rebalance_dates = df[df["rebalanced"] == 1].index if "rebalanced" in df.columns else []

    output_dir = None
    if save:
        output_dir = _get_next_run_dir("results")
        print(f"\n[Export Engine] Saving artifacts to: '{output_dir}/'", flush=True)
        metrics_df.to_csv(os.path.join(output_dir, f"{prefix}metrics.csv"))
        if committee_report is not None and not committee_report.empty: committee_report.to_csv(os.path.join(output_dir, f"{prefix}committee_report.csv"), index=False)
        if moo_blotter is not None: moo_blotter.to_csv(os.path.join(output_dir, f"{prefix}moo_blotter.csv"), index=False)
        if net_portfolio is not None:
            try: net_portfolio.trades.records_readable.to_csv(os.path.join(output_dir, f"{prefix}trade_records.csv"), index=False)
            except Exception: pass
            try: net_portfolio.stats().to_csv(os.path.join(output_dir, f"{prefix}portfolio_stats.csv"))
            except Exception: pass

    fig1, ax1 = plt.subplots(figsize=(16, 4))
    ax1.plot(df.index, df["Ghost_Size"], label="Ghost Universe", color="#2b5c8f", linestyle="--", linewidth=1.5)
    ax1.plot(df.index, df["Promoted_Size"], label="Promoted Universe (Parametric Gated)", color="#e07a5f", linestyle="-.", linewidth=1.5)
    ax1.step(df.index, df["Live_Size"], label="Live Portfolio", color="#2a9d8f", where="post", linewidth=2.5)
    ax1.set_title("Universe Funnel Sizing (Pair Counts)", fontsize=11, fontweight="bold", loc="left")
    ax1.legend(loc="upper left", bbox_to_anchor=(1.02, 1), borderaxespad=0., frameon=True)
    format_independent_axis(ax1, rebalance_dates)
    plt.tight_layout()
    if save and output_dir: fig1.savefig(os.path.join(output_dir, f"{prefix}funnel_sizing.png"), dpi=300, bbox_inches="tight")
    plt.show()

    fig3, ax3 = plt.subplots(figsize=(16, 4))
    ax3_twin = ax3.twinx()
    ax3.plot(df.index, df["Mean_Innovation_Z"], label="Mean |Innovation Z| (|e_t|)", color="#e76f51", linewidth=2.0)
    ax3_twin.plot(df.index, df["Mean_CUSUM_S_t"], label="Mean CUSUM Statistic (S_t)", color="#264653", linestyle="--", linewidth=1.5)
    ax3.set_title("Kalman Innovation Z-Score (|e_t|) & CUSUM Structural Stability (S_t)", fontsize=11, fontweight="bold", loc="left")
    h3, l3 = ax3.get_legend_handles_labels()
    h3_twin, l3_twin = ax3_twin.get_legend_handles_labels()
    ax3.legend(h3 + h3_twin, l3 + l3_twin, loc="upper left", bbox_to_anchor=(1.08, 1), borderaxespad=0., frameon=True)
    format_independent_axis(ax3, rebalance_dates)
    plt.tight_layout()
    if save and output_dir: fig3.savefig(os.path.join(output_dir, f"{prefix}kalman_cusum.png"), dpi=300, bbox_inches="tight")
    plt.show()

    fig4, ax4 = plt.subplots(figsize=(16, 4))
    ax4.plot(df.index, df["Mean_Parametric_Alpha"], label="Mean Parametric Alpha", color="#457b9d", linewidth=2.0)
    ax4.set_title("Parametric Expected Yield Trajectory", fontsize=11, fontweight="bold", loc="left")
    ax4.legend(loc="upper left", bbox_to_anchor=(1.02, 1), borderaxespad=0., frameon=True)
    format_independent_axis(ax4, rebalance_dates)
    plt.tight_layout()
    if save and output_dir: fig4.savefig(os.path.join(output_dir, f"{prefix}parametric_alpha.png"), dpi=300, bbox_inches="tight")
    plt.show()

    fig5, ax5 = plt.subplots(figsize=(16, 5))
    live_cum = (1.0 + df.get("Live_Realized_Return", pd.Series(0.0, index=df.index)).fillna(0.0)).cumprod() * initial_capital
    promoted_cum = (1.0 + df.get("Promoted_Realized_Return", pd.Series(0.0, index=df.index)).fillna(0.0)).cumprod() * initial_capital
    ghost_cum = (1.0 + df.get("Ghost_Realized_Return", pd.Series(0.0, index=df.index)).fillna(0.0)).cumprod() * initial_capital

    ax5.plot(df.index, live_cum, label="Live Realized Value ($)", color="#2a9d8f", linewidth=2.5)
    ax5.plot(df.index, promoted_cum, label="Promoted Shadow Value ($)", color="#e07a5f", linestyle="-.", linewidth=1.5)
    ax5.plot(df.index, ghost_cum, label="Ghost Shadow Value ($)", color="#2b5c8f", linestyle="--", linewidth=1.5)
    
    ax5.axhline(initial_capital, color="black", linewidth=0.8)
    ax5.set_title("Cumulative Performance Horizon & Funnel Attribution ($)", fontsize=11, fontweight="bold", loc="left")
    ax5.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
    ax5.legend(loc="upper left", bbox_to_anchor=(1.02, 1), borderaxespad=0., frameon=True)
    format_independent_axis(ax5, rebalance_dates)
    plt.tight_layout()
    if save and output_dir: fig5.savefig(os.path.join(output_dir, f"{prefix}cumulative_performance.png"), dpi=300, bbox_inches="tight")
    plt.show()

# ==============================================================================
# MAIN EXECUTION ENTRY POINT
# ==============================================================================
if __name__ == "__main__":
    committee_report, net_portfolio, metrics, moo_blotter, summary_data = run_unified_pipeline(params=run_params)
    
    if metrics is not None and not metrics.empty:
        print_execution_summary(
            metrics_df=metrics,
            committee_report=committee_report,
            moo_blotter=moo_blotter,
            **summary_data
        )
        
        plot_diagnostic_tearsheet(
            metrics_df=metrics,
            initial_capital=run_params.get("initial_capital", 250_000.0),
            committee_report=committee_report,
            net_portfolio=net_portfolio,
            moo_blotter=moo_blotter,
            save=True,
            prefix="dev_"
        )
# Out:
# =====================================================================================
# STARTING ROBUST 2-STAGE STAT-ARB ENGINE (PARAMETRIC ALPHA -> BOUNDED SLSQP)
# =====================================================================================
#
# [Screening Pass @ 2024-08-28 | Progress:   0.2% (1/500)] SciPy C-Accelerated Search...
#
# [Dynamic Rebalance @ 2024-08-28 | Progress:   0.2% (1/500)] Cause: INITIAL_ENTRY
#   --> Pipeline Funnel : Ghost=42 | Promoted=16 | Live=16
#   --> SLSQP Metrics   : Eff Gross=1.52 | Port Vol=0.1254 | Turnover Drag=0.001215
#   --> Top Allocations :
#       JKHY/USB | W_A: -15.2% | W_B: 6.6% | Inno Z: 1.80 | Parametric Alpha: 0.1892
#       JKHY/TFC | W_A: -14.8% | W_B: 5.9% | Inno Z: 2.01 | Parametric Alpha: 0.2513
#       JKHY/NTRS | W_A: -14.4% | W_B: 7.5% | Inno Z: 1.75 | Parametric Alpha: 0.1907
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-08-29 | Progress:   0.4% (2/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=36 | Promoted=13 | Live=9
#   --> SLSQP Metrics   : Eff Gross=0.88 | Port Vol=0.0340 | Turnover Drag=0.000676
#   --> Top Allocations :
#       FE/PPL | W_A: -25.0% | W_B: 21.9% | Inno Z: 1.27 | Parametric Alpha: 0.1070
#       CMS/FE | W_A: 19.6% | W_B: -17.6% | Inno Z: -1.23 | Parametric Alpha: 0.1154
#       DTE/FE | W_A: 11.6% | W_B: -10.8% | Inno Z: -0.87 | Parametric Alpha: 0.0464
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-08-30 | Progress:   0.6% (3/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=36 | Promoted=14 | Live=11
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0542 | Turnover Drag=0.000689
#   --> Top Allocations :
#       PAYX/SWK | W_A: 14.8% | W_B: -6.9% | Inno Z: -0.92 | Parametric Alpha: 0.0894
#       CMS/EIX | W_A: 13.8% | W_B: -10.5% | Inno Z: -1.01 | Parametric Alpha: 0.0218
#       MET/PNC | W_A: -13.6% | W_B: 8.8% | Inno Z: 0.74 | Parametric Alpha: 0.0261
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-03 | Progress:   0.8% (4/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=35 | Promoted=8 | Live=8
#   --> SLSQP Metrics   : Eff Gross=1.19 | Port Vol=0.1014 | Turnover Drag=0.000953
#   --> Top Allocations :
#       CSX/FAST | W_A: -25.0% | W_B: 14.2% | Inno Z: 0.78 | Parametric Alpha: 0.0463
#       PAYX/SWK | W_A: -24.0% | W_B: 11.1% | Inno Z: 0.60 | Parametric Alpha: 0.0207
#       DD/OTIS | W_A: -20.3% | W_B: 16.7% | Inno Z: 0.60 | Parametric Alpha: 0.0159
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-04 | Progress:   1.0% (5/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=33 | Promoted=17 | Live=14
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0491 | Turnover Drag=0.000786
#   --> Top Allocations :
#       MSFT/SNPS | W_A: -15.9% | W_B: 11.6% | Inno Z: 2.42 | Parametric Alpha: 0.1727
#       CSX/FAST | W_A: -10.3% | W_B: 5.9% | Inno Z: 0.78 | Parametric Alpha: 0.2225
#       DD/OTIS | W_A: 8.4% | W_B: -6.8% | Inno Z: -1.69 | Parametric Alpha: 0.2077
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-05 | Progress:   1.2% (6/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=36 | Promoted=15 | Live=14
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0564 | Turnover Drag=0.000720
#   --> Top Allocations :
#       MRSH/MCO | W_A: -15.5% | W_B: 10.2% | Inno Z: 0.94 | Parametric Alpha: 0.0413
#       HUBB/PH | W_A: 12.5% | W_B: -9.7% | Inno Z: -0.95 | Parametric Alpha: 0.0881
#       CDW/ROP | W_A: 10.3% | W_B: -7.9% | Inno Z: -1.49 | Parametric Alpha: 0.1811
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-06 | Progress:   1.4% (7/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=34 | Promoted=15 | Live=7
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0721 | Turnover Drag=0.000731
#   --> Top Allocations :
#       DTE/DUK | W_A: 25.0% | W_B: -23.4% | Inno Z: -2.13 | Parametric Alpha: 0.0811
#       CMS/FE | W_A: 16.7% | W_B: -15.0% | Inno Z: -0.99 | Parametric Alpha: 0.0817
#       CMS/ETR | W_A: 14.0% | W_B: -12.0% | Inno Z: -0.95 | Parametric Alpha: 0.0358
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-09 | Progress:   1.6% (8/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=31 | Promoted=11 | Live=11
#   --> SLSQP Metrics   : Eff Gross=1.67 | Port Vol=0.1315 | Turnover Drag=0.001334
#   --> Top Allocations :
#       KO/PM | W_A: 25.0% | W_B: -16.5% | Inno Z: -0.73 | Parametric Alpha: 0.0224
#       LYB/STLD | W_A: 18.8% | W_B: -9.3% | Inno Z: -0.63 | Parametric Alpha: 0.0169
#       JKHY/TFC | W_A: 18.1% | W_B: -7.4% | Inno Z: -0.64 | Parametric Alpha: 0.0229
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-10 | Progress:   1.8% (9/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=32 | Promoted=11 | Live=9
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0719 | Turnover Drag=0.000976
#   --> Top Allocations :
#       CMS/FE | W_A: -25.0% | W_B: 22.5% | Inno Z: 0.97 | Parametric Alpha: 0.0873
#       CMS/ETR | W_A: -20.8% | W_B: 17.7% | Inno Z: 1.31 | Parametric Alpha: 0.0709
#       AME/J | W_A: 8.1% | W_B: -5.9% | Inno Z: -0.56 | Parametric Alpha: 0.0084
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-11 | Progress:   2.0% (10/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=36 | Promoted=14 | Live=13
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0579 | Turnover Drag=0.000679
#   --> Top Allocations :
#       CMS/FE | W_A: -25.0% | W_B: 22.5% | Inno Z: 1.30 | Parametric Alpha: 0.1516
#       CSX/URI | W_A: 9.2% | W_B: -3.5% | Inno Z: -0.89 | Parametric Alpha: 0.0400
#       PAYX/SNA | W_A: -9.2% | W_B: 6.2% | Inno Z: 1.86 | Parametric Alpha: 0.1341
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-12 | Progress:   2.2% (11/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=38 | Promoted=18 | Live=13
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0657 | Turnover Drag=0.000716
#   --> Top Allocations :
#       PEG/SO | W_A: -21.2% | W_B: 17.9% | Inno Z: 2.06 | Parametric Alpha: 0.1477
#       BR/GWW | W_A: 11.5% | W_B: -7.5% | Inno Z: -1.42 | Parametric Alpha: 0.0882
#       HUBB/PH | W_A: -11.1% | W_B: 8.6% | Inno Z: 1.63 | Parametric Alpha: 0.2273
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-13 | Progress:   2.4% (12/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=43 | Promoted=16 | Live=16
#   --> SLSQP Metrics   : Eff Gross=1.29 | Port Vol=0.1186 | Turnover Drag=0.001029
#   --> Top Allocations :
#       JKHY/USB | W_A: -12.7% | W_B: 5.7% | Inno Z: 1.66 | Parametric Alpha: 0.1900
#       JKHY/NTRS | W_A: -12.7% | W_B: 6.7% | Inno Z: 0.78 | Parametric Alpha: 0.0435
#       MET/USB | W_A: -10.9% | W_B: 6.6% | Inno Z: 1.71 | Parametric Alpha: 0.1376
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-16 | Progress:   2.6% (13/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=42 | Promoted=14 | Live=12
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0555 | Turnover Drag=0.000712
#   --> Top Allocations :
#       PAYX/SWK | W_A: 13.5% | W_B: -6.3% | Inno Z: -0.73 | Parametric Alpha: 0.0396
#       KO/PM | W_A: -11.0% | W_B: 7.3% | Inno Z: 0.56 | Parametric Alpha: 0.0056
#       BR/GWW | W_A: -10.9% | W_B: 7.1% | Inno Z: 0.58 | Parametric Alpha: 0.0079
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-17 | Progress:   2.8% (14/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=43 | Promoted=21 | Live=10
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0256 | Turnover Drag=0.000718
#   --> Top Allocations :
#       FE/PPL | W_A: 25.0% | W_B: -21.9% | Inno Z: -1.06 | Parametric Alpha: 0.0753
#       DUK/ETR | W_A: 17.4% | W_B: -14.8% | Inno Z: -1.07 | Parametric Alpha: 0.0352
#       KO/PM | W_A: -14.3% | W_B: 9.5% | Inno Z: 0.91 | Parametric Alpha: 0.0397
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-18 | Progress:   3.0% (15/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=41 | Promoted=21 | Live=12
#   --> SLSQP Metrics   : Eff Gross=0.88 | Port Vol=0.0286 | Turnover Drag=0.000676
#   --> Top Allocations :
#       FE/PPL | W_A: 25.0% | W_B: -21.8% | Inno Z: -1.08 | Parametric Alpha: 0.0832
#       KO/PM | W_A: -15.8% | W_B: 10.5% | Inno Z: 1.26 | Parametric Alpha: 0.0733
#       DUK/ETR | W_A: 14.0% | W_B: -11.9% | Inno Z: -1.54 | Parametric Alpha: 0.0673
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-19 | Progress:   3.2% (16/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=43 | Promoted=18 | Live=14
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0392 | Turnover Drag=0.000675
#   --> Top Allocations :
#       DUK/ETR | W_A: 21.8% | W_B: -18.5% | Inno Z: -0.86 | Parametric Alpha: 0.0235
#       KO/PM | W_A: -16.2% | W_B: 10.7% | Inno Z: 1.47 | Parametric Alpha: 0.0959
#       DTE/PNW | W_A: 11.0% | W_B: -9.2% | Inno Z: -1.02 | Parametric Alpha: 0.0226
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-20 | Progress:   3.4% (17/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=48 | Promoted=24 | Live=13
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0513 | Turnover Drag=0.000711
#   --> Top Allocations :
#       MRSH/MCO | W_A: 25.0% | W_B: -16.3% | Inno Z: -1.66 | Parametric Alpha: 0.1200
#       CSX/SNA | W_A: -14.2% | W_B: 8.0% | Inno Z: 1.06 | Parametric Alpha: 0.0674
#       BLK/ICE | W_A: -14.0% | W_B: 15.0% | Inno Z: 3.06 | Parametric Alpha: 0.1863
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-23 | Progress:   3.6% (18/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=47 | Promoted=24 | Live=13
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0470 | Turnover Drag=0.000720
#   --> Top Allocations :
#       CMS/FE | W_A: 15.7% | W_B: -14.2% | Inno Z: -0.86 | Parametric Alpha: 0.0646
#       MRSH/MCO | W_A: 15.5% | W_B: -10.0% | Inno Z: -1.36 | Parametric Alpha: 0.0906
#       CSX/SNA | W_A: -10.1% | W_B: 5.7% | Inno Z: 1.17 | Parametric Alpha: 0.0735
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-24 | Progress:   3.8% (19/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=41 | Promoted=17 | Live=10
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0555 | Turnover Drag=0.000715
#   --> Top Allocations :
#       FE/PPL | W_A: 22.6% | W_B: -19.7% | Inno Z: -0.93 | Parametric Alpha: 0.0598
#       DTE/FE | W_A: -17.5% | W_B: 16.4% | Inno Z: 0.84 | Parametric Alpha: 0.0463
#       DTE/PNW | W_A: -10.6% | W_B: 8.9% | Inno Z: 1.15 | Parametric Alpha: 0.0279
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-25 | Progress:   4.0% (20/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=42 | Promoted=16 | Live=11
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0700 | Turnover Drag=0.000716
#   --> Top Allocations :
#       IT/FFIV | W_A: 25.0% | W_B: -20.3% | Inno Z: -1.85 | Parametric Alpha: 0.1131
#       DD/OTIS | W_A: -12.2% | W_B: 9.8% | Inno Z: 1.10 | Parametric Alpha: 0.0868
#       AOS/UNP | W_A: -9.7% | W_B: 6.6% | Inno Z: 0.84 | Parametric Alpha: 0.0285
# ------------------------------------------------------------
#
# [Screening Pass @ 2024-09-26 | Progress:   4.2% (21/500)] SciPy C-Accelerated Search...
#
# [Dynamic Rebalance @ 2024-09-26 | Progress:   4.2% (21/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=40 | Promoted=18 | Live=14
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0569 | Turnover Drag=0.000787
#   --> Top Allocations :
#       XOM/VLO | W_A: 13.9% | W_B: -8.5% | Inno Z: -1.24 | Parametric Alpha: 0.1111
#       IT/FFIV | W_A: -10.2% | W_B: 8.3% | Inno Z: 0.82 | Parametric Alpha: 0.0280
#       ALLE/SWK | W_A: -9.9% | W_B: 6.1% | Inno Z: 0.79 | Parametric Alpha: 0.0272
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-27 | Progress:   4.4% (22/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=39 | Promoted=18 | Live=13
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0788 | Turnover Drag=0.000736
#   --> Top Allocations :
#       ALLE/SWK | W_A: 12.7% | W_B: -7.8% | Inno Z: -0.88 | Parametric Alpha: 0.0397
#       CDW/ROP | W_A: -12.1% | W_B: 9.4% | Inno Z: 1.60 | Parametric Alpha: 0.1751
#       AOS/FAST | W_A: -11.9% | W_B: 9.5% | Inno Z: 2.75 | Parametric Alpha: 0.4703
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-30 | Progress:   4.6% (23/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=44 | Promoted=22 | Live=12
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0627 | Turnover Drag=0.000718
#   --> Top Allocations :
#       PAYX/SWK | W_A: 12.2% | W_B: -5.5% | Inno Z: -0.78 | Parametric Alpha: 0.0415
#       DTE/DUK | W_A: -11.6% | W_B: 11.0% | Inno Z: 0.99 | Parametric Alpha: 0.0292
#       DTE/PNW | W_A: -9.7% | W_B: 8.2% | Inno Z: 1.77 | Parametric Alpha: 0.0661
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-01 | Progress:   4.8% (24/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=40 | Promoted=17 | Live=14
#   --> SLSQP Metrics   : Eff Gross=0.88 | Port Vol=0.0543 | Turnover Drag=0.000707
#   --> Top Allocations :
#       AME/TXT | W_A: 16.7% | W_B: -11.5% | Inno Z: -0.76 | Parametric Alpha: 0.0416
#       DTE/DUK | W_A: -15.9% | W_B: 15.1% | Inno Z: 1.60 | Parametric Alpha: 0.0707
#       AFL/AIZ | W_A: -9.6% | W_B: 5.8% | Inno Z: 1.11 | Parametric Alpha: 0.0487
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-02 | Progress:   5.0% (25/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=34 | Promoted=12 | Live=10
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0582 | Turnover Drag=0.000668
#   --> Top Allocations :
#       PAYX/SWK | W_A: -15.6% | W_B: 7.1% | Inno Z: -0.78 | Parametric Alpha: 0.6801
#       AFL/AIZ | W_A: -12.7% | W_B: 7.7% | Inno Z: 1.11 | Parametric Alpha: 0.0329
#       DD/XYL | W_A: 11.5% | W_B: -7.9% | Inno Z: -0.89 | Parametric Alpha: 0.0386
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-03 | Progress:   5.2% (26/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=32 | Promoted=16 | Live=11
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0591 | Turnover Drag=0.000720
#   --> Top Allocations :
#       CSX/SNA | W_A: 18.4% | W_B: -10.1% | Inno Z: -1.39 | Parametric Alpha: 0.1167
#       AFL/AIZ | W_A: -15.0% | W_B: 9.1% | Inno Z: 1.35 | Parametric Alpha: 0.0455
#       SNA/SWK | W_A: -10.3% | W_B: 5.7% | Inno Z: 1.05 | Parametric Alpha: 0.0563
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-04 | Progress:   5.4% (27/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=36 | Promoted=14 | Live=12
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0553 | Turnover Drag=0.000720
#   --> Top Allocations :
#       ALLE/SWK | W_A: -15.6% | W_B: 9.6% | Inno Z: 1.33 | Parametric Alpha: 0.0587
#       AME/TXT | W_A: -11.8% | W_B: 8.1% | Inno Z: 1.11 | Parametric Alpha: 0.0464
#       BR/FERG | W_A: -8.8% | W_B: 5.4% | Inno Z: 1.26 | Parametric Alpha: 0.0908
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-07 | Progress:   5.6% (28/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=32 | Promoted=16 | Live=11
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0613 | Turnover Drag=0.000720
#   --> Top Allocations :
#       MRSH/MCO | W_A: -25.0% | W_B: 16.3% | Inno Z: 1.48 | Parametric Alpha: 0.1104
#       AME/PCAR | W_A: 13.6% | W_B: -9.0% | Inno Z: -1.30 | Parametric Alpha: 0.0596
#       AOS/IR | W_A: 12.6% | W_B: -8.5% | Inno Z: -1.26 | Parametric Alpha: 0.1601
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-08 | Progress:   5.8% (29/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=32 | Promoted=16 | Live=11
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0494 | Turnover Drag=0.000717
#   --> Top Allocations :
#       KO/PM | W_A: 22.7% | W_B: -15.2% | Inno Z: -1.79 | Parametric Alpha: 0.1094
#       ABT/HCA | W_A: -20.3% | W_B: 12.1% | Inno Z: 2.15 | Parametric Alpha: 0.1165
#       AME/PCAR | W_A: 12.6% | W_B: -8.3% | Inno Z: -2.17 | Parametric Alpha: 0.1310
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-09 | Progress:   6.0% (30/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=37 | Promoted=16 | Live=12
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0617 | Turnover Drag=0.000714
#   --> Top Allocations :
#       DD/IR | W_A: 19.2% | W_B: -11.1% | Inno Z: -1.19 | Parametric Alpha: 0.0472
#       HII/TXT | W_A: -15.5% | W_B: 10.8% | Inno Z: 1.02 | Parametric Alpha: 0.0550
#       ABT/HCA | W_A: -9.9% | W_B: 5.9% | Inno Z: 1.87 | Parametric Alpha: 0.1017
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-10 | Progress:   6.2% (31/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=40 | Promoted=20 | Live=12
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0477 | Turnover Drag=0.000710
#   --> Top Allocations :
#       AFL/AIZ | W_A: 15.7% | W_B: -9.4% | Inno Z: -1.63 | Parametric Alpha: 0.0567
#       MRSH/MCO | W_A: -10.8% | W_B: 7.1% | Inno Z: 0.94 | Parametric Alpha: 0.0499
#       IDXX/ZTS | W_A: 9.5% | W_B: -8.2% | Inno Z: -1.09 | Parametric Alpha: 0.0796
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-11 | Progress:   6.4% (32/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=40 | Promoted=20 | Live=14
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0505 | Turnover Drag=0.000716
#   --> Top Allocations :
#       MRSH/MCO | W_A: 11.9% | W_B: -7.8% | Inno Z: -0.76 | Parametric Alpha: 0.0299
#       ALLE/SWK | W_A: 9.5% | W_B: -5.8% | Inno Z: -1.29 | Parametric Alpha: 0.0559
#       DD/IR | W_A: -8.5% | W_B: 4.9% | Inno Z: 1.21 | Parametric Alpha: 0.0503
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-14 | Progress:   6.6% (33/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=37 | Promoted=19 | Live=17
#   --> SLSQP Metrics   : Eff Gross=0.88 | Port Vol=0.0461 | Turnover Drag=0.000706
#   --> Top Allocations :
#       AME/PCAR | W_A: 10.5% | W_B: -6.9% | Inno Z: -1.05 | Parametric Alpha: 0.0424
#       AFL/AIZ | W_A: -9.1% | W_B: 5.5% | Inno Z: 1.02 | Parametric Alpha: 0.0250
#       PAYX/SWK | W_A: 7.5% | W_B: -3.4% | Inno Z: -0.64 | Parametric Alpha: 0.0266
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-15 | Progress:   6.8% (34/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=39 | Promoted=19 | Live=14
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0508 | Turnover Drag=0.000701
#   --> Top Allocations :
#       KO/PM | W_A: -18.0% | W_B: 12.1% | Inno Z: 1.12 | Parametric Alpha: 0.0531
#       ALLE/SWK | W_A: -11.1% | W_B: 6.9% | Inno Z: 1.17 | Parametric Alpha: 0.0454
#       AIG/WFC | W_A: 7.8% | W_B: -4.8% | Inno Z: -1.67 | Parametric Alpha: 0.0631
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-16 | Progress:   7.0% (35/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=38 | Promoted=19 | Live=14
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0495 | Turnover Drag=0.000671
#   --> Top Allocations :
#       MRSH/MCO | W_A: 15.0% | W_B: -9.8% | Inno Z: -1.61 | Parametric Alpha: 0.1303
#       ALLE/SWK | W_A: -13.8% | W_B: 8.6% | Inno Z: 1.36 | Parametric Alpha: 0.0571
#       PAYX/SWK | W_A: -7.8% | W_B: 3.6% | Inno Z: 0.93 | Parametric Alpha: 0.0756
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-17 | Progress:   7.2% (36/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=32 | Promoted=13 | Live=15
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0547 | Turnover Drag=0.000537
#   --> Top Allocations :
#       ALLE/SWK | W_A: -20.6% | W_B: 12.8% | Inno Z: 1.36 | Parametric Alpha: 0.0815
#       IDXX/ZTS | W_A: 8.4% | W_B: -7.1% | Inno Z: -2.61 | Parametric Alpha: 0.3093
#       HUBB/GWW | W_A: 7.9% | W_B: -6.2% | Inno Z: -1.29 | Parametric Alpha: 0.0694
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-18 | Progress:   7.4% (37/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=32 | Promoted=16 | Live=11
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0509 | Turnover Drag=0.000719
#   --> Top Allocations :
#       ALLE/SWK | W_A: -24.0% | W_B: 15.0% | Inno Z: 2.16 | Parametric Alpha: 0.0994
#       CSX/IR | W_A: 8.6% | W_B: -4.1% | Inno Z: 1.29 | Parametric Alpha: 0.3552
#       ETN/VRT | W_A: -8.6% | W_B: 3.1% | Inno Z: 1.09 | Parametric Alpha: 0.1041
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-21 | Progress:   7.6% (38/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=38 | Promoted=11 | Live=10
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0586 | Turnover Drag=0.000720
#   --> Top Allocations :
#       MRSH/MCO | W_A: 25.0% | W_B: -16.2% | Inno Z: -1.29 | Parametric Alpha: 0.0952
#       BLK/BNY | W_A: -13.1% | W_B: 12.0% | Inno Z: 1.03 | Parametric Alpha: 0.0422
#       AMP/IBKR | W_A: -11.1% | W_B: 6.9% | Inno Z: 0.86 | Parametric Alpha: 0.0414
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-22 | Progress:   7.8% (39/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=33 | Promoted=15 | Live=11
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0496 | Turnover Drag=0.000676
#   --> Top Allocations :
#       MRSH/MCO | W_A: 20.0% | W_B: -12.9% | Inno Z: -1.19 | Parametric Alpha: 0.0845
#       CPT/PSA | W_A: -15.4% | W_B: 10.7% | Inno Z: 0.77 | Parametric Alpha: 0.0201
#       AME/ITW | W_A: -11.6% | W_B: 9.3% | Inno Z: 0.75 | Parametric Alpha: 0.0151
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-23 | Progress:   8.0% (40/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=28 | Promoted=13 | Live=11
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0613 | Turnover Drag=0.000699
#   --> Top Allocations :
#       KO/PM | W_A: 18.5% | W_B: -11.5% | Inno Z: 0.60 | Parametric Alpha: 0.7450
#       AJG/MCO | W_A: -17.5% | W_B: 11.5% | Inno Z: 1.28 | Parametric Alpha: 0.1037
#       ETN/VRT | W_A: 9.8% | W_B: -3.6% | Inno Z: -1.06 | Parametric Alpha: 0.1112
# ------------------------------------------------------------
#
# [Screening Pass @ 2024-10-24 | Progress:   8.2% (41/500)] SciPy C-Accelerated Search...
#
# [Dynamic Rebalance @ 2024-10-24 | Progress:   8.2% (41/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=24 | Promoted=8 | Live=8
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0710 | Turnover Drag=0.000567
#   --> Top Allocations :
#       KO/PM | W_A: 20.8% | W_B: -12.7% | Inno Z: 0.60 | Parametric Alpha: 0.3222
#       ETN/VRT | W_A: -17.7% | W_B: 6.6% | Inno Z: 1.34 | Parametric Alpha: 0.1721
#       ROP/TEL | W_A: 16.1% | W_B: -12.6% | Inno Z: -1.04 | Parametric Alpha: 0.0497
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-25 | Progress:   8.4% (42/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=27 | Promoted=12 | Live=7
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0745 | Turnover Drag=0.000682
#   --> Top Allocations :
#       ROP/TEL | W_A: 25.0% | W_B: -19.5% | Inno Z: -1.14 | Parametric Alpha: 0.0616
#       DOC/O | W_A: -25.0% | W_B: 21.7% | Inno Z: 1.49 | Parametric Alpha: 0.0577
#       BLK/BNY | W_A: 13.1% | W_B: -11.9% | Inno Z: -0.88 | Parametric Alpha: 0.0292
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-28 | Progress:   8.6% (43/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=28 | Promoted=12 | Live=10
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0498 | Turnover Drag=0.000720
#   --> Top Allocations :
#       CINF/FITB | W_A: -17.3% | W_B: 7.9% | Inno Z: 2.38 | Parametric Alpha: 0.2632
#       O/VICI | W_A: 15.2% | W_B: -12.2% | Inno Z: -1.88 | Parametric Alpha: 0.0785
#       AJG/MRSH | W_A: 13.8% | W_B: -13.7% | Inno Z: -1.10 | Parametric Alpha: 0.0304
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-29 | Progress:   8.8% (44/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=26 | Promoted=9 | Live=9
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0620 | Turnover Drag=0.000720
#   --> Top Allocations :
#       DOC/O | W_A: -25.0% | W_B: 21.7% | Inno Z: 1.39 | Parametric Alpha: 0.0499
#       O/VICI | W_A: 25.0% | W_B: -19.9% | Inno Z: -1.33 | Parametric Alpha: 0.0498
#       ROP/TEL | W_A: 9.1% | W_B: -7.1% | Inno Z: -0.66 | Parametric Alpha: 0.0146
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-30 | Progress:   9.0% (45/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=26 | Promoted=9 | Live=8
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0541 | Turnover Drag=0.000767
#   --> Top Allocations :
#       O/VICI | W_A: 25.0% | W_B: -19.9% | Inno Z: -1.73 | Parametric Alpha: 0.0790
#       DOC/O | W_A: -18.8% | W_B: 16.3% | Inno Z: 1.35 | Parametric Alpha: 0.0476
#       CINF/FITB | W_A: 16.5% | W_B: -7.5% | Inno Z: -0.80 | Parametric Alpha: 0.0460
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-31 | Progress:   9.2% (46/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=27 | Promoted=14 | Live=12
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0444 | Turnover Drag=0.000718
#   --> Top Allocations :
#       MAS/PNR | W_A: 19.2% | W_B: -14.9% | Inno Z: -1.52 | Parametric Alpha: 0.0618
#       DOC/O | W_A: -10.9% | W_B: 9.5% | Inno Z: 1.18 | Parametric Alpha: 0.0388
#       ABT/MDT | W_A: -9.8% | W_B: 7.1% | Inno Z: 0.64 | Parametric Alpha: 0.0210
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-01 | Progress:   9.4% (47/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=25 | Promoted=13 | Live=13
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0479 | Turnover Drag=0.000646
#   --> Top Allocations :
#       CMS/PPL | W_A: 25.0% | W_B: -23.8% | Inno Z: -1.57 | Parametric Alpha: 0.1255
#       ETN/VRT | W_A: 12.3% | W_B: -4.5% | Inno Z: -2.33 | Parametric Alpha: 0.3411
#       CINF/FITB | W_A: 9.0% | W_B: -4.1% | Inno Z: -0.99 | Parametric Alpha: 0.0694
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-04 | Progress:   9.6% (48/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=23 | Promoted=11 | Live=11
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0463 | Turnover Drag=0.000680
#   --> Top Allocations :
#       ABT/MDT | W_A: -19.3% | W_B: 14.1% | Inno Z: 0.64 | Parametric Alpha: 0.5321
#       DOC/O | W_A: 16.7% | W_B: -14.4% | Inno Z: -1.56 | Parametric Alpha: 0.0626
#       ETN/VRT | W_A: -9.0% | W_B: 3.3% | Inno Z: 1.21 | Parametric Alpha: 0.1346
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-05 | Progress:   9.8% (49/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=18 | Promoted=8 | Live=9
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0540 | Turnover Drag=0.000773
#   --> Top Allocations :
#       MRSH/MCO | W_A: -22.7% | W_B: 15.0% | Inno Z: 0.63 | Parametric Alpha: 0.0161
#       FIS/MA | W_A: -21.3% | W_B: 16.0% | Inno Z: 0.73 | Parametric Alpha: 0.0139
#       BLK/BNY | W_A: -10.4% | W_B: 9.5% | Inno Z: 1.02 | Parametric Alpha: 0.0406
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-06 | Progress:  10.0% (50/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=21 | Promoted=11 | Live=12
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0524 | Turnover Drag=0.000587
#   --> Top Allocations :
#       O/VICI | W_A: 19.6% | W_B: -15.6% | Inno Z: -1.62 | Parametric Alpha: 0.0741
#       DOC/O | W_A: -17.2% | W_B: 15.0% | Inno Z: -1.56 | Parametric Alpha: 0.1557
#       FIS/MA | W_A: 14.9% | W_B: -10.6% | Inno Z: 0.73 | Parametric Alpha: 0.1513
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-07 | Progress:  10.2% (51/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=17 | Promoted=9 | Live=9
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0642 | Turnover Drag=0.000676
#   --> Top Allocations :
#       CMS/PPL | W_A: 15.7% | W_B: -14.8% | Inno Z: -2.02 | Parametric Alpha: 0.2075
#       AIG/WFC | W_A: 15.5% | W_B: -8.8% | Inno Z: 1.23 | Parametric Alpha: 0.3957
#       DE/IEX | W_A: 13.9% | W_B: -11.9% | Inno Z: -2.04 | Parametric Alpha: 0.3314
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-08 | Progress:  10.4% (52/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=18 | Promoted=9 | Live=9
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0373 | Turnover Drag=0.000595
#   --> Top Allocations :
#       CMS/PPL | W_A: 21.4% | W_B: -20.2% | Inno Z: -2.02 | Parametric Alpha: 0.2628
#       O/VICI | W_A: 20.0% | W_B: -16.0% | Inno Z: -1.10 | Parametric Alpha: 0.0425
#       ROP/TEL | W_A: -13.1% | W_B: 10.4% | Inno Z: 1.37 | Parametric Alpha: 0.0636
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-11 | Progress:  10.6% (53/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=20 | Promoted=10 | Live=10
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0546 | Turnover Drag=0.000674
#   --> Top Allocations :
#       MRSH/MCO | W_A: 15.4% | W_B: -10.2% | Inno Z: -0.74 | Parametric Alpha: 0.0295
#       ABT/MDT | W_A: -15.2% | W_B: 11.4% | Inno Z: 1.32 | Parametric Alpha: 0.1310
#       BLK/BNY | W_A: -14.1% | W_B: 12.8% | Inno Z: 1.09 | Parametric Alpha: 0.0516
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-12 | Progress:  10.8% (54/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=22 | Promoted=11 | Live=9
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0507 | Turnover Drag=0.000720
#   --> Top Allocations :
#       ROP/NXPI | W_A: -18.5% | W_B: 9.9% | Inno Z: 0.86 | Parametric Alpha: 0.0580
#       ATO/SO | W_A: -16.1% | W_B: 14.2% | Inno Z: 1.88 | Parametric Alpha: 0.0678
#       MRSH/MCO | W_A: 15.0% | W_B: -9.9% | Inno Z: -1.00 | Parametric Alpha: 0.0612
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-13 | Progress:  11.0% (55/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=22 | Promoted=8 | Live=7
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0669 | Turnover Drag=0.000720
#   --> Top Allocations :
#       MRSH/MCO | W_A: -19.8% | W_B: 13.3% | Inno Z: 0.85 | Parametric Alpha: 0.0434
#       BLK/BNY | W_A: 17.8% | W_B: -15.7% | Inno Z: -0.73 | Parametric Alpha: 0.0239
#       DD/OTIS | W_A: 16.0% | W_B: -12.4% | Inno Z: -0.66 | Parametric Alpha: 0.0224
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-14 | Progress:  11.2% (56/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=29 | Promoted=12 | Live=10
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0864 | Turnover Drag=0.000652
#   --> Top Allocations :
#       ADI/QCOM | W_A: 19.7% | W_B: -13.3% | Inno Z: 1.01 | Parametric Alpha: 0.0669
#       ADSK/AVGO | W_A: -15.4% | W_B: 8.1% | Inno Z: 1.62 | Parametric Alpha: 0.0851
#       DD/XYL | W_A: -12.4% | W_B: 8.2% | Inno Z: 0.84 | Parametric Alpha: 0.0421
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-15 | Progress:  11.4% (57/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=25 | Promoted=13 | Live=11
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0478 | Turnover Drag=0.000880
#   --> Top Allocations :
#       MRSH/L | W_A: 16.2% | W_B: -13.1% | Inno Z: -1.24 | Parametric Alpha: 0.0780
#       ABT/MDT | W_A: -14.1% | W_B: 10.5% | Inno Z: 0.90 | Parametric Alpha: 0.0610
#       BLK/BNY | W_A: -9.8% | W_B: 8.6% | Inno Z: 1.24 | Parametric Alpha: 0.0778
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-18 | Progress:  11.6% (58/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=25 | Promoted=13 | Live=13
#   --> SLSQP Metrics   : Eff Gross=1.78 | Port Vol=0.2232 | Turnover Drag=0.001423
#   --> Top Allocations :
#       MRSH/MCO | W_A: -20.8% | W_B: 14.2% | Inno Z: 1.14 | Parametric Alpha: 0.0785
#       ETN/VRT | W_A: 18.1% | W_B: -6.8% | Inno Z: -0.88 | Parametric Alpha: 0.0722
#       DD/OTIS | W_A: 17.2% | W_B: -13.4% | Inno Z: -1.04 | Parametric Alpha: 0.0757
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-19 | Progress:  11.8% (59/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=22 | Promoted=8 | Live=9
#   --> SLSQP Metrics   : Eff Gross=1.29 | Port Vol=0.1198 | Turnover Drag=0.000891
#   --> Top Allocations :
#       ETN/VRT | W_A: 25.0% | W_B: -9.4% | Inno Z: -0.88 | Parametric Alpha: 0.1194
#       ABT/MDT | W_A: -25.0% | W_B: 18.8% | Inno Z: 1.12 | Parametric Alpha: 0.0827
#       DD/OTIS | W_A: 23.6% | W_B: -18.3% | Inno Z: -1.30 | Parametric Alpha: 0.1132
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-20 | Progress:  12.0% (60/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=21 | Promoted=11 | Live=12
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0468 | Turnover Drag=0.000888
#   --> Top Allocations :
#       ABT/MDT | W_A: -17.9% | W_B: 13.5% | Inno Z: 2.29 | Parametric Alpha: 0.2420
#       MRSH/L | W_A: 16.1% | W_B: -13.0% | Inno Z: -0.96 | Parametric Alpha: 0.0477
#       NDSN/UNP | W_A: 14.2% | W_B: -11.5% | Inno Z: -1.09 | Parametric Alpha: 0.0933
# ------------------------------------------------------------
#
# [Screening Pass @ 2024-11-21 | Progress:  12.2% (61/500)] SciPy C-Accelerated Search...
#
# [Dynamic Rebalance @ 2024-11-21 | Progress:  12.2% (61/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=22 | Promoted=8 | Live=8
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0672 | Turnover Drag=0.000659
#   --> Top Allocations :
#       NDSN/UNP | W_A: -16.9% | W_B: 13.7% | Inno Z: 0.76 | Parametric Alpha: 0.0409
#       DD/OTIS | W_A: -16.8% | W_B: 13.0% | Inno Z: 0.74 | Parametric Alpha: 0.0334
#       AMP/IBKR | W_A: 12.4% | W_B: -8.0% | Inno Z: -1.16 | Parametric Alpha: 0.0859
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-22 | Progress:  12.4% (62/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=21 | Promoted=11 | Live=8
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0786 | Turnover Drag=0.000692
#   --> Top Allocations :
#       IT/NOW | W_A: 23.7% | W_B: -13.9% | Inno Z: -0.94 | Parametric Alpha: 0.0686
#       ALL/HIG | W_A: -23.5% | W_B: 20.6% | Inno Z: 1.59 | Parametric Alpha: 0.0911
#       AJG/MCO | W_A: -13.2% | W_B: 9.4% | Inno Z: 1.61 | Parametric Alpha: 0.1065
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-25 | Progress:  12.6% (63/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=19 | Promoted=10 | Live=6
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0648 | Turnover Drag=0.000752
#   --> Top Allocations :
#       IT/NOW | W_A: 22.7% | W_B: -13.3% | Inno Z: -0.74 | Parametric Alpha: 0.0349
#       NDSN/UNP | W_A: -18.2% | W_B: 14.8% | Inno Z: 0.64 | Parametric Alpha: 0.0231
#       MRSH/MCO | W_A: -16.7% | W_B: 11.5% | Inno Z: 1.09 | Parametric Alpha: 0.0625
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-26 | Progress:  12.8% (64/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=19 | Promoted=10 | Live=7
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0608 | Turnover Drag=0.000632
#   --> Top Allocations :
#       ALLE/MAS | W_A: 25.0% | W_B: -18.9% | Inno Z: -2.04 | Parametric Alpha: 0.1354
#       NDSN/UNP | W_A: 25.0% | W_B: -20.3% | Inno Z: -1.27 | Parametric Alpha: 0.1125
#       CSX/URI | W_A: -14.9% | W_B: 5.5% | Inno Z: 1.10 | Parametric Alpha: 0.0681
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-27 | Progress:  13.0% (65/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=20 | Promoted=10 | Live=9
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0529 | Turnover Drag=0.000712
#   --> Top Allocations :
#       NDSN/UNP | W_A: 25.0% | W_B: -20.2% | Inno Z: -0.92 | Parametric Alpha: 0.0625
#       CSX/NDSN | W_A: -11.4% | W_B: 6.2% | Inno Z: 0.93 | Parametric Alpha: 0.1001
#       ALLE/MAS | W_A: 10.7% | W_B: -8.1% | Inno Z: -0.77 | Parametric Alpha: 0.0238
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-29 | Progress:  13.2% (66/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=21 | Promoted=4 | Live=4
#   --> SLSQP Metrics   : Eff Gross=0.50 | Port Vol=0.0534 | Turnover Drag=0.000400
#   --> Top Allocations :
#       BLK/BNY | W_A: 22.1% | W_B: -19.2% | Inno Z: -1.19 | Parametric Alpha: 0.0636
#       AJG/MCO | W_A: -12.7% | W_B: 9.1% | Inno Z: 0.65 | Parametric Alpha: 0.0143
#       ALLE/MAS | W_A: -11.0% | W_B: 8.3% | Inno Z: 0.69 | Parametric Alpha: 0.0173
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-02 | Progress:  13.4% (67/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=21 | Promoted=3 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.37 | Port Vol=0.0318 | Turnover Drag=0.000300
#   --> Top Allocations :
#       CMS/FE | W_A: 17.8% | W_B: -16.1% | Inno Z: -1.11 | Parametric Alpha: 0.0838
#       NDSN/UNP | W_A: -13.5% | W_B: 11.0% | Inno Z: 0.85 | Parametric Alpha: 0.0525
#       AJG/MCO | W_A: 6.2% | W_B: -4.4% | Inno Z: -0.64 | Parametric Alpha: 0.0130
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-03 | Progress:  13.6% (68/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=20 | Promoted=5 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.62 | Port Vol=0.0450 | Turnover Drag=0.000500
#   --> Top Allocations :
#       NDSN/UNP | W_A: -20.9% | W_B: 17.0% | Inno Z: 0.77 | Parametric Alpha: 0.0395
#       EXPD/NDSN | W_A: -17.0% | W_B: 11.4% | Inno Z: 0.84 | Parametric Alpha: 0.0461
#       AJG/MCO | W_A: 14.0% | W_B: -10.1% | Inno Z: -1.05 | Parametric Alpha: 0.0529
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-04 | Progress:  13.8% (69/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=21 | Promoted=11 | Live=10
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0650 | Turnover Drag=0.000720
#   --> Top Allocations :
#       NDSN/UNP | W_A: -25.0% | W_B: 20.3% | Inno Z: 1.17 | Parametric Alpha: 0.1011
#       MRSH/MCO | W_A: 16.8% | W_B: -11.5% | Inno Z: -0.67 | Parametric Alpha: 0.0179
#       BLK/BNY | W_A: -14.9% | W_B: 13.0% | Inno Z: 1.83 | Parametric Alpha: 0.1218
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-05 | Progress:  14.0% (70/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=20 | Promoted=10 | Live=11
#   --> SLSQP Metrics   : Eff Gross=1.52 | Port Vol=0.2003 | Turnover Drag=0.001174
#   --> Top Allocations :
#       AJG/MCO | W_A: 20.4% | W_B: -14.6% | Inno Z: -1.27 | Parametric Alpha: 0.0716
#       OXY/SLB | W_A: 17.7% | W_B: -10.2% | Inno Z: -1.79 | Parametric Alpha: 0.1625
#       IT/NOW | W_A: 17.6% | W_B: -10.3% | Inno Z: -0.68 | Parametric Alpha: 0.2200
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-06 | Progress:  14.2% (71/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=21 | Promoted=11 | Live=11
#   --> SLSQP Metrics   : Eff Gross=1.29 | Port Vol=0.2425 | Turnover Drag=0.001036
#   --> Top Allocations :
#       EG/MET | W_A: 19.1% | W_B: -13.2% | Inno Z: -1.50 | Parametric Alpha: 0.0676
#       CSX/URI | W_A: 13.5% | W_B: -4.8% | Inno Z: -1.03 | Parametric Alpha: 0.0568
#       CSX/NDSN | W_A: 13.1% | W_B: -7.1% | Inno Z: -1.09 | Parametric Alpha: 0.1440
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-09 | Progress:  14.4% (72/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=19 | Promoted=9 | Live=9
#   --> SLSQP Metrics   : Eff Gross=1.45 | Port Vol=0.1068 | Turnover Drag=0.001160
#   --> Top Allocations :
#       MRSH/MCO | W_A: 25.0% | W_B: -17.1% | Inno Z: -1.84 | Parametric Alpha: 0.1391
#       EXPD/NDSN | W_A: 23.9% | W_B: -16.0% | Inno Z: -0.93 | Parametric Alpha: 0.0543
#       AJG/MCO | W_A: 21.2% | W_B: -15.1% | Inno Z: -2.39 | Parametric Alpha: 0.1964
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-10 | Progress:  14.6% (73/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=18 | Promoted=9 | Live=6
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.0607 | Turnover Drag=0.000732
#   --> Top Allocations :
#       CMS/FE | W_A: -25.0% | W_B: 22.7% | Inno Z: 1.17 | Parametric Alpha: 0.0902
#       MRSH/MCO | W_A: 22.1% | W_B: -15.1% | Inno Z: -1.84 | Parametric Alpha: 0.2567
#       OXY/SLB | W_A: -15.0% | W_B: 8.6% | Inno Z: 1.55 | Parametric Alpha: 0.1311
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-11 | Progress:  14.8% (74/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=19 | Promoted=7 | Live=6
#   --> SLSQP Metrics   : Eff Gross=0.87 | Port Vol=0.0518 | Turnover Drag=0.000693
#   --> Top Allocations :
#       MRSH/MCO | W_A: 25.0% | W_B: -17.0% | Inno Z: -1.78 | Parametric Alpha: 0.1366
#       CMS/FE | W_A: -24.4% | W_B: 22.2% | Inno Z: 1.11 | Parametric Alpha: 0.0769
#       BLK/BNY | W_A: -11.9% | W_B: 10.7% | Inno Z: 0.95 | Parametric Alpha: 0.0366
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-12 | Progress:  15.0% (75/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=18 | Promoted=9 | Live=7
#   --> SLSQP Metrics   : Eff Gross=0.88 | Port Vol=0.0616 | Turnover Drag=0.000722
#   --> Top Allocations :
#       BLK/BNY | W_A: -24.5% | W_B: 22.1% | Inno Z: 1.94 | Parametric Alpha: 0.1116
#       MRSH/MCO | W_A: 19.2% | W_B: -13.0% | Inno Z: -1.65 | Parametric Alpha: 0.1175
#       PTC/WDC | W_A: -13.7% | W_B: 5.2% | Inno Z: 0.99 | Parametric Alpha: 0.0407
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-13 | Progress:  15.2% (76/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=19 | Promoted=9 | Live=9
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0573 | Turnover Drag=0.000678
#   --> Top Allocations :
#       D/FE | W_A: 17.0% | W_B: -15.9% | Inno Z: -1.36 | Parametric Alpha: 0.0663
#       EXPD/NDSN | W_A: -15.4% | W_B: 10.2% | Inno Z: 1.17 | Parametric Alpha: 0.5812
#       ALL/HIG | W_A: -12.2% | W_B: 10.7% | Inno Z: 0.81 | Parametric Alpha: 0.0232
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-16 | Progress:  15.4% (77/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=16 | Promoted=8 | Live=8
#   --> SLSQP Metrics   : Eff Gross=1.31 | Port Vol=0.2275 | Turnover Drag=0.001048
#   --> Top Allocations :
#       ALL/HIG | W_A: -25.0% | W_B: 22.0% | Inno Z: 1.18 | Parametric Alpha: 0.0497
#       CSX/FAST | W_A: 20.1% | W_B: -10.3% | Inno Z: -0.55 | Parametric Alpha: 0.0111
#       CSX/GWW | W_A: 19.5% | W_B: -8.8% | Inno Z: -0.58 | Parametric Alpha: 0.0125
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-17 | Progress:  15.6% (78/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=16 | Promoted=7 | Live=7
#   --> SLSQP Metrics   : Eff Gross=1.25 | Port Vol=0.1356 | Turnover Drag=0.001001
#   --> Top Allocations :
#       OXY/SLB | W_A: 25.0% | W_B: -14.5% | Inno Z: -1.44 | Parametric Alpha: 0.0982
#       MRSH/MCO | W_A: 25.0% | W_B: -17.0% | Inno Z: -0.81 | Parametric Alpha: 0.0304
#       CSX/FAST | W_A: 19.2% | W_B: -9.8% | Inno Z: -0.58 | Parametric Alpha: 0.0170
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-18 | Progress:  15.8% (79/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=16 | Promoted=8 | Live=7
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0612 | Turnover Drag=0.000720
#   --> Top Allocations :
#       CMS/FE | W_A: -25.0% | W_B: 22.7% | Inno Z: 0.67 | Parametric Alpha: 0.0186
#       OXY/SLB | W_A: -15.2% | W_B: 8.8% | Inno Z: 0.66 | Parametric Alpha: 0.0174
#       ALL/HIG | W_A: -13.0% | W_B: 11.5% | Inno Z: 0.64 | Parametric Alpha: 0.0099
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-19 | Progress:  16.0% (80/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=15 | Promoted=6 | Live=6
#   --> SLSQP Metrics   : Eff Gross=1.23 | Port Vol=0.1739 | Turnover Drag=0.000981
#   --> Top Allocations :
#       AMP/IBKR | W_A: 25.0% | W_B: -16.3% | Inno Z: -1.78 | Parametric Alpha: 0.1275
#       OXY/SLB | W_A: -25.0% | W_B: 14.5% | Inno Z: 1.36 | Parametric Alpha: 0.0919
#       CSX/GWW | W_A: 22.5% | W_B: -10.1% | Inno Z: -0.99 | Parametric Alpha: 0.0545
# ------------------------------------------------------------
#
# [Screening Pass @ 2024-12-20 | Progress:  16.2% (81/500)] SciPy C-Accelerated Search...
#
# [Dynamic Rebalance @ 2024-12-20 | Progress:  16.2% (81/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=14 | Promoted=7 | Live=6
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.0872 | Turnover Drag=0.000840
#   --> Top Allocations :
#       PAYX/PNR | W_A: -22.1% | W_B: 11.8% | Inno Z: 1.09 | Parametric Alpha: 0.1021
#       BLK/BNY | W_A: 21.8% | W_B: -19.5% | Inno Z: -1.04 | Parametric Alpha: 0.0382
#       INVH/PSA | W_A: -17.1% | W_B: 9.3% | Inno Z: 1.56 | Parametric Alpha: 0.1322
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-23 | Progress:  16.4% (82/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=13 | Promoted=4 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.63 | Port Vol=0.0605 | Turnover Drag=0.000460
#   --> Top Allocations :
#       OXY/SLB | W_A: -21.3% | W_B: 12.5% | Inno Z: 1.36 | Parametric Alpha: 0.3247
#       PTC/CRM | W_A: 15.6% | W_B: -8.4% | Inno Z: -0.74 | Parametric Alpha: 0.0277
#       PAYX/PNR | W_A: -13.9% | W_B: 7.5% | Inno Z: 0.88 | Parametric Alpha: 0.0653
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-24 | Progress:  16.6% (83/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=15 | Promoted=8 | Live=8
#   --> SLSQP Metrics   : Eff Gross=1.42 | Port Vol=0.2543 | Turnover Drag=0.001134
#   --> Top Allocations :
#       CSX/FAST | W_A: -24.6% | W_B: 12.5% | Inno Z: 0.98 | Parametric Alpha: 0.0771
#       CSX/GWW | W_A: -24.6% | W_B: 11.1% | Inno Z: 1.18 | Parametric Alpha: 0.0725
#       CSX/NDSN | W_A: -22.0% | W_B: 11.8% | Inno Z: 0.90 | Parametric Alpha: 0.0826
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-26 | Progress:  16.8% (84/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=15 | Promoted=8 | Live=8
#   --> SLSQP Metrics   : Eff Gross=1.49 | Port Vol=0.2052 | Turnover Drag=0.001189
#   --> Top Allocations :
#       PAYX/PNR | W_A: -25.0% | W_B: 13.5% | Inno Z: 0.90 | Parametric Alpha: 0.0668
#       BLK/BNY | W_A: -25.0% | W_B: 22.5% | Inno Z: 1.16 | Parametric Alpha: 0.0470
#       CSX/FAST | W_A: -22.5% | W_B: 11.5% | Inno Z: 0.80 | Parametric Alpha: 0.0475
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-27 | Progress:  17.0% (85/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=13 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0514 | Turnover Drag=0.000200
#   --> Top Allocations :
#       PAYX/PNR | W_A: -25.0% | W_B: 13.6% | Inno Z: 0.89 | Parametric Alpha: 0.0738
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-30 | Progress:  17.2% (86/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=13 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.12 | Port Vol=0.0145 | Turnover Drag=0.000100
#   --> Top Allocations :
#       CMS/FE | W_A: -12.5% | W_B: 11.4% | Inno Z: 0.58 | Parametric Alpha: 0.0078
# ------------------------------------------------------------
#
# ...
#  ALLE / PNR         -0.024052     -0.530975      -0.023709    0.024052     50.000000             2
#  TDY / ZBRA         -0.014230     -0.532435      -0.023774    0.014230     50.000000             2
#  EXPD / EFX         -0.048463     -0.534077      -0.023847    0.048463      0.000000             2
#    MCO / RF         -0.067216     -0.535405      -0.023907    0.067216      0.000000             2
#   DOW / IFF         -0.003943     -0.535418      -0.023907    0.003943      0.000000             2
#   AIZ / MET         -2.725551     -0.535429      -0.041427    2.725551     30.000000            10
#  CDW / ZBRA         -0.007770     -0.538743      -0.024055    0.007770     50.000000             2
#  AMCR / SHW         -0.016341     -0.539327      -0.024081    0.016341     50.000000             2
#   AON / WTW         -0.082282     -0.541958      -0.024199    0.082282     50.000000             2
#   DTE / EXC         -0.572519     -0.542921      -0.103044    0.694882     46.666667            30
#   FDS / BEN         -0.028096     -0.543948      -0.024288    0.028096     50.000000             2
#   KMI / WMB         -0.431861     -0.544863      -0.049986    0.561051     50.000000             8
#   AMP / COF         -0.660229     -0.546817      -0.061020    0.795864     57.142857            14
#    RF / STT         -0.090437     -0.547597      -0.034894    0.090437     50.000000             6
#  ALLE / EFX         -0.557243     -0.548893      -0.060501    0.614692     50.000000            18
#  COF / IBKR         -0.313160     -0.549418      -0.058575    0.443586     50.000000            12
#   CEG / NRG         -0.271998     -0.550605      -0.068235    0.407720     40.000000            20
#   FITB / RF         -0.015832     -0.551128      -0.024608    0.015832     50.000000             2
#    BR / LII         -0.150337     -0.554097      -0.055487    0.193146     40.000000            10
#   AEE / AEP         -0.058608     -0.554793      -0.052200    0.058608     50.000000             8
#   SNA / SWK         -0.677780     -0.559546      -0.039502    0.677780     25.000000             4
#  XYZ / TROW         -0.536044     -0.563289      -0.047051    0.536044     30.000000            10
#  KEYS / NOW         -0.613318     -0.564500      -0.063879    0.788268     50.000000            20
#    MMM / PH         -0.011308     -0.564521      -0.025205    0.011308      0.000000             2
#   DUK / PNW         -0.337881     -0.568460      -0.048659    0.402753     16.666667             6
#  EVRG / ETR         -0.022105     -0.569561      -0.025430    0.022105     50.000000             2
#  RJF / TROW         -0.119224     -0.570514      -0.031197    0.119224      0.000000             4
# CDNS / INTU         -0.554931     -0.571996      -0.052759    0.585526     30.000000            10
#  FERG / ROK         -0.255857     -0.573229      -0.031345    0.255857     25.000000             4
#   MKC / TSN         -0.218682     -0.573956      -0.040873    0.218682     37.500000             8
#   PFG / USB         -0.037994     -0.575595      -0.025699    0.037994     50.000000             2
#   APO / CFG         -0.072019     -0.577285      -0.036714    0.079504     25.000000             4
#   CCI / UDR         -0.240120     -0.583040      -0.036813    0.240120     50.000000             6
#   RJF / SYF         -0.272775     -0.583571      -0.050132    0.283087     30.000000            10
#    GD / HII         -0.900359     -0.583808      -0.045292    0.945125     41.666667            12
# MPWR / NTAP         -1.019649     -0.585259      -0.036953    1.019649     50.000000             4
#   ALL / TRV         -1.487612     -0.591307      -0.136994    1.776552     50.000000            58
#    BR / GWW         -0.464938     -0.597444      -0.091824    0.546599     33.333333            30
#    PNW / SO         -0.405891     -0.599859      -0.070421    0.405891     40.000000            10
#   HON / EMR         -0.050193     -0.600537      -0.032836    0.050193     50.000000             4
#  CINF / TRV         -0.552279     -0.602127      -0.108974    0.609401     46.428571            28
# MSFT / SNPS         -0.431906     -0.603339      -0.042589    0.431906     50.000000             4
#  FFIV / NOW         -0.138907     -0.606941      -0.038782    0.156539     16.666667             6
#  HBAN / WFC         -0.005031     -0.614445      -0.027431    0.005031     50.000000             2
#  ITW / VLTO         -1.290566     -0.617297      -0.061879    1.302366     31.250000            16
# CPAY / MSCI         -0.431757     -0.620136      -0.047951    0.431757     16.666667             6
#   AMP / JPM         -0.244205     -0.620571      -0.039179    0.244205     25.000000             4
#   CPT / MAA         -0.037720     -0.623641      -0.034098    0.037720     50.000000             2
#   EXR / IRM         -0.192010     -0.625921      -0.053484    0.224050     42.857143            14
#   AME / XYL         -0.892246     -0.636018      -0.066804    0.924599     43.750000            16
#   CDW / HPQ         -0.305932     -0.637246      -0.040390    0.326379     50.000000             4
#   CVX / EXE         -0.324821     -0.641847      -0.035092    0.324821     50.000000             4
#   AJG / MCO         -0.657200     -0.641899      -0.102680    0.693831     45.454545            22
#   ROP / CRM         -0.268273     -0.642523      -0.057563    0.284167     25.000000             8
#   AIG / AFL         -0.235910     -0.647430      -0.054207    0.235910     50.000000            10
#   CPT / PSA         -0.015104     -0.648818      -0.028963    0.015104     50.000000             2
# QCOM / NXPI         -0.536254     -0.648962      -0.071480    0.580171     50.000000            16
#  NXPI / STX         -0.343293     -0.650669      -0.041076    0.343293     50.000000             4
#    MA / RJF         -0.578375     -0.654238      -0.076973    0.776424     55.000000            20
#   PWR / TDG         -0.222588     -0.654624      -0.066794    0.222588     50.000000            10
#    AWK / ES         -0.436025     -0.662538      -0.041824    0.436025     50.000000             4
# KEYS / MSFT         -0.087138     -0.668080      -0.042174    0.087138      0.000000             4
#  CINF / ICE         -0.197080     -0.672059      -0.120445    0.261853     35.714286            28
#  ABBV / JNJ         -0.661542     -0.672874      -0.056215    0.661542     50.000000            10
#   BLK / ICE         -0.239344     -0.674642      -0.047614    0.239344     25.000000             4
#    BX / KKR         -1.004470     -0.676470      -0.108767    1.136282     50.000000            42
#    ALL / GL         -0.712605     -0.686449      -0.076502    0.712605     42.857143            14
#   AEE / PPL         -0.198942     -0.694416      -0.037960    0.198942     25.000000             4
#  FDX / JBHT         -0.437371     -0.698322      -0.092638    0.504024     39.285714            28
#   USB / TFC         -0.051303     -0.702194      -0.058634    0.051303     50.000000             6
#   LNT / PPL         -0.533852     -0.707224      -0.125905    0.641987     46.428571            28
#   CSX / PNR         -0.487248     -0.708318      -0.051522    0.487248     33.333333             6
#  JKHY / TFC         -0.097231     -0.709779      -0.044801    0.097231     50.000000             4
#   MU / QCOM         -0.314503     -0.712147      -0.044950    0.314503     25.000000             4
#   SYK / ZBH         -0.417364     -0.715117      -0.056228    0.456930     41.666667            12
#   AOS / UNP         -0.180545     -0.717110      -0.055435    0.180545     50.000000             6
#  OTIS / PWR         -0.155061     -0.721192      -0.050904    0.155061     33.333333             6
#  COF / HBAN         -0.144982     -0.722318      -0.039483    0.144982     50.000000             4
#   HII / TXT         -0.304118     -0.726658      -0.064861    0.304118     40.000000            10
#   BAC / CFG         -0.054208     -0.728734      -0.045995    0.054208     25.000000             4
#   ABT / SYK         -0.149477     -0.729483      -0.039873    0.149477     50.000000             2
#  BLK / HBAN         -0.080454     -0.730942      -0.046134    0.080454      0.000000             4
#  PAYX / RSG         -0.045391     -0.731147      -0.039964    0.045391     50.000000             4
#   AFL / MET         -0.524199     -0.733866      -0.104880    0.730126     40.909091            22
#   COF / WFC         -0.523614     -0.738214      -0.120718    0.603986     50.000000            32
#   MET / ICE         -0.506224     -0.741500      -0.094749    0.506224     12.500000            16
#   CAT / ETN         -0.147051     -0.744823      -0.052557    0.147051     50.000000             4
#    EG / MET         -0.624670     -0.747573      -0.089437    0.624670     50.000000            20
#  AME / HUBB         -0.039551     -0.761717      -0.041631    0.039551     50.000000             4
#   EXR / SPG         -0.871042     -0.765474      -0.097106    0.871042     36.363636            22
# ARES / NDAQ         -0.216344     -0.775044      -0.049128    0.216344     25.000000             4
# KEYS / NTAP         -0.432017     -0.785578      -0.061029    0.446066     30.000000            10
#     REG / O         -0.103350     -0.786719      -0.060803    0.103350     50.000000             6
#   DOC / VTR         -1.217854     -0.786811      -0.080505    1.217854     50.000000            14
#   REG / VTR         -0.135585     -0.791123      -0.049923    0.135585      0.000000             2
#   EXR / FRT         -0.291046     -0.796275      -0.066601    0.302473     20.000000            10
#   CSX / FTV         -0.097480     -0.799896      -0.061819    0.097480     50.000000             4
#   FTV / UPS         -0.843861     -0.801987      -0.110494    0.886995     46.875000            32
#  DHR / GEHC         -0.174854     -0.806281      -0.062311    0.174854     16.666667             6
#    COF / GS         -0.962871     -0.822869      -0.102539    1.060295     41.666667            24
#   AON / PGR         -2.001360     -0.836563      -0.207586    2.366746     41.891892            74
#  ETN / FERG         -1.225729     -0.838559      -0.091622    1.352315     44.444444            18
#   FTV / WAB         -0.247669     -0.860893      -0.066520    0.247669     33.333333             6
#    LNT / NI         -0.742506     -0.862443      -0.162664    0.770378     42.000000            50
# NTAP / ZBRA         -0.868736     -0.864058      -0.054512    0.868736     33.333333             6
#    PEG / SO         -0.210035     -0.897605      -0.080076    0.210035     30.000000            10
#   KEY / MTB         -0.177381     -0.898455      -0.094672    0.177381     35.714286            14
#   AMAT / MU         -0.365369     -0.898463      -0.069414    0.365369     50.000000             8
#   COP / SLB         -0.411097     -0.923083      -0.071310    0.411097     33.333333             6
#  MRSH / MCO         -1.889179     -0.955520      -0.189403    2.313658     39.130435            46
#    AEP / NI         -0.600710     -1.013078      -0.090570    0.625860     57.142857            14
#  MSFT / PTC         -0.937974     -1.017133      -0.126569    0.942333     40.000000            20
# MRSH / JKHY         -0.398229     -1.045821      -0.087251    0.398229     12.500000             8
#   AEE / ETR         -1.248923     -1.066372      -0.210164    1.343090     38.000000            50
#   ARE / AMT         -1.786940     -1.068335      -0.139258    1.786940     40.909091            22
#  AMP / HBAN         -0.475550     -1.077937      -0.191364    0.521305     42.105263            38
#   BLK / CFG         -0.377938     -1.229876      -0.185155    0.410881     31.818182            22
#    AEE / NI         -0.725119     -1.380062      -0.173735    0.725119     38.888889            18
#
# =====================================================================================
# WALK-FORWARD NET PORTFOLIO STATS (POST-FEES & EXECUTION LAG)
# =====================================================================================
# Start                         2024-08-28 00:00:00
# End                           2026-08-26 00:00:00
# Period                                        500
# Start Value                              250000.0
# End Value                           196291.490373
# Total Return [%]                       -21.483404
# Benchmark Return [%]                    55.186227
# Max Gross Exposure [%]                 184.320261
# Total Fees Paid                      37891.287947
# Max Drawdown [%]                        22.603642
# Max Drawdown Duration                       489.0
# Total Trades                                 7043
# Total Closed Trades                          7025
# Total Open Trades                              18
# Open Trade PnL                         151.111763
# Win Rate [%]                            48.939502
# Best Trade [%]                            17.9922
# Worst Trade [%]                        -18.051959
# Avg Winning Trade [%]                    1.464951
# Avg Losing Trade [%]                    -1.511337
# Avg Winning Trade Duration               1.489238
# Avg Losing Trade Duration                1.499303
# Profit Factor                            0.940457
# Expectancy                               -7.66685
#
# =====================================================================================
# ACTIONABLE MARKET-ON-OPEN (MOO) ORDER BLOTTER FOR NEXT SESSION
# =====================================================================================
# Ticker Action Order_Type  Delta_Shares  Target_Shares  Current_Shares  Est_Order_USD  Target_Weight_%  ADV_Participation_%  Price_Ref
#    AIG    BUY        MOO           816            816               0       62807.52            25.12                0.021      76.97
#    AEE    BUY        MOO           431            431               0       46440.25            18.58                0.008     107.75
#     MA   SELL        MOO            71            -71               0       42491.37           -17.00                0.000     598.47
#    AEP   SELL        MOO           300           -300               0       37008.00           -14.80                0.005     123.36
#    RJF    BUY        MOO           172            172               0       30390.68            12.16                0.002     176.69
#    TXT    BUY        MOO           201            201               0       16745.31             6.70                0.005      83.31
#   IBKR   SELL        MOO           167           -167               0       16187.68            -6.48                0.004      96.93
#      V   SELL        MOO            40            -40               0       15356.00            -6.14                0.000     383.90
#   ACGL   SELL        MOO           151           -151               0       15208.72            -6.08                0.003     100.72
#   NTRS    BUY        MOO            75             75               0       14074.50             5.63                0.001     187.66
#   CDNS   SELL        MOO            38            -38               0       12717.84            -5.09                0.000     334.68
#    EXR    BUY        MOO            86             86               0       12391.74             4.96                0.001     144.09
#    HIG   SELL        MOO            88            -88               0       12253.93            -4.90                0.001     139.25
#    ADI   SELL        MOO            33            -33               0       12232.13            -4.89                0.000     370.67
#    PSA   SELL        MOO            34            -34               0       10790.58            -4.32                0.000     317.37
#   NXPI    BUY        MOO            30             30               0        6694.50             2.68                0.000     223.15
#    LUV   SELL        MOO           152           -152               0        6153.02            -2.46                0.007      40.48
#   INTC    BUY        MOO            44             44               0        3882.56             1.55                0.001      88.24
#
# [Export Engine] Saving artifacts to: 'results/10/'
