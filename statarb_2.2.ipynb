# %%
# ==============================================================================
# S&P 500 STAT-ARB PIPELINE: TENSOR-DAG PARAMETRIC ARCHITECTURE (FULL OPTIMIZER FIX)
# ==============================================================================
import os
import gc
import pickle
import warnings
from typing import Dict, List, Tuple, Optional
from collections import deque
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint
from scipy.optimize import minimize as scipy_minimize
import vectorbt as vbt
from joblib import Parallel, delayed

warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 250)
from datetime import datetime

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
model_id = "model_A_tensor_dag_fixed"

# ==============================================================================
# 1. INSTITUTIONAL PARAMETER CONFIGURATION
# ==============================================================================
run_params = {
    "price_csv": "data/universe_daily_train.csv",
    "oos_price_csv": "data/universe_daily_val.csv",
    "constituents_path": "data/constituents.csv",
    "state_persistence_file": f"artifacts/{model_id}/stat_arb_state_{timestamp}.pkl",

    "lookback_days": 504,             
    "min_history_days": 100,          
    "weight_drift_threshold": 0.05,     
    "screening_freq_days": 20,          
    "quarantine_days": 42,             
    
    "kalman_delta": 1e-4,              
    "kalman_obs_noise": 1e-3,          
    "max_hurst_exponent": 0.45,        
    
    "min_correlation": 0.40,           
    "p_value_threshold": 0.20,         
    
    "min_half_life": 2.0,             
    "max_half_life": 45.0,            
    "tau_hl_penalty": 5.0,             
    
    "exit_z_spread": 0.50,             
    "stop_loss_z": 3.00,               
    
    "promote_top_n": 30,               
    "ghost_truncation_quantile": 0.50, 
    
    # SLSQP RISK & NEUTRALITY BOUNDS
    "max_net_dollar_exposure": 0.03,   # Strict 3% net dollar limit
    "max_net_beta_exposure": 0.02,     # Strict 2% net market beta limit
    "max_sector_exposure": 0.08,       # Strict 8% net sector limit
    "max_single_stock_gross": 0.15,    # Hard cap on leg overlap across pairs (15%)
    "max_gross_exposure": 1.80,        
    "max_sleeve_weight": 0.25,        

    "max_adv_participation": 0.015,    
    "initial_capital": 250_000.0,
    "exec_fee": 0.00015,              
    "borrow_bps": 50.0
}

# ==============================================================================
# 2. STATE PERSISTENCE ENGINE
# ==============================================================================
class StatePersistenceEngine:
    @staticmethod
    def save_checkpoint(filepath: str, state_dict: dict):
        try:
            os.makedirs(os.path.dirname(filepath), exist_ok=True)
            with open(filepath, "wb") as f:
                pickle.dump(state_dict, f)
        except Exception:
            pass

    @staticmethod
    def load_checkpoint(filepath: str) -> Optional[dict]:
        if not os.path.exists(filepath): return None
        try:
            with open(filepath, "rb") as f:
                return pickle.load(f)
        except Exception:
            return None

# ==============================================================================
# 3. VECTORIZED MATH KERNELS
# ==============================================================================
def get_rolling_half_life(spread: pd.Series, window: int = 126) -> pd.Series:
    """Vectorized OLS Half-Life using rolling covariance."""
    s_lag = spread.shift(1)
    s_diff = spread.diff()
    var_x = s_lag.rolling(window).var()
    cov_xy = s_lag.rolling(window).cov(s_diff)
    gamma = cov_xy / np.maximum(var_x, 1e-8)
    gamma = np.clip(gamma, -0.9999, -1e-5)
    hl = -np.log(2.0) / np.log(1.0 + gamma)
    return hl

def get_rolling_hurst(spread: pd.Series, window: int = 126, max_lag: int = 20) -> pd.Series:
    """Vectorized Hurst Exponent."""
    lags = np.arange(2, max_lag)
    log_lags = np.log(lags)
    
    tau_dict = {}
    for lag in lags:
        tau_dict[lag] = spread.diff(lag).rolling(window).std()
    tau_df = pd.DataFrame(tau_dict)
    
    log_tau = np.log(np.maximum(tau_df, 1e-8))
    mean_x = np.mean(log_lags)
    var_x = np.var(log_lags)
    
    mean_y = log_tau.mean(axis=1)
    cov_xy = ((log_tau.subtract(mean_y, axis=0)) * (log_lags - mean_x)).mean(axis=1)
    
    slope = cov_xy / var_x
    return slope * 2.0

def batch_kalman_filter_numpy(y: np.ndarray, x: np.ndarray, delta: float, obs_noise: float):
    """Native Python Kalman execution."""
    N = len(y)
    betas = np.zeros(N)
    innovations = np.zeros(N)
    F_arr = np.zeros(N)
    
    state_mean = np.zeros(2)
    state_cov = np.eye(2)
    Q = (delta / (1.0 - delta)) * np.eye(2)
    
    for t in range(N):
        H = np.array([1.0, x[t]])
        pred_cov = state_cov + Q
        v = y[t] - np.dot(H, state_mean)
        F = np.dot(H, np.dot(pred_cov, H)) + obs_noise
        K = np.dot(pred_cov, H) / F
        
        state_mean = state_mean + K * v
        state_cov = pred_cov - np.outer(K, np.dot(H, pred_cov))
        
        betas[t] = state_mean[1]
        innovations[t] = v
        F_arr[t] = F
        
    return betas, innovations, F_arr

# ==============================================================================
# 4. THE "ALPHA CUBE" PRE-COMPUTE WORKER
# ==============================================================================
def process_pair_history(t1: str, t2: str, price_s1: pd.Series, price_s2: pd.Series, params: dict):
    """Generates the full timeline of statistical signals and true economic returns for a pair."""
    y = np.log(price_s1.values)
    x = np.log(price_s2.values)
    
    betas, innovations, F_arr = batch_kalman_filter_numpy(
        y, x, delta=params['kalman_delta'], obs_noise=params['kalman_obs_noise']
    )
    
    # FIX 1: Direct smoothed variance with strict floor (10 bps min vol)
    F_series = pd.Series(F_arr, index=price_s1.index).rolling(21, min_periods=5).mean().bfill().values
    spread_vol = np.sqrt(np.maximum(F_series, 1e-4))
    
    # FIX 2: Z-spread bounded to a realistic range [-5.0, 5.0]
    z_spread = np.clip(innovations / spread_vol, -5.0, 5.0)
    
    spread = pd.Series(y - betas * x, index=price_s1.index)
    hl = get_rolling_half_life(spread).fillna(25.0).clip(params['min_half_life'], params['max_half_life'])
    hurst = get_rolling_hurst(spread).fillna(0.50)
    
    # Parametric Alpha Calculation
    exp_yield = np.maximum(0.0, np.abs(z_spread) - params['exit_z_spread']) * spread_vol
    alpha = exp_yield * (252.0 / hl.values) * (1.0 - np.exp(-hl.values / params['tau_hl_penalty']))
    
    # FIX 3: True economic daily return of the beta-hedged pair
    ret_A = price_s1.pct_change().fillna(0.0).values
    ret_B = price_s2.pct_change().fillna(0.0).values
    pair_returns = (ret_A - betas * ret_B) / (1.0 + np.abs(betas))
    
    df = pd.DataFrame({
        'Beta': betas,
        'Z_Spread': z_spread,
        'Spread_Vol': spread_vol,
        'Half_Life': hl.values,
        'Hurst': hurst.values,
        'Parametric_Alpha': alpha,
        'Spread_Return': pair_returns
    }, index=price_s1.index)
    
    return (t1, t2), df

class UniverseScreener:
    def __init__(self, constituents_path: str):
        self.constituents_path = constituents_path

    def get_sectors(self, tickers: List[str]) -> pd.Series:
        if os.path.exists(self.constituents_path):
            const = pd.read_csv(self.constituents_path)
            sym_col = "Symbol" if "Symbol" in const.columns else "Ticker"
            return pd.Series(tickers, index=tickers).map(dict(zip(const[sym_col], const["GICS Sector"]))).fillna("Unknown")
        return pd.Series("Unknown", index=tickers)

# ==============================================================================
# 5. FIXED SLSQP OPTIMIZER (EMPIRICAL COVARIANCE + BETA/OVERLAP NEUTRALITY)
# ==============================================================================
class ConvexPortfolioOptimizer:
    def __init__(self, params: dict):
        self.params = params

    @staticmethod
    def calculate_max_weight_drift(current_sleeve_weights: Dict[Tuple[str, str], float], target_sleeve_weights: Dict[Tuple[str, str], float]) -> float:
        all_keys = set(current_sleeve_weights.keys()).union(target_sleeve_weights.keys())
        if not all_keys: return 0.0
        return float(max([abs(current_sleeve_weights.get(pk, 0.0) - target_sleeve_weights.get(pk, 0.0)) for pk in all_keys]))

    def allocate(self, live_df: pd.DataFrame, sectors: pd.Series, current_weights: dict, alpha_cube: dict, current_idx: int):
        if live_df.empty: return {}, {}, {}

        N = len(live_df)
        pair_keys = [(r["Asset_A"], r["Asset_B"]) for _, r in live_df.iterrows()]
        
        # 1. EMPIRICAL COVARIANCE MATRIX (Replaces diagonal matrix)
        returns_list = []
        for pk in pair_keys:
            s_ret = alpha_cube[pk]["Spread_Return"].iloc[max(0, current_idx-63):current_idx].values
            if len(s_ret) < 63:
                s_ret = np.pad(s_ret, (63 - len(s_ret), 0), 'constant')
            returns_list.append(s_ret)
            
        returns_mat = np.column_stack(returns_list)
        cov_matrix = np.cov(returns_mat, rowvar=False) * 252.0
        if N == 1: cov_matrix = np.array([[cov_matrix]])
        cov_matrix += np.eye(N) * 1e-5 # Ridge stability

        pair_betas, pair_zs = live_df["Beta"].values, live_df["Z_Spread"].values
        alphas = live_df["Parametric_Alpha"].values

        w_prev = np.array([current_weights.get(pk, 0.0) for pk in pair_keys])
        turnover_bps = (self.params["exec_fee"] * 2.0) + 0.0005 

        # Net Dollar and Beta Contribution
        dollar_mults = np.where(pair_zs > 0, pair_betas - 1.0, 1.0 - pair_betas)
        beta_mults = np.where(pair_zs > 0, -1.0 + pair_betas, 1.0 - pair_betas)

        pair_secs = np.array([sectors.get(live_df.iloc[i]["Asset_A"], "Unknown") for i in range(N)])
        unique_secs = np.unique(pair_secs)

        def objective(w):
            risk = np.dot(w.T, np.dot(cov_matrix, w))
            turnover = np.sum(np.abs(w - w_prev)) * turnover_bps
            return risk + turnover

        target_gross = min(self.params["max_gross_exposure"], N * self.params["max_sleeve_weight"])
        min_gross = max(1.0, target_gross * 0.5) 
        
        max_net_dollar = self.params["max_net_dollar_exposure"]
        max_net_beta = self.params["max_net_beta_exposure"]
        max_sec = self.params["max_sector_exposure"]
        
        # 2. STRICT CONSTRAINTS (INEQUALITY UN-CORNERED)
        constraints = [
            {'type': 'ineq', 'fun': lambda w: target_gross - np.sum(w)}, 
            {'type': 'ineq', 'fun': lambda w: np.sum(w) - min_gross},    
            {'type': 'ineq', 'fun': lambda w: max_net_dollar - np.abs(np.sum(w * dollar_mults))},
            {'type': 'ineq', 'fun': lambda w: max_net_beta - np.abs(np.sum(w * beta_mults))}
        ]
        
        # Sector Net Constraints
        for s in unique_secs:
            constraints.append({'type': 'ineq', 'fun': lambda w, sec=s: max_sec - np.abs(np.sum(w[pair_secs == sec] * dollar_mults[pair_secs == sec]))})

        # 3. SINGLE STOCK OVERLAP CAP CONSTRAINTS
        all_assets = list(set(live_df["Asset_A"]).union(live_df["Asset_B"]))
        for asset in all_assets:
            asset_mask = np.zeros(N)
            for i, r in live_df.iterrows():
                idx_pos = live_df.index.get_loc(i)
                if r["Asset_A"] == asset:
                    asset_mask[idx_pos] += 1.0
                if r["Asset_B"] == asset:
                    asset_mask[idx_pos] += abs(r["Beta"])
            constraints.append({'type': 'ineq', 'fun': lambda w, mask=asset_mask: self.params["max_single_stock_gross"] - np.sum(w * mask)})

        base_cap = self.params["max_sleeve_weight"]
        alpha_median = max(float(np.median(alphas)), 1e-6)
        bounds = [(0.0, base_cap * np.clip(float(alphas[i]) / alpha_median, 0.20, 1.00)) for i in range(N)]
        
        spread_vols = live_df["Spread_Vol"].values
        init_w = (1.0 / np.maximum(spread_vols, 1e-4))
        init_w = np.minimum((init_w / np.sum(init_w)) * target_gross, [b[1] for b in bounds])

        res = scipy_minimize(objective, init_w, method='SLSQP', bounds=bounds, constraints=constraints)
        best_w = res.x if res.success else init_w
        best_w[best_w < 0.01] = 0.0

        allocs, memory = {}, {}
        for i, pk in enumerate(pair_keys):
            if best_w[i] > 0:
                row = live_df.iloc[i]
                w_a = -best_w[i] if row["Z_Spread"] > 0 else best_w[i]
                w_b = best_w[i] * row["Beta"] if row["Z_Spread"] > 0 else -best_w[i] * row["Beta"]
                allocs[pk] = {row["Asset_A"]: w_a, row["Asset_B"]: w_b, "Sleeve_Weight": best_w[i]}
                memory[pk] = {
                    "Beta": row["Beta"], "Entry_Z": row["Entry_Z"] if row["Is_Active"] else row["Z_Spread"],
                    "Parametric_Alpha": row["Parametric_Alpha"], 
                    "Days_Held": row.get("Days_Held", 0)
                }

        metrics = {"Portfolio_Variance": np.dot(best_w.T, np.dot(cov_matrix, best_w)), "Turnover_Cost": np.sum(np.abs(best_w - w_prev)) * turnover_bps, "Effective_Gross": np.sum(best_w)}
        return allocs, memory, metrics

# ==============================================================================
# 6. BACKTEST ENGINES & DIAGNOSTICS
# ==============================================================================
class CommitteeTearsheetEngine:
    def __init__(self, params: dict):
        self.initial_capital = params.get("initial_capital", 250_000.0)
        self.exec_fee = params.get("exec_fee", 0.00015)
        self.daily_borrow_rate = (params.get("borrow_bps", 50.0) / 10000.0) / 252.0

    def generate_tearsheets(self, prices_df: pd.DataFrame, pair_weight_matrices: Dict[Tuple[str, str], pd.DataFrame]) -> pd.DataFrame:
        results = []
        for pair_key, w_df in pair_weight_matrices.items():
            a, b = pair_key
            active_dates = w_df.dropna(how='all').index
            if len(active_dates) == 0: continue
            start_date = active_dates[0]
            p_oos = prices_df[[a, b]].loc[start_date:]
            w_target = w_df.loc[start_date:].copy()
            w_target.iloc[-1] = 0.0 
            
            pf_gross = vbt.Portfolio.from_orders(
                close=p_oos, size=w_target, size_type='targetpercent',
                group_by=True, cash_sharing=True, init_cash=self.initial_capital, fees=self.exec_fee
            )
            asset_values = pf_gross.asset_value(group_by=False)
            short_exposure = asset_values.where(asset_values < 0, 0).abs()
            daily_short_cost = short_exposure.sum(axis=1) * self.daily_borrow_rate
            net_val = pf_gross.value() - daily_short_cost.cumsum()
            net_ret = net_val.pct_change().fillna(0)
            
            tot_ret = (net_val.iloc[-1] / self.initial_capital) - 1.0
            mean_ret, std_ret = net_ret.mean(), net_ret.std()
            down_std = np.sqrt((net_ret[net_ret < 0] ** 2).mean())
            sharpe = (mean_ret / std_ret) * np.sqrt(252) if std_ret > 0 else 0.0
            sortino = (mean_ret / down_std) * np.sqrt(252) if down_std > 0 else 0.0
            max_dd = (1 - net_val / net_val.cummax()).max() if not net_val.empty else 0.0
            trades = pf_gross.trades.count()
            win_rate = (pf_gross.trades.winning.count() / trades) if trades > 0 else 0.0
            
            results.append({
                "Pair_Legs": f"{a} / {b}", "Total_Return_[%]": tot_ret * 100,
                "Sharpe_Ratio": sharpe, "Sortino_Ratio": sortino,
                "Max_DD_[%]": max_dd * 100, "Win_Rate_[%]": win_rate * 100, "Total_Trades": trades
            })
            del pf_gross
            gc.collect()

        if not results: return pd.DataFrame()
        return pd.DataFrame(results).sort_values("Sharpe_Ratio", ascending=False).reset_index(drop=True)

class VectorbtBacktestEngine:
    def __init__(self, params: dict):
        self.initial_capital = params.get("initial_capital", 250_000.0)
        self.exec_fee = params.get("exec_fee", 0.00015)
        self.daily_borrow_rate = (params.get("borrow_bps", 50.0) / 10000.0) / 252.0

    def run_backtest(self, close_prices_df: pd.DataFrame, open_prices_df: pd.DataFrame, weights_df: pd.DataFrame) -> Tuple[vbt.Portfolio, pd.Series, pd.Series]:
        tradable_assets = weights_df.columns.intersection(close_prices_df.columns)
        p_close_oos, p_open_oos = close_prices_df[tradable_assets].ffill(), open_prices_df[tradable_assets].ffill()
        sparse_weights = weights_df[tradable_assets]

        pf_gross = vbt.Portfolio.from_orders(
            close=p_close_oos, price=p_open_oos, size=sparse_weights, size_type='targetpercent',
            group_by=True, cash_sharing=True, init_cash=self.initial_capital, fees=self.exec_fee
        )
        
        asset_values = pf_gross.asset_value(group_by=False)
        short_exposure = asset_values.where(asset_values < 0, 0).abs()
        daily_short_cost = short_exposure.sum(axis=1) * self.daily_borrow_rate
        net_portfolio_value = pf_gross.value() - daily_short_cost.cumsum()
        
        total_abs_asset_val = asset_values.abs().sum(axis=1)
        true_gross_exposure = (total_abs_asset_val / net_portfolio_value.replace(0.0, np.nan)).fillna(0.0)
        return pf_gross, net_portfolio_value, true_gross_exposure

class MarketNeutralityDiagnosticEngine:
    def __init__(self, max_beta: float = 0.03, max_r2: float = 0.01):
        self.max_beta, self.max_r2 = max_beta, max_r2

    def analyze(self, strategy_returns: pd.Series, benchmark_returns: pd.Series) -> Tuple[pd.DataFrame, dict]:
        aligned_df = pd.concat([strategy_returns, benchmark_returns], axis=1).dropna()
        aligned_df.columns = ["Strategy", "Benchmark"]
        r_p, r_m = aligned_df["Strategy"], aligned_df["Benchmark"]
        
        capm_model = sm.OLS(r_p, sm.add_constant(r_m)).fit()
        alpha_ann = capm_model.params.get("const", 0.0) * 252.0
        beta_m = capm_model.params.get("Benchmark", 0.0)
        p_val_beta = capm_model.pvalues.get("Benchmark", 1.0)
        t_stat_beta = capm_model.tvalues.get("Benchmark", 0.0)
        r2_capm = capm_model.rsquared

        bull_mask, bear_mask = r_m > 0, r_m < 0
        beta_bull = sm.OLS(r_p[bull_mask], sm.add_constant(r_m[bull_mask])).fit().params.get("Benchmark", 0.0) if bull_mask.sum() > 10 else 0.0
        beta_bear = sm.OLS(r_p[bear_mask], sm.add_constant(r_m[bear_mask])).fit().params.get("Benchmark", 0.0) if bear_mask.sum() > 10 else 0.0

        metrics = [
            {"Metric": "Annualized Alpha", "Value": f"{alpha_ann:.2%}", "Threshold": "N/A", "Status": "INFO"},
            {"Metric": "Market Beta (β_m)", "Value": f"{beta_m:.4f}", "Threshold": f"< |{self.max_beta}|", "Status": "PASS" if abs(beta_m) <= self.max_beta else "FAIL"},
            {"Metric": "Beta p-value", "Value": f"{p_val_beta:.4f}", "Threshold": ">= 0.05", "Status": "PASS" if p_val_beta >= 0.05 else "FAIL"},
            {"Metric": "Beta t-statistic", "Value": f"{t_stat_beta:.4f}", "Threshold": "< |1.96|", "Status": "PASS" if abs(t_stat_beta) < 1.96 else "FAIL"},
            {"Metric": "Variance Explained (R²)", "Value": f"{r2_capm:.2%}", "Threshold": f"< {self.max_r2:.1%}", "Status": "PASS" if r2_capm <= self.max_r2 else "FAIL"},
            {"Metric": "Bull Market Beta (R_m > 0)", "Value": f"{beta_bull:.4f}", "Threshold": f"< |{self.max_beta}|", "Status": "PASS" if abs(beta_bull) <= self.max_beta else "FAIL"},
            {"Metric": "Bear Market Beta (R_m < 0)", "Value": f"{beta_bear:.4f}", "Threshold": f"< |{self.max_beta}|", "Status": "PASS" if abs(beta_bear) <= self.max_beta else "FAIL"}
        ]
        metrics_df = pd.DataFrame(metrics)
        all_passed = (metrics_df["Status"] != "FAIL").all()
        verdict = {"Market_Neutral": "TRUE" if all_passed else "FALSE", "Core_Failure_Reason": "None" if all_passed else ", ".join(metrics_df[metrics_df["Status"] == "FAIL"]["Metric"].tolist())}
        return metrics_df, verdict

class LiveMOOOrderGenerator:
    def __init__(self, min_order_usd: float = 250.0, max_adv_part: float = 0.015, round_lots: bool = False):
        self.min_order_usd, self.max_adv_part, self.round_lots = min_order_usd, max_adv_part, round_lots

    def generate_blotter(self, target_weights: pd.Series, current_positions: Dict[str, int], latest_prices: pd.Series, rolling_adv_shares: pd.Series, portfolio_nav: float) -> pd.DataFrame:
        blotter = []
        all_tickers = set(target_weights.index).union(current_positions.keys())
        for ticker in all_tickers:
            t_weight, price, adv_shares = float(target_weights.get(ticker, 0.0)), float(latest_prices.get(ticker, np.nan)), float(rolling_adv_shares.get(ticker, 1_000_000.0))
            if np.isnan(price) or price <= 0: continue

            curr_shares = int(current_positions.get(ticker, 0))
            raw_target_shares = int((t_weight * portfolio_nav) / price)
            max_allowed_delta = int(adv_shares * self.max_adv_part)
            desired_delta = raw_target_shares - curr_shares
            
            target_shares = curr_shares + (max_allowed_delta if desired_delta > max_allowed_delta else (-max_allowed_delta if desired_delta < -max_allowed_delta else desired_delta))
            if self.round_lots: target_shares = (target_shares // 100) * 100

            delta_shares = target_shares - curr_shares
            delta_value = delta_shares * price

            if abs(delta_value) < self.min_order_usd and target_shares != 0: continue

            if delta_shares != 0:
                blotter.append({
                    "Ticker": ticker, "Action": "BUY" if delta_shares > 0 else "SELL", "Order_Type": "MOO",
                    "Delta_Shares": abs(delta_shares), "Target_Shares": target_shares, "Current_Shares": curr_shares,
                    "Est_Order_USD": round(abs(delta_value), 2), "Target_Weight_%": round((target_shares * price / portfolio_nav) * 100, 2),
                    "ADV_Participation_%": round((abs(delta_shares) / max(1.0, adv_shares)) * 100, 3), "Price_Ref": round(price, 2)
                })

        df_blotter = pd.DataFrame(blotter)
        if df_blotter.empty: return pd.DataFrame(columns=["Ticker", "Action", "Order_Type", "Delta_Shares", "Target_Shares", "Current_Shares", "Est_Order_USD", "Target_Weight_%", "ADV_Participation_%", "Price_Ref"])
        return df_blotter.sort_values("Est_Order_USD", ascending=False).reset_index(drop=True)

# ==============================================================================
# 7. UNIFIED 2-STAGE ORCHESTRATOR
# ==============================================================================
def run_unified_pipeline(params: dict):
    print("=" * 85, flush=True)
    print("STARTING ROBUST 2-STAGE STAT-ARB ENGINE (TENSOR-DAG PARAMETRIC SLSQP)", flush=True)
    print("=" * 85, flush=True)
    
    try:
        prices_train = pd.read_csv(params["price_csv"], index_col=0, parse_dates=True)
        prices_val = pd.read_csv(params["oos_price_csv"], index_col=0, parse_dates=True)
        prices_full = pd.concat([prices_train, prices_val]).dropna(axis=1, how="all").ffill()
    except Exception:
        prices_train = pd.read_csv(params["price_csv"], index_col=0, parse_dates=True)
        prices_full = prices_train.ffill()

    prices_full = prices_full[~prices_full.index.duplicated()].sort_index()

    try:
        open_train = pd.read_csv(params["price_csv"].replace("close", "open"), index_col=0, parse_dates=True)
        open_val = pd.read_csv(params["oos_price_csv"].replace("close", "open"), index_col=0, parse_dates=True)
        open_full = pd.concat([open_train, open_val]).dropna(axis=1, how="all").ffill()
        open_full = open_full[~open_full.index.duplicated(keep='first')].sort_index()
    except FileNotFoundError:
        open_full = prices_full.copy()

    screener = UniverseScreener(params["constituents_path"])
    sectors = screener.get_sectors(prices_full.columns.tolist())
    market_ret = prices_full.pct_change().mean(axis=1)
    
    # ---------------------------------------------------------
    # PHASE A: THE TENSOR DAG PRE-COMPUTE
    # ---------------------------------------------------------
    print("[DAG Pre-Compute] Initializing Vectorized Matrix Space...", flush=True)
    dag_df = prices_full.ffill().dropna(axis=1)
    valid_tickers = list(dag_df.columns)
    if len(valid_tickers) < 2:
        raise ValueError("DAG pre-compute requires at least 2 tickers with full price history")
    log_prices = np.log(dag_df.values)
    corr_matrix = np.corrcoef(np.diff(log_prices, axis=0), rowvar=False)
    
    sector_arr = sectors.reindex(valid_tickers).values
    sec_match = sector_arr[:, None] == sector_arr[None, :]
    mask = np.triu(sec_match & (corr_matrix >= params["min_correlation"]), k=1)
    
    candidate_pairs = [(valid_tickers[i], valid_tickers[j]) for i, j in zip(*np.where(mask))]
    print(f"[DAG Pre-Compute] Processing {len(candidate_pairs)} Sector-Matched Correlated Pairs across {len(prices_full)} days...", flush=True)
    
    with Parallel(n_jobs=-1, backend="loky") as parallel:
        results = parallel(delayed(process_pair_history)(t1, t2, prices_full[t1], prices_full[t2], params) for t1, t2 in candidate_pairs)
    
    alpha_cube = {pair: df for pair, df in results}
    print("[DAG Pre-Compute] Completed successfully. Executing Portfolio Routing Loop.", flush=True)
    
    # ---------------------------------------------------------
    # PHASE B: ROUTING LOOP (MILLISECOND EXECUTION)
    # ---------------------------------------------------------
    engine_alloc = ConvexPortfolioOptimizer(params)
    
    state = StatePersistenceEngine.load_checkpoint(params["state_persistence_file"]) or {}
    active_pairs, cooldown_tracker = state.get("active_pairs", {}), state.get("cooldown_tracker", {})
    
    start_idx = min(params["lookback_days"], len(prices_train))
    total_steps = len(prices_full) - start_idx

    master_weights = pd.DataFrame(np.nan, index=prices_full.index, columns=prices_full.columns, dtype=np.float64)
    ghost_weights = pd.DataFrame(np.nan, index=prices_full.index, columns=prices_full.columns, dtype=np.float64)
    promoted_weights = pd.DataFrame(np.nan, index=prices_full.index, columns=prices_full.columns, dtype=np.float64)
    
    pair_weight_matrices, current_sleeve_weights, target_sleeve_weights = {}, {}, {}
    metrics_history, cached_keys = [], []
    days_since_screening = 0

    for i in range(start_idx, len(prices_full)):
        current_date = prices_full.index[i]
        step_num = i - start_idx + 1
        progress_pct = (step_num / total_steps) * 100.0

        has_exit = False
        for p in list(active_pairs.keys()):
            mem = active_pairs[p]
            current_state = alpha_cube[p].iloc[i]
            
            e_t = current_state["Z_Spread"]
            mem.update({"Days_Held": mem["Days_Held"] + 1})

            if abs(e_t) <= params["exit_z_spread"] or abs(e_t) >= params["stop_loss_z"] or mem["Days_Held"] > (current_state["Half_Life"] * 2.5):
                has_exit = True
                master_weights.loc[current_date, p[0]], master_weights.loc[current_date, p[1]] = 0.0, 0.0
                if p in pair_weight_matrices:
                    pair_weight_matrices[p].loc[current_date, p[0]] = 0.0
                    pair_weight_matrices[p].loc[current_date, p[1]] = 0.0

                if abs(e_t) >= params["stop_loss_z"]: cooldown_tracker[p] = params["quarantine_days"]
                del active_pairs[p]
                if p in current_sleeve_weights: del current_sleeve_weights[p]

        for p in list(cooldown_tracker.keys()):
            cooldown_tracker[p] -= 1
            if cooldown_tracker[p] <= 0: del cooldown_tracker[p]

        if days_since_screening >= params["screening_freq_days"] or not cached_keys:
            lb_prices = prices_full.iloc[i - params["lookback_days"] : i]
            def _check_coint(t1, t2):
                p1, p2 = lb_prices[t1].values, lb_prices[t2].values
                if coint(p1, p2)[1] <= params["p_value_threshold"]: return (t1, t2)
                return None
            cached_keys = [res for res in [_check_coint(p[0], p[1]) for p in candidate_pairs] if res is not None]
            days_since_screening = 0
        days_since_screening += 1

        ghost_records = []
        for p in list(active_pairs.keys()) + [k for k in cached_keys if k not in active_pairs and k not in cooldown_tracker]:
            if p not in alpha_cube: continue
            state_t = alpha_cube[p].iloc[i]
            if state_t.isna().any(): continue
            
            is_active = p in active_pairs
            if not is_active and state_t["Hurst"] >= params["max_hurst_exponent"]: continue
            if not is_active and state_t["Half_Life"] == params["max_half_life"]: continue
            
            rec = {
                "Asset_A": p[0], "Asset_B": p[1], "Beta": state_t["Beta"], 
                "Half_Life_Days": state_t["Half_Life"], "Z_Spread": state_t["Z_Spread"],
                "Parametric_Alpha": state_t["Parametric_Alpha"], "Spread_Vol": state_t["Spread_Vol"], 
                "Days_Held": active_pairs[p]["Days_Held"] if is_active else 0,
                "Is_Active": is_active, "Entry_Z": active_pairs[p]["Entry_Z"] if is_active else state_t["Z_Spread"]
            }
            ghost_records.append(rec)
            
        ghost_df = pd.DataFrame(ghost_records)

        promoted_ghosts = pd.DataFrame()
        if not ghost_df.empty:
            ghost_pool = ghost_df[~ghost_df["Is_Active"]]
            
            if not ghost_pool.empty:
                min_score = max(1e-6, ghost_pool["Parametric_Alpha"].quantile(params["ghost_truncation_quantile"]))
                promoted_ghosts = ghost_pool[ghost_pool["Parametric_Alpha"] >= min_score]
                promoted_ghosts = promoted_ghosts.sort_values("Parametric_Alpha", ascending=False).head(params["promote_top_n"])

            if len(ghost_pool) > 0:
                g_alloc = 1.0 / len(ghost_pool)
                for _, r in ghost_pool.iterrows():
                    ghost_weights.loc[current_date, r["Asset_A"]] = -g_alloc if r["Z_Spread"] > 0 else g_alloc
                    ghost_weights.loc[current_date, r["Asset_B"]] = g_alloc * r["Beta"] if r["Z_Spread"] > 0 else -g_alloc * r["Beta"]
            
            if len(promoted_ghosts) > 0:
                p_alloc = 1.0 / len(promoted_ghosts)
                for _, r in promoted_ghosts.iterrows():
                    promoted_weights.loc[current_date, r["Asset_A"]] = -p_alloc if r["Z_Spread"] > 0 else p_alloc
                    promoted_weights.loc[current_date, r["Asset_B"]] = p_alloc * r["Beta"] if r["Z_Spread"] > 0 else -p_alloc * r["Beta"]

        current_max_drift = ConvexPortfolioOptimizer.calculate_max_weight_drift(current_sleeve_weights, target_sleeve_weights)
        has_drift_trigger = current_max_drift >= params["weight_drift_threshold"]
        is_initial_day = (i == start_idx)

        should_rebalance = has_exit or len(promoted_ghosts) > 0 or has_drift_trigger or is_initial_day

        if should_rebalance:
            trigger_cause = (
                "INITIAL_ENTRY" if is_initial_day else
                ("SIGNAL_EXIT" if has_exit else
                ("SIGNAL_ENTRY" if not promoted_ghosts.empty else f"WEIGHT_DRIFT ({current_max_drift:.1%})"))
            )

            print(f"\n[Dynamic Rebalance @ {current_date.date()} | Progress: {progress_pct:5.1f}% ({step_num}/{total_steps})] Cause: {trigger_cause}", flush=True)
            
            if ghost_df.empty:
                print(f"  --> Pipeline Funnel : Ghost=0 | Promoted=0 | Live={len(active_pairs)}", flush=True)
                metrics_history.append({"Date": current_date, "Ghost_Size": 0, "Promoted_Size": 0, "Live_Size": len(active_pairs), "Opt_Exp_Variance": 0.0, "Effective_Gross": 0.0, "Mean_Innovation_Z": 0.0, "Mean_Parametric_Alpha": 0.0, "rebalanced": 1})
                continue

            live_candidates = ghost_df[ghost_df["Is_Active"]]
            live_df = pd.concat([live_candidates, promoted_ghosts]).drop_duplicates(subset=["Asset_A", "Asset_B"])
            
            # OPTIMIZER CALL passing the full Alpha Cube for Empirical Covariance Matrix construction
            allocs, active_pairs_updates, opt = engine_alloc.allocate(live_df, sectors, current_sleeve_weights, alpha_cube, i)
            
            dropped = set(active_pairs.keys()) - set(allocs.keys())
            for p in dropped:
                master_weights.loc[current_date, p[0]], master_weights.loc[current_date, p[1]] = 0.0, 0.0
                if p in pair_weight_matrices:
                    pair_weight_matrices[p].loc[current_date, p[0]] = 0.0
                    pair_weight_matrices[p].loc[current_date, p[1]] = 0.0
                cooldown_tracker[p] = params["quarantine_days"]

            active_pairs = active_pairs_updates
            current_sleeve_weights = {p: w["Sleeve_Weight"] for p, w in allocs.items()}
            target_sleeve_weights = current_sleeve_weights.copy()

            for p, w in allocs.items():
                if p not in pair_weight_matrices: pair_weight_matrices[p] = pd.DataFrame(np.nan, index=prices_full.index, columns=[p[0], p[1]])
                pair_weight_matrices[p].loc[current_date, p[0]] = w[p[0]]
                pair_weight_matrices[p].loc[current_date, p[1]] = w[p[1]]
                prev_w0 = 0.0 if pd.isna(master_weights.at[current_date, p[0]]) else master_weights.at[current_date, p[0]]
                prev_w1 = 0.0 if pd.isna(master_weights.at[current_date, p[1]]) else master_weights.at[current_date, p[1]]
                master_weights.loc[current_date, p[0]] = prev_w0 + w[p[0]]
                master_weights.loc[current_date, p[1]] = prev_w1 + w[p[1]]

            avg_inno_z = np.mean([abs(mem['Entry_Z']) for mem in active_pairs.values()]) if active_pairs else 0.0
            avg_alpha = live_df["Parametric_Alpha"].mean() if not live_df.empty else 0.0
            
            metrics_history.append({"Date": current_date, "Ghost_Size": len(ghost_pool) if 'ghost_pool' in locals() else 0, "Promoted_Size": len(promoted_ghosts), "Live_Size": len(active_pairs), "Opt_Exp_Variance": opt.get("Portfolio_Variance", 0.0), "Effective_Gross": opt.get("Effective_Gross", 0.0), "Mean_Innovation_Z": avg_inno_z, "Mean_Parametric_Alpha": avg_alpha, "rebalanced": 1})

            print(f"  --> Pipeline Funnel : Ghost={len(ghost_pool) if 'ghost_pool' in locals() else 0} | Promoted={len(promoted_ghosts)} | Live={len(active_pairs)}", flush=True)
            if active_pairs:
                print(f"  --> SLSQP Metrics   : Eff Gross={opt.get('Effective_Gross', 0):.2f} | Port Vol={np.sqrt(max(0, opt.get('Portfolio_Variance', 0))):.4f} | Turnover Drag={opt.get('Turnover_Cost', 0):.6f}", flush=True)
                print(f"  --> Top Allocations :", flush=True)
                sorted_allocs = sorted(active_pairs.keys(), key=lambda x: abs(allocs[x]['Sleeve_Weight']), reverse=True)[:3]
                for p in sorted_allocs:
                    w_data = allocs[p]
                    mem = active_pairs[p]
                    print(f"      {p[0]}/{p[1]} | W_A: {w_data[p[0]]:.1%} | W_B: {w_data[p[1]]:.1%} | Inno Z: {mem['Entry_Z']:.2f} | Parametric Alpha: {mem['Parametric_Alpha']:.4f}", flush=True)
            print("-" * 60, flush=True)

            StatePersistenceEngine.save_checkpoint(params["state_persistence_file"], {
                "active_pairs": active_pairs,
                "cooldown_tracker": cooldown_tracker
            })

    # ==============================================================================
    # EXHAUSTIVE BACKTEST & FUNNEL ATTRIBUTION LOGIC
    # ==============================================================================
    cap = params["max_gross_exposure"]
    for df_w in [master_weights, ghost_weights, promoted_weights]:
        abs_sum = df_w.abs().sum(axis=1)
        exceed_mask = abs_sum > cap
        if exceed_mask.any(): 
            df_w.loc[exceed_mask] = df_w.loc[exceed_mask].div(abs_sum[exceed_mask], axis=0) * cap

    exec_weights = master_weights.shift(1).iloc[start_idx:]
    exec_ghost_weights = ghost_weights.shift(1).iloc[start_idx:]
    exec_promoted_weights = promoted_weights.shift(1).iloc[start_idx:]

    for p in pair_weight_matrices: 
        pair_weight_matrices[p] = pair_weight_matrices[p].ffill().fillna(0.0).shift(1)

    rebalance_metrics_df = pd.DataFrame(metrics_history).set_index("Date")

    exec_close_prices = prices_full.iloc[start_idx:]
    exec_open_prices = open_full.iloc[start_idx:]

    metrics_df = pd.DataFrame(index=exec_close_prices.index)
    metrics_df = metrics_df.join(rebalance_metrics_df, how="left")
    metrics_df["rebalanced"] = metrics_df["rebalanced"].fillna(0).astype(int)

    ffill_cols = ["Ghost_Size", "Promoted_Size", "Live_Size", "Opt_Exp_Variance", "Effective_Gross", "Mean_Innovation_Z", "Mean_Parametric_Alpha"]
    metrics_df[ffill_cols] = metrics_df[ffill_cols].ffill().fillna(0.0)

    global_engine = VectorbtBacktestEngine(params)
    net_portfolio_live, val_live, true_gross_exp_series = global_engine.run_backtest(exec_close_prices, exec_open_prices, exec_weights)
    _, val_ghost, _ = global_engine.run_backtest(exec_close_prices, exec_open_prices, exec_ghost_weights)
    _, val_promoted, _ = global_engine.run_backtest(exec_close_prices, exec_open_prices, exec_promoted_weights)

    ret_live = val_live.pct_change().fillna(0.0)
    ret_ghost = val_ghost.pct_change().fillna(0.0)
    ret_promoted = val_promoted.pct_change().fillna(0.0)

    metrics_df["Live_Realized_Return"] = ret_live
    metrics_df["Ghost_Realized_Return"] = ret_ghost
    metrics_df["Promoted_Realized_Return"] = ret_promoted

    n_days = max(1, len(ret_live))
    ann_factor = 252.0 / n_days

    tot_ret_ghost = (val_ghost.iloc[-1] / params["initial_capital"]) - 1.0
    tot_ret_promoted = (val_promoted.iloc[-1] / params["initial_capital"]) - 1.0
    tot_ret_live = (val_live.iloc[-1] / params["initial_capital"]) - 1.0

    ann_ret_ghost = (((1.0 + tot_ret_ghost) ** ann_factor) - 1.0) * 100.0
    ann_ret_promoted = (((1.0 + tot_ret_promoted) ** ann_factor) - 1.0) * 100.0
    ann_ret_live = (((1.0 + tot_ret_live) ** ann_factor) - 1.0) * 100.0

    sortino_ghost = compute_sortino_ratio(ret_ghost)
    sortino_promoted = compute_sortino_ratio(ret_promoted)
    sortino_live = compute_sortino_ratio(ret_live)

    ret_delta_parametric = ann_ret_promoted - ann_ret_ghost
    ret_delta_optimizer = ann_ret_live - ann_ret_promoted

    sortino_delta_parametric = sortino_promoted - sortino_ghost
    sortino_delta_optimizer = sortino_live - sortino_promoted

    benchmark_returns = market_ret.iloc[start_idx:]
    neutrality_engine = MarketNeutralityDiagnosticEngine(max_beta=0.03, max_r2=0.01)
    neutrality_metrics_df, verdict = neutrality_engine.analyze(strategy_returns=ret_live, benchmark_returns=benchmark_returns)

    tearsheet_engine = CommitteeTearsheetEngine(params)
    committee_report = tearsheet_engine.generate_tearsheets(prices_full, pair_weight_matrices)

    stats_df = net_portfolio_live.stats()
    stats_df["Max Gross Exposure [%]"] = float(true_gross_exp_series.max() * 100.0)

    order_gen = LiveMOOOrderGenerator(min_order_usd=500.0, max_adv_part=params.get("max_adv_participation", 0.015))
    rolling_adv_shares = (prices_full.iloc[-20:].mean() * 50_000).fillna(1_000_000) 
    final_target_weights = master_weights.ffill().fillna(0.0).iloc[-1]
    
    moo_blotter = order_gen.generate_blotter(
        target_weights=final_target_weights,
        current_positions={},
        latest_prices=prices_full.iloc[-1],
        rolling_adv_shares=rolling_adv_shares,
        portfolio_nav=params["initial_capital"]
    )

    summary_data = {
        "stats_df": stats_df,
        "ann_ret_ghost": ann_ret_ghost,
        "sortino_ghost": sortino_ghost,
        "ann_ret_promoted": ann_ret_promoted,
        "sortino_promoted": sortino_promoted,
        "ann_ret_live": ann_ret_live,
        "sortino_live": sortino_live,
        "ret_delta_parametric": ret_delta_parametric,
        "sortino_delta_parametric": sortino_delta_parametric,
        "ret_delta_optimizer": ret_delta_optimizer,
        "sortino_delta_optimizer": sortino_delta_optimizer,
        "verdict": verdict,
        "neutrality_metrics_df": neutrality_metrics_df
    }

    return committee_report, net_portfolio_live, metrics_df, moo_blotter, summary_data

# ==============================================================================
# 8. DIAGNOSTIC TEARSHEET PLOTTER & REPORTING ENGINE
# ==============================================================================
def _get_next_run_dir(base_dir: str = "results") -> str:
    os.makedirs(base_dir, exist_ok=True)
    existing_ids = [int(d) for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d)) and d.isdigit()]
    run_id = max(existing_ids) + 1 if existing_ids else 1
    run_dir = os.path.join(base_dir, str(run_id))
    os.makedirs(run_dir, exist_ok=True)
    return run_dir

def format_independent_axis(ax, rebalance_dates):
    for r_date in rebalance_dates:
        ax.axvline(x=r_date, color="red", linestyle=":", alpha=0.4, linewidth=1.2)
    ax.grid(True, linestyle=":", alpha=0.6)
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
    ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right")

def print_execution_summary(
    metrics_df: pd.DataFrame, 
    stats_df: pd.DataFrame, 
    committee_report: pd.DataFrame, 
    moo_blotter: pd.DataFrame,
    ann_ret_ghost: float, sortino_ghost: float,
    ann_ret_promoted: float, sortino_promoted: float,
    ann_ret_live: float, sortino_live: float,
    ret_delta_parametric: float, sortino_delta_parametric: float,
    ret_delta_optimizer: float, sortino_delta_optimizer: float,
    verdict: dict, neutrality_metrics_df: pd.DataFrame
):
    print("\n" + "=" * 85, flush=True)
    print("FUNNEL CONVERSION ATTRIBUTION & MARGINAL PERFORMANCE REPORT", flush=True)
    print("=" * 85, flush=True)
    print(f"  {'Funnel Tier / Portfolio Stage':<38} | {'Ann. Return [%]':<18} | {'Sortino Ratio':<18}", flush=True)
    print("-" * 85, flush=True)
    print(f"  {'Ghost Portfolio (Raw Universe)':<38} | {ann_ret_ghost:17.2f}% | {sortino_ghost:18.4f}", flush=True)
    print(f"  {'Promoted Portfolio (Parametric Gated)':<38} | {ann_ret_promoted:17.2f}% | {sortino_promoted:18.4f}", flush=True)
    print(f"  {'Live Portfolio (SLSQP Optimized)':<38} | {ann_ret_live:17.2f}% | {sortino_live:18.4f}", flush=True)
    print("-" * 85, flush=True)
    print(f"  {'--> Parametric Selection Delta':<38} | {ret_delta_parametric:+17.2f}% | {sortino_delta_parametric:+18.4f}", flush=True)
    print(f"  {'--> Optimizer Allocation Delta':<38} | {ret_delta_optimizer:+17.2f}% | {sortino_delta_optimizer:+18.4f}", flush=True)
    print("=" * 85, flush=True)

    print("\n" + "=" * 85, flush=True)
    print("QUANTITATIVE MARKET NEUTRALITY & FACTOR DIAGNOSTIC AUDIT", flush=True)
    print("=" * 85, flush=True)
    print(neutrality_metrics_df.to_string(index=False), flush=True)
    print("-" * 85, flush=True)
    print(f"  VERDICT: Market Neutral = {verdict['Market_Neutral']} | Failures: {verdict['Core_Failure_Reason']}", flush=True)
    print("=" * 85, flush=True)

    print("\n" + "=" * 85, flush=True)
    if not committee_report.empty:
        print("INVESTMENT COMMITTEE PAIR REVIEW TEARSHEET", flush=True)
        print("=" * 85, flush=True)
        print(committee_report.to_string(index=False), flush=True)
    else:
        print("INVESTMENT COMMITTEE PAIR REVIEW TEARSHEET: NO TRADES COMPLETED.", flush=True)

    print("\n" + "=" * 85, flush=True)
    print("WALK-FORWARD NET PORTFOLIO STATS (POST-FEES & EXECUTION LAG)", flush=True)
    print("=" * 85, flush=True)
    print(stats_df.to_string(), flush=True)

    print("\n" + "=" * 85, flush=True)
    print("ACTIONABLE MARKET-ON-OPEN (MOO) ORDER BLOTTER FOR NEXT SESSION", flush=True)
    print("=" * 85, flush=True)
    print(moo_blotter.to_string(index=False), flush=True)

def plot_diagnostic_tearsheet(
    metrics_df: pd.DataFrame,
    initial_capital: float = 250_000.0,
    committee_report: Optional[pd.DataFrame] = None,
    net_portfolio: Optional[vbt.Portfolio] = None,
    moo_blotter: Optional[pd.DataFrame] = None,
    save: bool = True,
    prefix: str = "dev_"
):
    if metrics_df.empty: return
    df = metrics_df.copy()
    if not isinstance(df.index, pd.DatetimeIndex): df.index = pd.to_datetime(df.index)
    rebalance_dates = df[df["rebalanced"] == 1].index if "rebalanced" in df.columns else []

    output_dir = None
    if save:
        output_dir = _get_next_run_dir("results")
        print(f"\n[Export Engine] Saving artifacts to: '{output_dir}/'", flush=True)
        metrics_df.to_csv(os.path.join(output_dir, f"{prefix}metrics.csv"))
        if committee_report is not None and not committee_report.empty: committee_report.to_csv(os.path.join(output_dir, f"{prefix}committee_report.csv"), index=False)
        if moo_blotter is not None: moo_blotter.to_csv(os.path.join(output_dir, f"{prefix}moo_blotter.csv"), index=False)
        if net_portfolio is not None:
            try: net_portfolio.trades.records_readable.to_csv(os.path.join(output_dir, f"{prefix}trade_records.csv"), index=False)
            except Exception: pass
            try: net_portfolio.stats().to_csv(os.path.join(output_dir, f"{prefix}portfolio_stats.csv"))
            except Exception: pass

    fig1, ax1 = plt.subplots(figsize=(16, 4))
    if "Ghost_Size" in df.columns:
        ax1.plot(df.index, df["Ghost_Size"], label="Ghost Universe", color="#2b5c8f", linestyle="--", linewidth=1.5)
    if "Promoted_Size" in df.columns:
        ax1.plot(df.index, df["Promoted_Size"], label="Promoted Universe (Parametric Gated)", color="#e07a5f", linestyle="-.", linewidth=1.5)
    if "Live_Size" in df.columns:
        ax1.step(df.index, df["Live_Size"], label="Live Portfolio", color="#2a9d8f", where="post", linewidth=2.5)
    ax1.set_title("Universe Funnel Sizing (Pair Counts)", fontsize=11, fontweight="bold", loc="left")
    ax1.legend(loc="upper left", bbox_to_anchor=(1.02, 1), borderaxespad=0., frameon=True)
    format_independent_axis(ax1, rebalance_dates)
    plt.tight_layout()
    if save and output_dir: fig1.savefig(os.path.join(output_dir, f"{prefix}funnel_sizing.png"), dpi=300, bbox_inches="tight")
    plt.show()

    fig4, ax4 = plt.subplots(figsize=(16, 4))
    if "Mean_Parametric_Alpha" in df.columns:
        ax4.plot(df.index, df["Mean_Parametric_Alpha"], label="Mean Parametric Alpha", color="#457b9d", linewidth=2.0)
    ax4.set_title("Parametric Expected Yield Trajectory", fontsize=11, fontweight="bold", loc="left")
    ax4.legend(loc="upper left", bbox_to_anchor=(1.02, 1), borderaxespad=0., frameon=True)
    format_independent_axis(ax4, rebalance_dates)
    plt.tight_layout()
    if save and output_dir: fig4.savefig(os.path.join(output_dir, f"{prefix}parametric_alpha.png"), dpi=300, bbox_inches="tight")
    plt.show()

    fig5, ax5 = plt.subplots(figsize=(16, 5))
    live_cum = (1.0 + df.get("Live_Realized_Return", pd.Series(0.0, index=df.index)).fillna(0.0)).cumprod() * initial_capital
    promoted_cum = (1.0 + df.get("Promoted_Realized_Return", pd.Series(0.0, index=df.index)).fillna(0.0)).cumprod() * initial_capital
    ghost_cum = (1.0 + df.get("Ghost_Realized_Return", pd.Series(0.0, index=df.index)).fillna(0.0)).cumprod() * initial_capital

    ax5.plot(df.index, live_cum, label="Live Realized Value ($)", color="#2a9d8f", linewidth=2.5)
    ax5.plot(df.index, promoted_cum, label="Promoted Shadow Value ($)", color="#e07a5f", linestyle="-.", linewidth=1.5)
    ax5.plot(df.index, ghost_cum, label="Ghost Shadow Value ($)", color="#2b5c8f", linestyle="--", linewidth=1.5)
    
    ax5.axhline(initial_capital, color="black", linewidth=0.8)
    ax5.set_title("Cumulative Performance Horizon & Funnel Attribution ($)", fontsize=11, fontweight="bold", loc="left")
    ax5.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
    ax5.legend(loc="upper left", bbox_to_anchor=(1.02, 1), borderaxespad=0., frameon=True)
    format_independent_axis(ax5, rebalance_dates)
    plt.tight_layout()
    if save and output_dir: fig5.savefig(os.path.join(output_dir, f"{prefix}cumulative_performance.png"), dpi=300, bbox_inches="tight")
    plt.show()

# ==============================================================================
# MAIN EXECUTION ENTRY POINT
# ==============================================================================
if __name__ == "__main__":
    committee_report, net_portfolio, metrics, moo_blotter, summary_data = run_unified_pipeline(params=run_params)
    
    if metrics is not None and not metrics.empty:
        print_execution_summary(
            metrics_df=metrics,
            committee_report=committee_report,
            moo_blotter=moo_blotter,
            **summary_data
        )
        
        plot_diagnostic_tearsheet(
            metrics_df=metrics,
            initial_capital=run_params.get("initial_capital", 250_000.0),
            committee_report=committee_report,
            net_portfolio=net_portfolio,
            moo_blotter=moo_blotter,
            save=True,
            prefix="dev_"
        )
# Out:
# =====================================================================================
# STARTING ROBUST 2-STAGE STAT-ARB ENGINE (TENSOR-DAG PARAMETRIC SLSQP)
# =====================================================================================
# [DAG Pre-Compute] Initializing Vectorized Matrix Space...
# [DAG Pre-Compute] Processing 4793 Sector-Matched Correlated Pairs across 1004 days...
# [DAG Pre-Compute] Completed successfully. Executing Portfolio Routing Loop.
#
# [Dynamic Rebalance @ 2024-08-28 | Progress:   0.2% (1/500)] Cause: INITIAL_ENTRY
#   --> Pipeline Funnel : Ghost=25 | Promoted=4 | Live=4
#   --> SLSQP Metrics   : Eff Gross=0.81 | Port Vol=0.1640 | Turnover Drag=0.000646
#   --> Top Allocations :
#       XYZ/RF | W_A: 25.0% | W_B: -17.6% | Inno Z: -0.59 | Parametric Alpha: 0.1565
#       MRVL/SMCI | W_A: -23.9% | W_B: 8.0% | Inno Z: 0.99 | Parametric Alpha: 1.1982
#       XYZ/FITB | W_A: 20.1% | W_B: -14.1% | Inno Z: -0.56 | Parametric Alpha: 0.1052
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-08-29 | Progress:   0.4% (2/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=25 | Promoted=3 | Live=4
#   --> SLSQP Metrics   : Eff Gross=0.79 | Port Vol=0.1288 | Turnover Drag=0.000440
#   --> Top Allocations :
#       MRVL/SMCI | W_A: -25.0% | W_B: 8.5% | Inno Z: 0.99 | Parametric Alpha: 0.1898
#       XYZ/TROW | W_A: -25.0% | W_B: 25.1% | Inno Z: 0.73 | Parametric Alpha: 0.4703
#       TECH/STE | W_A: -17.2% | W_B: 11.3% | Inno Z: 0.56 | Parametric Alpha: 0.0994
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-08-30 | Progress:   0.6% (3/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=24 | Promoted=1 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.30 | Port Vol=0.0946 | Turnover Drag=0.000044
#   --> Top Allocations :
#       MRVL/SMCI | W_A: -25.0% | W_B: 8.9% | Inno Z: 0.99 | Parametric Alpha: 3.0085
#       APA/OKE | W_A: 5.5% | W_B: -4.5% | Inno Z: -0.77 | Parametric Alpha: 0.3688
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-03 | Progress:   0.8% (4/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=23 | Promoted=4 | Live=6
#   --> SLSQP Metrics   : Eff Gross=0.85 | Port Vol=0.1249 | Turnover Drag=0.000433
#   --> Top Allocations :
#       MRVL/SMCI | W_A: 25.0% | W_B: -8.7% | Inno Z: 0.99 | Parametric Alpha: 1.0751
#       APA/OKE | W_A: 24.9% | W_B: -20.1% | Inno Z: -0.77 | Parametric Alpha: 0.9762
#       FIX/PH | W_A: 19.7% | W_B: -16.7% | Inno Z: -1.02 | Parametric Alpha: 1.2552
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-04 | Progress:   1.0% (5/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=27 | Promoted=1 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.34 | Port Vol=0.0476 | Turnover Drag=0.000069
#   --> Top Allocations :
#       APA/OKE | W_A: 25.0% | W_B: -20.0% | Inno Z: -0.77 | Parametric Alpha: 0.3016
#       DE/ITW | W_A: -8.5% | W_B: 7.7% | Inno Z: 0.53 | Parametric Alpha: 0.0621
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-05 | Progress:   1.2% (6/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=28 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-06 | Progress:   1.4% (7/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=30 | Promoted=3 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.57 | Port Vol=0.1246 | Turnover Drag=0.000452
#   --> Top Allocations :
#       XYZ/RF | W_A: 25.0% | W_B: -17.4% | Inno Z: -0.68 | Parametric Alpha: 0.3058
#       XYZ/KEY | W_A: 25.0% | W_B: -11.6% | Inno Z: -0.65 | Parametric Alpha: 0.2869
#       MRVL/SMCI | W_A: 6.5% | W_B: -2.2% | Inno Z: -0.53 | Parametric Alpha: 0.0748
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-09 | Progress:   1.6% (8/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=26 | Promoted=0 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0632 | Turnover Drag=0.000000
#   --> Top Allocations :
#       XYZ/KEY | W_A: 25.0% | W_B: -11.4% | Inno Z: -0.65 | Parametric Alpha: 0.0624
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-10 | Progress:   1.8% (9/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=30 | Promoted=4 | Live=4
#   --> SLSQP Metrics   : Eff Gross=0.63 | Port Vol=0.1208 | Turnover Drag=0.000504
#   --> Top Allocations :
#       APA/OKE | W_A: 25.0% | W_B: -19.6% | Inno Z: -0.79 | Parametric Alpha: 0.4352
#       MRVL/SMCI | W_A: -25.0% | W_B: 8.8% | Inno Z: 0.67 | Parametric Alpha: 0.3992
#       TECH/LH | W_A: -8.1% | W_B: 5.9% | Inno Z: 0.64 | Parametric Alpha: 0.0767
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-11 | Progress:   2.0% (10/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=27 | Promoted=8 | Live=9
#   --> SLSQP Metrics   : Eff Gross=1.51 | Port Vol=0.1866 | Turnover Drag=0.001277
#   --> Top Allocations :
#       XYZ/KEY | W_A: -24.3% | W_B: 11.2% | Inno Z: 0.62 | Parametric Alpha: 0.2394
#       XYZ/RF | W_A: -23.3% | W_B: 16.2% | Inno Z: 0.82 | Parametric Alpha: 0.5152
#       AVGO/KLAC | W_A: -19.6% | W_B: 16.7% | Inno Z: 0.62 | Parametric Alpha: 0.1528
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-12 | Progress:   2.2% (11/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=27 | Promoted=0 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0575 | Turnover Drag=0.000043
#   --> Top Allocations :
#       AVGO/KLAC | W_A: -25.0% | W_B: 21.5% | Inno Z: 0.62 | Parametric Alpha: 0.8122
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-13 | Progress:   2.4% (12/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=31 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-16 | Progress:   2.6% (13/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=31 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0633 | Turnover Drag=0.000200
#   --> Top Allocations :
#       XYZ/KEY | W_A: -25.0% | W_B: 11.8% | Inno Z: 0.54 | Parametric Alpha: 0.0838
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-17 | Progress:   2.8% (14/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=31 | Promoted=1 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.30 | Port Vol=0.0668 | Turnover Drag=0.000338
#   --> Top Allocations :
#       XYZ/TFC | W_A: -23.4% | W_B: 14.7% | Inno Z: 0.63 | Parametric Alpha: 0.3027
#       XYZ/KEY | W_A: -6.2% | W_B: 3.0% | Inno Z: 0.54 | Parametric Alpha: 0.0427
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-18 | Progress:   3.0% (15/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=32 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-19 | Progress:   3.2% (16/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=32 | Promoted=3 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.71 | Port Vol=0.1085 | Turnover Drag=0.000569
#   --> Top Allocations :
#       MRVL/SMCI | W_A: -25.0% | W_B: 9.0% | Inno Z: 0.70 | Parametric Alpha: 0.4739
#       BKR/DVN | W_A: -25.0% | W_B: 18.1% | Inno Z: 0.68 | Parametric Alpha: 0.3036
#       EQT/OKE | W_A: -21.2% | W_B: 14.9% | Inno Z: 0.63 | Parametric Alpha: 0.2573
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-20 | Progress:   3.4% (17/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=37 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0475 | Turnover Drag=0.000200
#   --> Top Allocations :
#       AVGO/KLAC | W_A: -25.0% | W_B: 21.6% | Inno Z: 0.57 | Parametric Alpha: 0.0980
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-23 | Progress:   3.6% (18/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=37 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0984 | Turnover Drag=0.000200
#   --> Top Allocations :
#       MRVL/SMCI | W_A: 25.0% | W_B: -8.8% | Inno Z: -0.71 | Parametric Alpha: 0.4865
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-24 | Progress:   3.8% (19/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=40 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0298 | Turnover Drag=0.000200
#   --> Top Allocations :
#       CAT/CSX | W_A: -25.0% | W_B: 23.7% | Inno Z: 0.83 | Parametric Alpha: 0.1826
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-25 | Progress:   4.0% (20/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=40 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.33 | Port Vol=0.0762 | Turnover Drag=0.000266
#   --> Top Allocations :
#       XYZ/TFC | W_A: 23.4% | W_B: -14.7% | Inno Z: -0.55 | Parametric Alpha: 0.1103
#       XYZ/KEY | W_A: 9.8% | W_B: -4.7% | Inno Z: -0.51 | Parametric Alpha: 0.0270
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-26 | Progress:   4.2% (21/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=39 | Promoted=6 | Live=6
#   --> SLSQP Metrics   : Eff Gross=1.03 | Port Vol=0.2282 | Turnover Drag=0.000824
#   --> Top Allocations :
#       LRCX/SMCI | W_A: -25.0% | W_B: 7.1% | Inno Z: 1.69 | Parametric Alpha: 2.5258
#       MRVL/SMCI | W_A: -25.0% | W_B: 8.8% | Inno Z: 1.33 | Parametric Alpha: 1.8915
#       ROK/VRT | W_A: -25.0% | W_B: 4.7% | Inno Z: 0.72 | Parametric Alpha: 0.4477
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-27 | Progress:   4.4% (22/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=39 | Promoted=3 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.58 | Port Vol=0.0909 | Turnover Drag=0.000460
#   --> Top Allocations :
#       APA/OKE | W_A: -24.9% | W_B: 19.8% | Inno Z: 0.70 | Parametric Alpha: 0.3474
#       APA/TRGP | W_A: -23.3% | W_B: 18.0% | Inno Z: 0.77 | Parametric Alpha: 0.6519
#       DELL/WDC | W_A: 9.2% | W_B: -7.0% | Inno Z: -0.64 | Parametric Alpha: 0.1285
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-09-30 | Progress:   4.6% (23/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=41 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-01 | Progress:   4.8% (24/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=41 | Promoted=3 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.69 | Port Vol=0.1034 | Turnover Drag=0.000553
#   --> Top Allocations :
#       APA/OKE | W_A: -24.9% | W_B: 20.0% | Inno Z: 0.62 | Parametric Alpha: 0.2039
#       APA/TRGP | W_A: -23.3% | W_B: 18.2% | Inno Z: 0.53 | Parametric Alpha: 0.0810
#       DELL/WDC | W_A: 20.8% | W_B: -15.7% | Inno Z: -0.57 | Parametric Alpha: 0.0674
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-02 | Progress:   5.0% (25/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=43 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-04 | Progress:   5.4% (27/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=46 | Promoted=8 | Live=8
#   --> SLSQP Metrics   : Eff Gross=1.46 | Port Vol=0.1102 | Turnover Drag=0.001170
#   --> Top Allocations :
#       CCI/KIM | W_A: 25.0% | W_B: -17.1% | Inno Z: -0.65 | Parametric Alpha: 0.2599
#       DELL/WDC | W_A: -23.3% | W_B: 17.8% | Inno Z: 0.83 | Parametric Alpha: 0.3385
#       MET/NDAQ | W_A: -22.2% | W_B: 13.5% | Inno Z: 0.64 | Parametric Alpha: 0.2834
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-07 | Progress:   5.6% (28/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=51 | Promoted=7 | Live=7
#   --> SLSQP Metrics   : Eff Gross=1.44 | Port Vol=0.2209 | Turnover Drag=0.001151
#   --> Top Allocations :
#       LRCX/SMCI | W_A: 25.0% | W_B: -6.6% | Inno Z: -0.88 | Parametric Alpha: 0.8175
#       MRVL/SMCI | W_A: 25.0% | W_B: -8.6% | Inno Z: -0.72 | Parametric Alpha: 0.4718
#       CINF/FITB | W_A: 25.0% | W_B: -11.4% | Inno Z: -0.69 | Parametric Alpha: 0.4400
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-08 | Progress:   5.8% (29/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=50 | Promoted=7 | Live=7
#   --> SLSQP Metrics   : Eff Gross=1.31 | Port Vol=0.2311 | Turnover Drag=0.001052
#   --> Top Allocations :
#       XYZ/KEY | W_A: -25.0% | W_B: 12.1% | Inno Z: 0.66 | Parametric Alpha: 0.3260
#       XYZ/FITB | W_A: -25.0% | W_B: 17.8% | Inno Z: 0.64 | Parametric Alpha: 0.3122
#       XYZ/TFC | W_A: -25.0% | W_B: 15.8% | Inno Z: 0.58 | Parametric Alpha: 0.1932
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-09 | Progress:   6.0% (30/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=48 | Promoted=3 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.53 | Port Vol=0.0755 | Turnover Drag=0.000423
#   --> Top Allocations :
#       DELL/WDC | W_A: -25.0% | W_B: 19.3% | Inno Z: 0.55 | Parametric Alpha: 0.0457
#       NCLH/RCL | W_A: -22.9% | W_B: 19.6% | Inno Z: 0.95 | Parametric Alpha: 0.4921
#       MRVL/KLAC | W_A: 5.0% | W_B: -4.7% | Inno Z: -0.50 | Parametric Alpha: 0.0053
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-10 | Progress:   6.2% (31/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=48 | Promoted=4 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.85 | Port Vol=0.1328 | Turnover Drag=0.000483
#   --> Top Allocations :
#       XYZ/KEY | W_A: -25.0% | W_B: 12.3% | Inno Z: 0.61 | Parametric Alpha: 0.2263
#       DELL/WDC | W_A: -24.9% | W_B: 19.4% | Inno Z: 0.55 | Parametric Alpha: 0.1034
#       DDOG/MSFT | W_A: -19.3% | W_B: 17.9% | Inno Z: 0.58 | Parametric Alpha: 0.2341
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-11 | Progress:   6.4% (32/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=47 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-14 | Progress:   6.6% (33/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=46 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.1040 | Turnover Drag=0.000200
#   --> Top Allocations :
#       MRVL/SMCI | W_A: -25.0% | W_B: 8.7% | Inno Z: 0.96 | Parametric Alpha: 0.8583
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-15 | Progress:   6.8% (34/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=48 | Promoted=10 | Live=11
#   --> SLSQP Metrics   : Eff Gross=1.59 | Port Vol=0.1917 | Turnover Drag=0.001328
#   --> Top Allocations :
#       KLAC/WDC | W_A: 17.3% | W_B: -11.5% | Inno Z: -2.71 | Parametric Alpha: 0.9358
#       DELL/KLAC | W_A: -16.4% | W_B: 12.3% | Inno Z: 1.61 | Parametric Alpha: 2.3450
#       AVGO/KLAC | W_A: -16.4% | W_B: 13.9% | Inno Z: 1.54 | Parametric Alpha: 2.1530
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-16 | Progress:   7.0% (35/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=46 | Promoted=4 | Live=10
#   --> SLSQP Metrics   : Eff Gross=1.58 | Port Vol=0.1751 | Turnover Drag=0.000541
#   --> Top Allocations :
#       XYZ/CFG | W_A: -19.1% | W_B: 13.2% | Inno Z: 0.75 | Parametric Alpha: 0.2912
#       KLAC/WDC | W_A: 18.5% | W_B: -11.9% | Inno Z: -2.71 | Parametric Alpha: 0.5391
#       MS/NDAQ | W_A: -17.7% | W_B: 11.9% | Inno Z: 0.93 | Parametric Alpha: 0.2829
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-17 | Progress:   7.2% (36/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=46 | Promoted=3 | Live=7
#   --> SLSQP Metrics   : Eff Gross=1.30 | Port Vol=0.1106 | Turnover Drag=0.000644
#   --> Top Allocations :
#       CCI/KIM | W_A: 25.0% | W_B: -16.8% | Inno Z: -0.70 | Parametric Alpha: 0.3713
#       DELL/KLAC | W_A: -24.7% | W_B: 18.6% | Inno Z: 1.61 | Parametric Alpha: 0.2434
#       AVGO/KLAC | W_A: -24.7% | W_B: 21.1% | Inno Z: 1.54 | Parametric Alpha: 0.4096
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-18 | Progress:   7.4% (37/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=50 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0395 | Turnover Drag=0.000200
#   --> Top Allocations :
#       SLB/VLO | W_A: 25.0% | W_B: -14.7% | Inno Z: -0.75 | Parametric Alpha: 0.1199
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-21 | Progress:   7.6% (38/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=50 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0724 | Turnover Drag=0.000200
#   --> Top Allocations :
#       MPWR/STX | W_A: 25.0% | W_B: -20.8% | Inno Z: -0.60 | Parametric Alpha: 0.2604
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-22 | Progress:   7.8% (39/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=56 | Promoted=6 | Live=6
#   --> SLSQP Metrics   : Eff Gross=0.82 | Port Vol=0.0945 | Turnover Drag=0.000654
#   --> Top Allocations :
#       GPC/PHM | W_A: 25.0% | W_B: -9.9% | Inno Z: -3.10 | Parametric Alpha: 6.7664
#       GPC/LEN | W_A: 25.0% | W_B: -11.5% | Inno Z: -3.16 | Parametric Alpha: 5.4411
#       GPC/NVR | W_A: 16.6% | W_B: -8.1% | Inno Z: -2.18 | Parametric Alpha: 5.1991
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-23 | Progress:   8.0% (40/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=53 | Promoted=8 | Live=8
#   --> SLSQP Metrics   : Eff Gross=1.26 | Port Vol=0.1325 | Turnover Drag=0.001006
#   --> Top Allocations :
#       NTRS/TFC | W_A: -24.5% | W_B: 14.5% | Inno Z: 1.15 | Parametric Alpha: 1.5014
#       KEY/NTRS | W_A: 22.1% | W_B: -19.5% | Inno Z: -1.07 | Parametric Alpha: 1.3869
#       MPWR/STX | W_A: -21.6% | W_B: 17.8% | Inno Z: 1.15 | Parametric Alpha: 1.6359
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-24 | Progress:   8.2% (41/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=44 | Promoted=4 | Live=7
#   --> SLSQP Metrics   : Eff Gross=1.36 | Port Vol=0.1762 | Turnover Drag=0.000896
#   --> Top Allocations :
#       GPC/PHM | W_A: 24.9% | W_B: -9.6% | Inno Z: -0.60 | Parametric Alpha: 0.2153
#       GPC/LEN | W_A: 24.3% | W_B: -11.0% | Inno Z: -0.59 | Parametric Alpha: 0.2066
#       ODFL/UNP | W_A: -23.5% | W_B: 19.9% | Inno Z: -0.79 | Parametric Alpha: 0.2665
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-25 | Progress:   8.4% (42/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=49 | Promoted=2 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.55 | Port Vol=0.0485 | Turnover Drag=0.000527
#   --> Top Allocations :
#       PFG/NDAQ | W_A: 25.0% | W_B: -15.6% | Inno Z: -1.11 | Parametric Alpha: 0.6684
#       HIG/PGR | W_A: 23.8% | W_B: -14.4% | Inno Z: -0.88 | Parametric Alpha: 0.6750
#       ODFL/UNP | W_A: -6.3% | W_B: 5.4% | Inno Z: -0.79 | Parametric Alpha: 0.1696
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-28 | Progress:   8.6% (43/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=52 | Promoted=5 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.89 | Port Vol=0.1263 | Turnover Drag=0.000713
#   --> Top Allocations :
#       NXPI/STX | W_A: -25.0% | W_B: 15.7% | Inno Z: 0.70 | Parametric Alpha: 0.3463
#       APA/OKE | W_A: 25.0% | W_B: -19.8% | Inno Z: -0.61 | Parametric Alpha: 0.1548
#       APA/TRGP | W_A: 24.4% | W_B: -18.4% | Inno Z: -0.56 | Parametric Alpha: 0.1209
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-29 | Progress:   8.8% (44/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=50 | Promoted=4 | Live=5
#   --> SLSQP Metrics   : Eff Gross=1.16 | Port Vol=0.1549 | Turnover Drag=0.000786
#   --> Top Allocations :
#       AMT/KIM | W_A: 25.0% | W_B: -18.5% | Inno Z: -0.79 | Parametric Alpha: 0.4639
#       MPWR/STX | W_A: -24.1% | W_B: 20.3% | Inno Z: 0.76 | Parametric Alpha: 0.5428
#       KLAC/STX | W_A: -24.1% | W_B: 15.2% | Inno Z: 0.57 | Parametric Alpha: 0.0792
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-30 | Progress:   9.0% (45/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=53 | Promoted=5 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.98 | Port Vol=0.1585 | Turnover Drag=0.000786
#   --> Top Allocations :
#       LRCX/SMCI | W_A: -25.0% | W_B: 6.0% | Inno Z: 1.43 | Parametric Alpha: 1.3357
#       DELL/WDC | W_A: -25.0% | W_B: 19.1% | Inno Z: 1.41 | Parametric Alpha: 1.0938
#       DELL/QCOM | W_A: -21.8% | W_B: 15.9% | Inno Z: 1.41 | Parametric Alpha: 1.6021
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-10-31 | Progress:   9.2% (46/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=52 | Promoted=15 | Live=14
#   --> SLSQP Metrics   : Eff Gross=1.00 | Port Vol=0.0463 | Turnover Drag=0.000773
#   --> Top Allocations :
#       D/ETR | W_A: 15.0% | W_B: -11.2% | Inno Z: -1.70 | Parametric Alpha: 2.9680
#       ROK/XYL | W_A: -15.0% | W_B: 12.6% | Inno Z: 0.84 | Parametric Alpha: 0.5414
#       BXP/KIM | W_A: 12.4% | W_B: -13.5% | Inno Z: -1.14 | Parametric Alpha: 0.2379
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-01 | Progress:   9.4% (47/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=54 | Promoted=4 | Live=7
#   --> SLSQP Metrics   : Eff Gross=1.29 | Port Vol=0.1600 | Turnover Drag=0.000950
#   --> Top Allocations :
#       BXP/KIM | W_A: 25.0% | W_B: -27.0% | Inno Z: -1.14 | Parametric Alpha: 0.2426
#       DELL/WDC | W_A: -25.0% | W_B: 19.4% | Inno Z: 0.86 | Parametric Alpha: 0.4922
#       MPWR/STX | W_A: 24.6% | W_B: -19.9% | Inno Z: -3.06 | Parametric Alpha: 0.2495
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-04 | Progress:   9.6% (48/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=58 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0574 | Turnover Drag=0.000200
#   --> Top Allocations :
#       BEN/SYF | W_A: 25.0% | W_B: -11.6% | Inno Z: -0.56 | Parametric Alpha: 0.0530
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-05 | Progress:   9.8% (49/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=60 | Promoted=4 | Live=4
#   --> SLSQP Metrics   : Eff Gross=0.72 | Port Vol=0.0549 | Turnover Drag=0.000573
#   --> Top Allocations :
#       ADSK/PLTR | W_A: 25.0% | W_B: -6.0% | Inno Z: -0.63 | Parametric Alpha: 0.2940
#       AME/EMR | W_A: 25.0% | W_B: -17.4% | Inno Z: -0.60 | Parametric Alpha: 0.0747
#       APA/TRGP | W_A: 16.1% | W_B: -11.9% | Inno Z: -0.52 | Parametric Alpha: 0.0355
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-06 | Progress:  10.0% (50/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=67 | Promoted=30 | Live=21
#   --> SLSQP Metrics   : Eff Gross=0.98 | Port Vol=0.0228 | Turnover Drag=0.000799
#   --> Top Allocations :
#       EXC/SRE | W_A: 14.3% | W_B: -10.7% | Inno Z: -0.97 | Parametric Alpha: 0.3542
#       IRM/VMRK | W_A: 11.5% | W_B: -10.3% | Inno Z: -1.42 | Parametric Alpha: 1.0622
#       GS/FITB | W_A: -8.2% | W_B: 5.4% | Inno Z: 1.39 | Parametric Alpha: 0.9112
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-07 | Progress:  10.2% (51/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=76 | Promoted=5 | Live=9
#   --> SLSQP Metrics   : Eff Gross=1.29 | Port Vol=0.0757 | Turnover Drag=0.000957
#   --> Top Allocations :
#       AMT/KIM | W_A: 23.6% | W_B: -16.6% | Inno Z: -1.42 | Parametric Alpha: 0.2906
#       DTE/FE | W_A: 21.9% | W_B: -20.3% | Inno Z: -0.74 | Parametric Alpha: 0.4996
#       ROK/VRT | W_A: 19.2% | W_B: -3.7% | Inno Z: -0.69 | Parametric Alpha: 0.4465
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-08 | Progress:  10.4% (52/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=79 | Promoted=5 | Live=8
#   --> SLSQP Metrics   : Eff Gross=1.27 | Port Vol=0.1375 | Turnover Drag=0.000889
#   --> Top Allocations :
#       APA/OKE | W_A: 23.8% | W_B: -17.5% | Inno Z: -1.00 | Parametric Alpha: 0.7562
#       EOG/XOM | W_A: -23.1% | W_B: 22.5% | Inno Z: 0.92 | Parametric Alpha: 0.4352
#       APA/TRGP | W_A: 22.1% | W_B: -15.6% | Inno Z: -1.88 | Parametric Alpha: 0.5693
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-11 | Progress:  10.6% (53/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=82 | Promoted=9 | Live=10
#   --> SLSQP Metrics   : Eff Gross=1.52 | Port Vol=0.1471 | Turnover Drag=0.001211
#   --> Top Allocations :
#       XYZ/KEY | W_A: -21.2% | W_B: 11.0% | Inno Z: 2.03 | Parametric Alpha: 3.1611
#       XYZ/TFC | W_A: -18.8% | W_B: 12.5% | Inno Z: 1.64 | Parametric Alpha: 2.6613
#       XYZ/CFG | W_A: -18.8% | W_B: 13.0% | Inno Z: 1.77 | Parametric Alpha: 0.7228
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-12 | Progress:  10.8% (54/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=73 | Promoted=1 | Live=8
#   --> SLSQP Metrics   : Eff Gross=1.26 | Port Vol=0.1804 | Turnover Drag=0.000365
#   --> Top Allocations :
#       XYZ/KEY | W_A: -25.0% | W_B: 13.4% | Inno Z: 2.03 | Parametric Alpha: 2.5747
#       XYZ/TFC | W_A: -22.6% | W_B: 15.3% | Inno Z: 1.64 | Parametric Alpha: 1.7693
#       XYZ/CFG | W_A: -21.8% | W_B: 15.3% | Inno Z: 1.77 | Parametric Alpha: 0.4946
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-13 | Progress:  11.0% (55/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=73 | Promoted=3 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.53 | Port Vol=0.1037 | Turnover Drag=0.000423
#   --> Top Allocations :
#       MPWR/STX | W_A: 25.0% | W_B: -19.3% | Inno Z: -1.00 | Parametric Alpha: 1.1552
#       FIX/CMI | W_A: 22.9% | W_B: -20.6% | Inno Z: -0.89 | Parametric Alpha: 0.9454
#       ROK/XYL | W_A: -5.0% | W_B: 4.3% | Inno Z: 0.59 | Parametric Alpha: 0.0558
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-14 | Progress:  11.2% (56/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=67 | Promoted=4 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.87 | Port Vol=0.1482 | Turnover Drag=0.000500
#   --> Top Allocations :
#       MPWR/STX | W_A: 25.0% | W_B: -19.1% | Inno Z: -1.00 | Parametric Alpha: 0.7411
#       XYZ/TROW | W_A: 25.0% | W_B: -25.5% | Inno Z: -0.64 | Parametric Alpha: 0.3121
#       APTV/PHM | W_A: 25.0% | W_B: -10.2% | Inno Z: -0.67 | Parametric Alpha: 0.2705
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-15 | Progress:  11.4% (57/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=63 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0367 | Turnover Drag=0.000200
#   --> Top Allocations :
#       ADSK/PLTR | W_A: 25.0% | W_B: -5.8% | Inno Z: -0.94 | Parametric Alpha: 0.9682
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-18 | Progress:  11.6% (58/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=56 | Promoted=5 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.84 | Port Vol=0.1617 | Turnover Drag=0.000672
#   --> Top Allocations :
#       XYZ/KEY | W_A: -25.0% | W_B: 13.8% | Inno Z: 1.45 | Parametric Alpha: 1.9802
#       XYZ/TFC | W_A: -24.7% | W_B: 17.0% | Inno Z: 1.25 | Parametric Alpha: 1.7580
#       XYZ/TROW | W_A: -21.9% | W_B: 22.7% | Inno Z: 1.22 | Parametric Alpha: 1.5465
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-19 | Progress:  11.8% (59/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=47 | Promoted=1 | Live=5
#   --> SLSQP Metrics   : Eff Gross=1.00 | Port Vol=0.1848 | Turnover Drag=0.000240
#   --> Top Allocations :
#       XYZ/KEY | W_A: -25.0% | W_B: 14.0% | Inno Z: 1.45 | Parametric Alpha: 1.1692
#       XYZ/TFC | W_A: -25.0% | W_B: 17.4% | Inno Z: 1.25 | Parametric Alpha: 0.5797
#       ROK/VRT | W_A: 22.4% | W_B: -4.1% | Inno Z: -0.72 | Parametric Alpha: 0.5580
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-20 | Progress:  12.0% (60/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=48 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-21 | Progress:  12.2% (61/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=34 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.29 | Port Vol=0.0439 | Turnover Drag=0.000233
#   --> Top Allocations :
#       ADSK/PLTR | W_A: -24.1% | W_B: 5.8% | Inno Z: 0.53 | Parametric Alpha: 0.0663
#       GS/HOOD | W_A: -5.0% | W_B: 1.3% | Inno Z: 0.50 | Parametric Alpha: 0.0023
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-22 | Progress:  12.4% (62/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=32 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.30 | Port Vol=0.0710 | Turnover Drag=0.000240
#   --> Top Allocations :
#       ROK/VRT | W_A: -25.0% | W_B: 4.7% | Inno Z: 0.67 | Parametric Alpha: 0.4224
#       ROK/WAB | W_A: -5.0% | W_B: 4.3% | Inno Z: 0.51 | Parametric Alpha: 0.0261
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-25 | Progress:  12.6% (63/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=31 | Promoted=2 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.63 | Port Vol=0.0883 | Turnover Drag=0.000329
#   --> Top Allocations :
#       LOW/NCLH | W_A: -25.0% | W_B: 6.3% | Inno Z: 0.68 | Parametric Alpha: 0.1650
#       ROK/VRT | W_A: -23.3% | W_B: 4.5% | Inno Z: 0.67 | Parametric Alpha: 0.5807
#       FIX/VRT | W_A: -14.5% | W_B: 7.0% | Inno Z: 0.61 | Parametric Alpha: 0.0954
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-26 | Progress:  12.8% (64/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=33 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-27 | Progress:  13.0% (65/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=33 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0440 | Turnover Drag=0.000200
#   --> Top Allocations :
#       ADSK/PLTR | W_A: 25.0% | W_B: -5.6% | Inno Z: -1.59 | Parametric Alpha: 2.3052
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-11-29 | Progress:  13.2% (66/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=29 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-02 | Progress:  13.4% (67/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=28 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.49 | Port Vol=0.1142 | Turnover Drag=0.000388
#   --> Top Allocations :
#       XYZ/KEY | W_A: -25.0% | W_B: 13.9% | Inno Z: 1.10 | Parametric Alpha: 1.2517
#       XYZ/TFC | W_A: -23.5% | W_B: 16.2% | Inno Z: 0.98 | Parametric Alpha: 1.1235
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-05 | Progress:  14.0% (70/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=25 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-09 | Progress:  14.4% (72/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=28 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.43 | Port Vol=0.0492 | Turnover Drag=0.000346
#   --> Top Allocations :
#       BXP/KIM | W_A: -25.0% | W_B: 26.6% | Inno Z: 0.78 | Parametric Alpha: 0.2473
#       FIX/VRT | W_A: 18.3% | W_B: -8.8% | Inno Z: -0.67 | Parametric Alpha: 0.1422
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-10 | Progress:  14.6% (73/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=29 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-11 | Progress:  14.8% (74/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=28 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.44 | Port Vol=0.1094 | Turnover Drag=0.000349
#   --> Top Allocations :
#       XYZ/TFC | W_A: -23.5% | W_B: 16.6% | Inno Z: 0.89 | Parametric Alpha: 0.9278
#       XYZ/KEY | W_A: -20.2% | W_B: 11.7% | Inno Z: 0.80 | Parametric Alpha: 0.6277
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-12 | Progress:  15.0% (75/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=28 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0323 | Turnover Drag=0.000200
#   --> Top Allocations :
#       KEY/MET | W_A: 25.0% | W_B: -26.3% | Inno Z: -0.77 | Parametric Alpha: 0.5294
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-13 | Progress:  15.2% (76/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=31 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.43 | Port Vol=0.1134 | Turnover Drag=0.000343
#   --> Top Allocations :
#       XYZ/KEY | W_A: 25.0% | W_B: -14.3% | Inno Z: -0.65 | Parametric Alpha: 0.3070
#       XYZ/TFC | W_A: 17.9% | W_B: -12.4% | Inno Z: -0.57 | Parametric Alpha: 0.1704
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-16 | Progress:  15.4% (77/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=30 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0875 | Turnover Drag=0.000200
#   --> Top Allocations :
#       MRVL/NVDA | W_A: -25.0% | W_B: 17.2% | Inno Z: 1.09 | Parametric Alpha: 1.4472
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-18 | Progress:  15.8% (79/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=32 | Promoted=5 | Live=6
#   --> SLSQP Metrics   : Eff Gross=0.91 | Port Vol=0.1695 | Turnover Drag=0.000565
#   --> Top Allocations :
#       XYZ/KEY | W_A: 25.0% | W_B: -14.3% | Inno Z: -0.86 | Parametric Alpha: 0.7421
#       XYZ/TFC | W_A: 25.0% | W_B: -17.4% | Inno Z: -0.76 | Parametric Alpha: 0.6006
#       MRVL/NVDA | W_A: 22.9% | W_B: -15.3% | Inno Z: 1.09 | Parametric Alpha: 1.6585
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-19 | Progress:  16.0% (80/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=37 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.49 | Port Vol=0.0685 | Turnover Drag=0.000390
#   --> Top Allocations :
#       LOW/NCLH | W_A: 25.0% | W_B: -5.8% | Inno Z: -0.61 | Parametric Alpha: 0.1274
#       PSA/VTR | W_A: 23.7% | W_B: -16.2% | Inno Z: -0.57 | Parametric Alpha: 0.1164
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-20 | Progress:  16.2% (81/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=40 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2024-12-31 | Progress:  17.4% (87/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=31 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0604 | Turnover Drag=0.000200
#   --> Top Allocations :
#       XYZ/RF | W_A: 25.0% | W_B: -19.6% | Inno Z: -0.61 | Parametric Alpha: 0.2330
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-02 | Progress:  17.6% (88/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=30 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-03 | Progress:  17.8% (89/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=30 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0611 | Turnover Drag=0.000200
#   --> Top Allocations :
#       XYZ/RF | W_A: -25.0% | W_B: 19.9% | Inno Z: 1.06 | Parametric Alpha: 1.1860
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-06 | Progress:  18.0% (90/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=31 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0337 | Turnover Drag=0.000200
#   --> Top Allocations :
#       CBRE/KIM | W_A: -25.0% | W_B: 21.9% | Inno Z: 0.80 | Parametric Alpha: 0.2946
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-07 | Progress:  18.2% (91/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=34 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0624 | Turnover Drag=0.000200
#   --> Top Allocations :
#       XYZ/RF | W_A: 25.0% | W_B: -19.8% | Inno Z: -0.87 | Parametric Alpha: 0.7925
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-08 | Progress:  18.4% (92/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=35 | Promoted=2 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.52 | Port Vol=0.0246 | Turnover Drag=0.000539
#   --> Top Allocations :
#       EIX/PCG | W_A: 25.0% | W_B: -18.5% | Inno Z: -1.63 | Parametric Alpha: 1.1897
#       ED/EIX | W_A: -22.4% | W_B: 15.6% | Inno Z: 1.49 | Parametric Alpha: 2.3895
#       XYZ/RF | W_A: 5.0% | W_B: -3.9% | Inno Z: -0.87 | Parametric Alpha: 0.0182
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-10 | Progress:  18.6% (93/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=35 | Promoted=10 | Live=9
#   --> SLSQP Metrics   : Eff Gross=1.00 | Port Vol=0.0463 | Turnover Drag=0.000710
#   --> Top Allocations :
#       AEP/FE | W_A: -15.0% | W_B: 14.0% | Inno Z: 0.74 | Parametric Alpha: 0.2806
#       ED/EIX | W_A: -15.0% | W_B: 10.2% | Inno Z: 1.49 | Parametric Alpha: 0.1730
#       CINF/WTW | W_A: 14.2% | W_B: -9.9% | Inno Z: -0.62 | Parametric Alpha: 0.1229
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-13 | Progress:  18.8% (94/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=31 | Promoted=0 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.80 | Port Vol=0.0771 | Turnover Drag=0.000369
#   --> Top Allocations :
#       XYZ/RF | W_A: 25.0% | W_B: -19.4% | Inno Z: -0.87 | Parametric Alpha: 0.5010
#       ED/EIX | W_A: -22.7% | W_B: 14.0% | Inno Z: 1.49 | Parametric Alpha: 0.4259
#       PCG/PNW | W_A: 22.5% | W_B: -12.6% | Inno Z: -1.83 | Parametric Alpha: 1.6563
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-14 | Progress:  19.0% (95/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=38 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.48 | Port Vol=0.0545 | Turnover Drag=0.000382
#   --> Top Allocations :
#       EIX/PPL | W_A: 25.0% | W_B: -22.9% | Inno Z: -0.78 | Parametric Alpha: 0.3317
#       EME/VRT | W_A: -22.8% | W_B: 8.8% | Inno Z: 0.63 | Parametric Alpha: 0.2976
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-15 | Progress:  19.2% (96/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=37 | Promoted=4 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.82 | Port Vol=0.0835 | Turnover Drag=0.000778
#   --> Top Allocations :
#       CBRE/KIM | W_A: -25.0% | W_B: 21.9% | Inno Z: 0.97 | Parametric Alpha: 0.5789
#       GS/HOOD | W_A: -24.4% | W_B: 6.1% | Inno Z: 0.68 | Parametric Alpha: 0.3420
#       C/NDAQ | W_A: -22.4% | W_B: 15.2% | Inno Z: 0.99 | Parametric Alpha: 1.0868
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-16 | Progress:  19.4% (97/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=34 | Promoted=0 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0382 | Turnover Drag=0.000000
#   --> Top Allocations :
#       CBRE/KIM | W_A: -25.0% | W_B: 22.1% | Inno Z: 0.97 | Parametric Alpha: 0.2248
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-17 | Progress:  19.6% (98/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=36 | Promoted=1 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.37 | Port Vol=0.0271 | Turnover Drag=0.000290
#   --> Top Allocations :
#       KEY/TFC | W_A: 23.9% | W_B: -24.5% | Inno Z: -0.64 | Parametric Alpha: 0.2424
#       CBRE/KIM | W_A: -12.7% | W_B: 11.3% | Inno Z: 0.97 | Parametric Alpha: 0.0825
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-21 | Progress:  19.8% (99/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=34 | Promoted=1 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.57 | Port Vol=0.0516 | Turnover Drag=0.000175
#   --> Top Allocations :
#       KEY/TFC | W_A: 25.0% | W_B: -25.2% | Inno Z: -0.64 | Parametric Alpha: 0.7899
#       TER/ZBRA | W_A: 20.0% | W_B: -12.3% | Inno Z: -0.85 | Parametric Alpha: 0.3197
#       CBRE/KIM | W_A: -11.9% | W_B: 10.7% | Inno Z: 0.97 | Parametric Alpha: 0.1520
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-22 | Progress:  20.0% (100/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=35 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.42 | Port Vol=0.0501 | Turnover Drag=0.000338
#   --> Top Allocations :
#       EIX/PPL | W_A: 25.0% | W_B: -22.8% | Inno Z: -0.81 | Parametric Alpha: 0.3958
#       AXP/BAC | W_A: -17.3% | W_B: 14.4% | Inno Z: 0.61 | Parametric Alpha: 0.2092
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-23 | Progress:  20.2% (101/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=39 | Promoted=2 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.65 | Port Vol=0.0562 | Turnover Drag=0.000482
#   --> Top Allocations :
#       KKR/HBAN | W_A: -25.0% | W_B: 19.7% | Inno Z: 0.67 | Parametric Alpha: 0.3044
#       BXP/KIM | W_A: 25.0% | W_B: -26.7% | Inno Z: -0.69 | Parametric Alpha: 0.2798
#       EIX/PPL | W_A: 14.7% | W_B: -13.4% | Inno Z: -0.81 | Parametric Alpha: 0.1647
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-24 | Progress:  20.4% (102/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=36 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-27 | Progress:  20.6% (103/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=38 | Promoted=16 | Live=12
#   --> SLSQP Metrics   : Eff Gross=1.00 | Port Vol=0.0645 | Turnover Drag=0.000800
#   --> Top Allocations :
#       EQIX/KIM | W_A: 15.0% | W_B: -10.8% | Inno Z: -1.22 | Parametric Alpha: 0.6619
#       EXC/NI | W_A: -15.0% | W_B: 11.7% | Inno Z: 1.13 | Parametric Alpha: 1.2056
#       AME/VRT | W_A: -12.7% | W_B: 2.3% | Inno Z: 0.77 | Parametric Alpha: 0.4656
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-28 | Progress:  20.8% (104/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=39 | Promoted=2 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.53 | Port Vol=0.0887 | Turnover Drag=0.000385
#   --> Top Allocations :
#       COHR/FLEX | W_A: 25.0% | W_B: -20.9% | Inno Z: -2.19 | Parametric Alpha: 1.0747
#       IVZ/PYPL | W_A: -23.4% | W_B: 11.0% | Inno Z: 1.57 | Parametric Alpha: 2.3621
#       XYZ/TFC | W_A: -5.0% | W_B: 3.4% | Inno Z: 0.56 | Parametric Alpha: 0.1435
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-29 | Progress:  21.0% (105/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=45 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.41 | Port Vol=0.0491 | Turnover Drag=0.000326
#   --> Top Allocations :
#       BXP/KIM | W_A: 25.0% | W_B: -26.6% | Inno Z: -0.72 | Parametric Alpha: 0.3452
#       XYZ/RF | W_A: -15.7% | W_B: 12.3% | Inno Z: 0.57 | Parametric Alpha: 0.1582
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-30 | Progress:  21.2% (106/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=47 | Promoted=5 | Live=6
#   --> SLSQP Metrics   : Eff Gross=1.03 | Port Vol=0.1847 | Turnover Drag=0.000697
#   --> Top Allocations :
#       XYZ/RF | W_A: -25.0% | W_B: 19.7% | Inno Z: 0.57 | Parametric Alpha: 0.4534
#       COHR/FLEX | W_A: -25.0% | W_B: 21.1% | Inno Z: 0.62 | Parametric Alpha: 0.2201
#       CDNS/MSFT | W_A: -20.2% | W_B: 17.1% | Inno Z: 1.03 | Parametric Alpha: 1.3171
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-01-31 | Progress:  21.4% (107/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=47 | Promoted=1 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.30 | Port Vol=0.0366 | Turnover Drag=0.000360
#   --> Top Allocations :
#       BXP/KIM | W_A: -25.0% | W_B: 26.8% | Inno Z: 0.59 | Parametric Alpha: 0.1465
#       COHR/FLEX | W_A: -5.0% | W_B: 4.2% | Inno Z: 0.62 | Parametric Alpha: 0.0143
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-02-03 | Progress:  21.6% (108/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=50 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.42 | Port Vol=0.0716 | Turnover Drag=0.000337
#   --> Top Allocations :
#       DECK/RL | W_A: 23.5% | W_B: -14.5% | Inno Z: -1.01 | Parametric Alpha: 1.2930
#       IVZ/PYPL | W_A: 18.6% | W_B: -8.6% | Inno Z: -0.81 | Parametric Alpha: 0.7678
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-02-04 | Progress:  21.8% (109/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=38 | Promoted=5 | Live=6
#   --> SLSQP Metrics   : Eff Gross=1.06 | Port Vol=0.1655 | Turnover Drag=0.000702
#   --> Top Allocations :
#       KKR/HBAN | W_A: 25.0% | W_B: -19.4% | Inno Z: -1.85 | Parametric Alpha: 1.9377
#       XYZ/RF | W_A: 25.0% | W_B: -19.5% | Inno Z: -1.00 | Parametric Alpha: 1.0808
#       XYZ/TFC | W_A: 24.7% | W_B: -16.8% | Inno Z: -0.93 | Parametric Alpha: 1.0051
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-02-05 | Progress:  22.0% (110/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=35 | Promoted=0 | Live=0
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-02-06 | Progress:  22.2% (111/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=28 | Promoted=5 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.87 | Port Vol=0.0799 | Turnover Drag=0.000693
#   --> Top Allocations :
#       CDNS/PTC | W_A: -25.0% | W_B: 21.7% | Inno Z: 1.38 | Parametric Alpha: 1.0387
#       AFL/MRSH | W_A: 24.7% | W_B: -19.3% | Inno Z: -0.63 | Parametric Alpha: 0.3084
#       DECK/RL | W_A: 24.3% | W_B: -14.5% | Inno Z: -0.82 | Parametric Alpha: 0.8030
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-02-07 | Progress:  22.4% (112/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=25 | Promoted=1 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.29 | Port Vol=0.0534 | Turnover Drag=0.000215
#   --> Top Allocations :
#       ABNB/EXPE | W_A: 24.3% | W_B: -13.1% | Inno Z: -1.03 | Parametric Alpha: 1.2265
#       APTV/PHM | W_A: -5.0% | W_B: 2.2% | Inno Z: 0.62 | Parametric Alpha: 0.0371
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-02-10 | Progress:  22.6% (113/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=25 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0682 | Turnover Drag=0.000200
#   --> Top Allocations :
#       DECK/RL | W_A: 25.0% | W_B: -14.7% | Inno Z: -0.63 | Parametric Alpha: 0.3165
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-02-11 | Progress:  22.8% (114/500)] Cause: SIGNAL_ENTRY
#   --> Pipeline Funnel : Ghost=23 | Promoted=2 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.52 | Port Vol=0.1152 | Turnover Drag=0.000281
#   --> Top Allocations :
#       XYZ/RF | W_A: 25.0% | W_B: -19.1% | Inno Z: -0.69 | Parametric Alpha: 0.4052
#       DECK/RL | W_A: 20.9% | W_B: -12.1% | Inno Z: -0.63 | Parametric Alpha: 0.2328
#       XYZ/TFC | W_A: 6.0% | W_B: -4.0% | Inno Z: -0.52 | Parametric Alpha: 0.0557
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2025-02-12 | Progress:  23.0% (115/500)] Cause: SIGNAL_EXIT
# ...
#   --> Pipeline Funnel : Ghost=103 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.28 | Port Vol=0.0922 | Turnover Drag=0.000221
#   --> Top Allocations :
#       KLAC/WDC | W_A: 22.6% | W_B: -12.0% | Inno Z: -0.55 | Parametric Alpha: 0.1450
#       ALL/PFG | W_A: -5.0% | W_B: 3.1% | Inno Z: 0.51 | Parametric Alpha: 0.0041
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-07-21 | Progress:  94.8% (474/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=110 | Promoted=13 | Live=13
#   --> SLSQP Metrics   : Eff Gross=1.44 | Port Vol=0.1529 | Turnover Drag=0.001149
#   --> Top Allocations :
#       GS/KEY | W_A: -16.9% | W_B: 12.2% | Inno Z: 0.66 | Parametric Alpha: 0.3145
#       MSCI/NDAQ | W_A: 14.2% | W_B: -10.8% | Inno Z: -1.53 | Parametric Alpha: 0.4736
#       MSCI/PFG | W_A: 13.8% | W_B: -8.9% | Inno Z: -1.44 | Parametric Alpha: 1.7219
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-07-22 | Progress:  95.0% (475/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=109 | Promoted=7 | Live=7
#   --> SLSQP Metrics   : Eff Gross=1.08 | Port Vol=0.1493 | Turnover Drag=0.000861
#   --> Top Allocations :
#       DELL/HPE | W_A: -25.0% | W_B: 24.4% | Inno Z: 1.10 | Parametric Alpha: 1.0959
#       AME/WAB | W_A: 22.6% | W_B: -15.3% | Inno Z: -1.00 | Parametric Alpha: 1.0208
#       BLDR/WAB | W_A: 22.6% | W_B: -15.4% | Inno Z: -0.86 | Parametric Alpha: 1.0127
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-07-23 | Progress:  95.2% (476/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=110 | Promoted=8 | Live=9
#   --> SLSQP Metrics   : Eff Gross=1.43 | Port Vol=0.0809 | Turnover Drag=0.001086
#   --> Top Allocations :
#       SCHW/HBAN | W_A: -25.0% | W_B: 15.0% | Inno Z: 0.71 | Parametric Alpha: 0.1855
#       DOV/PCAR | W_A: 19.8% | W_B: -13.0% | Inno Z: -1.27 | Parametric Alpha: 0.5496
#       COO/DHR | W_A: 18.7% | W_B: -10.3% | Inno Z: -0.63 | Parametric Alpha: 0.2405
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-07-24 | Progress:  95.4% (477/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=106 | Promoted=3 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.93 | Port Vol=0.1502 | Turnover Drag=0.000656
#   --> Top Allocations :
#       BX/COIN | W_A: -25.0% | W_B: 6.4% | Inno Z: 0.78 | Parametric Alpha: 0.7853
#       VRT/WAB | W_A: 23.9% | W_B: -30.0% | Inno Z: -0.72 | Parametric Alpha: 0.3059
#       INTC/STX | W_A: 21.0% | W_B: -10.9% | Inno Z: -0.62 | Parametric Alpha: 0.1135
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-07-27 | Progress:  95.6% (478/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=104 | Promoted=8 | Live=8
#   --> SLSQP Metrics   : Eff Gross=1.40 | Port Vol=0.2013 | Turnover Drag=0.001123
#   --> Top Allocations :
#       CPAY/KEY | W_A: -25.0% | W_B: 12.4% | Inno Z: 0.69 | Parametric Alpha: 0.3548
#       DELL/HPE | W_A: 23.0% | W_B: -22.5% | Inno Z: -0.60 | Parametric Alpha: 0.1793
#       CPAY/USB | W_A: -21.7% | W_B: 13.9% | Inno Z: 0.56 | Parametric Alpha: 0.0897
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-07-28 | Progress:  95.8% (479/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=97 | Promoted=18 | Live=10
#   --> SLSQP Metrics   : Eff Gross=1.00 | Port Vol=0.0661 | Turnover Drag=0.000935
#   --> Top Allocations :
#       ALL/CINF | W_A: -15.0% | W_B: 11.8% | Inno Z: 0.72 | Parametric Alpha: 0.2711
#       COHR/LRCX | W_A: 15.0% | W_B: -13.1% | Inno Z: -0.58 | Parametric Alpha: 0.2329
#       CHRW/EXPD | W_A: 15.0% | W_B: -12.4% | Inno Z: -1.01 | Parametric Alpha: 0.4197
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-07-29 | Progress:  96.0% (480/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=91 | Promoted=15 | Live=14
#   --> SLSQP Metrics   : Eff Gross=1.00 | Port Vol=0.0601 | Turnover Drag=0.000804
#   --> Top Allocations :
#       AMT/REG | W_A: -15.0% | W_B: 10.9% | Inno Z: 0.87 | Parametric Alpha: 0.6262
#       BXP/SPG | W_A: -11.5% | W_B: 9.2% | Inno Z: 0.64 | Parametric Alpha: 0.1698
#       COHR/LRCX | W_A: 10.1% | W_B: -8.8% | Inno Z: -0.58 | Parametric Alpha: 0.2254
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-07-30 | Progress:  96.2% (481/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=104 | Promoted=20 | Live=9
#   --> SLSQP Metrics   : Eff Gross=1.00 | Port Vol=0.0961 | Turnover Drag=0.000734
#   --> Top Allocations :
#       CBRE/UDR | W_A: -15.0% | W_B: 12.7% | Inno Z: 0.77 | Parametric Alpha: 0.1309
#       CHRW/EXPD | W_A: 15.0% | W_B: -12.2% | Inno Z: -2.19 | Parametric Alpha: 3.9882
#       AMAT/MPWR | W_A: -15.0% | W_B: 10.8% | Inno Z: 1.08 | Parametric Alpha: 0.8997
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-07-31 | Progress:  96.4% (482/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=106 | Promoted=7 | Live=10
#   --> SLSQP Metrics   : Eff Gross=1.41 | Port Vol=0.1384 | Turnover Drag=0.000930
#   --> Top Allocations :
#       CPAY/BEN | W_A: 20.7% | W_B: -12.4% | Inno Z: -0.65 | Parametric Alpha: 0.1714
#       XYZ/TROW | W_A: -17.6% | W_B: 16.7% | Inno Z: 0.73 | Parametric Alpha: 0.4511
#       AJG/AFL | W_A: 17.5% | W_B: -12.3% | Inno Z: -0.52 | Parametric Alpha: 0.1452
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-03 | Progress:  96.6% (483/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=112 | Promoted=9 | Live=11
#   --> SLSQP Metrics   : Eff Gross=1.33 | Port Vol=0.1769 | Turnover Drag=0.000819
#   --> Top Allocations :
#       BAX/ZBH | W_A: -17.6% | W_B: 11.0% | Inno Z: 0.87 | Parametric Alpha: 0.8953
#       LII/PCAR | W_A: -16.9% | W_B: 11.8% | Inno Z: 0.68 | Parametric Alpha: 0.4450
#       AMZN/ABNB | W_A: -16.6% | W_B: 9.6% | Inno Z: 0.54 | Parametric Alpha: 0.3725
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-04 | Progress:  96.8% (484/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=104 | Promoted=4 | Live=7
#   --> SLSQP Metrics   : Eff Gross=1.21 | Port Vol=0.2373 | Turnover Drag=0.000723
#   --> Top Allocations :
#       DELL/HPE | W_A: -25.0% | W_B: 24.5% | Inno Z: 0.82 | Parametric Alpha: 0.5998
#       COHR/LRCX | W_A: -23.6% | W_B: 21.1% | Inno Z: -0.58 | Parametric Alpha: 1.2813
#       KLAC/WDC | W_A: -21.0% | W_B: 10.7% | Inno Z: 0.65 | Parametric Alpha: 0.4852
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-05 | Progress:  97.0% (485/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=110 | Promoted=10 | Live=11
#   --> SLSQP Metrics   : Eff Gross=1.00 | Port Vol=0.0813 | Turnover Drag=0.000782
#   --> Top Allocations :
#       CCI/VICI | W_A: 15.0% | W_B: -12.0% | Inno Z: -0.77 | Parametric Alpha: 0.6021
#       BAX/ZBH | W_A: 15.0% | W_B: -9.3% | Inno Z: -0.71 | Parametric Alpha: 0.4949
#       EOG/TRGP | W_A: 15.0% | W_B: -9.7% | Inno Z: -0.87 | Parametric Alpha: 0.7620
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-06 | Progress:  97.2% (486/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=107 | Promoted=12 | Live=12
#   --> SLSQP Metrics   : Eff Gross=1.25 | Port Vol=0.1309 | Turnover Drag=0.001003
#   --> Top Allocations :
#       FOX/WBD | W_A: -17.5% | W_B: 3.9% | Inno Z: 0.98 | Parametric Alpha: 1.0585
#       EMR/FAST | W_A: 16.2% | W_B: -10.4% | Inno Z: -0.67 | Parametric Alpha: 0.2937
#       DELL/HPE | W_A: 16.1% | W_B: -15.6% | Inno Z: -0.77 | Parametric Alpha: 0.5120
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-07 | Progress:  97.4% (487/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=99 | Promoted=5 | Live=7
#   --> SLSQP Metrics   : Eff Gross=1.38 | Port Vol=0.1754 | Turnover Drag=0.000867
#   --> Top Allocations :
#       OMC/NWS | W_A: -25.0% | W_B: 13.6% | Inno Z: 1.00 | Parametric Alpha: 1.1351
#       ABNB/NCLH | W_A: -25.0% | W_B: 10.4% | Inno Z: 3.30 | Parametric Alpha: 0.8643
#       FOX/WBD | W_A: -23.1% | W_B: 5.3% | Inno Z: 0.98 | Parametric Alpha: 0.7589
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-10 | Progress:  97.6% (488/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=101 | Promoted=2 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.91 | Port Vol=0.1812 | Turnover Drag=0.000317
#   --> Top Allocations :
#       ABNB/CCL | W_A: -25.0% | W_B: 10.8% | Inno Z: 2.06 | Parametric Alpha: 2.4169
#       APA/TRGP | W_A: -21.3% | W_B: 18.1% | Inno Z: 0.98 | Parametric Alpha: 0.6344
#       ABNB/NCLH | W_A: -20.2% | W_B: 8.6% | Inno Z: 3.30 | Parametric Alpha: 0.5129
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-11 | Progress:  97.8% (489/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=91 | Promoted=3 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.90 | Port Vol=0.1621 | Turnover Drag=0.000451
#   --> Top Allocations :
#       ABNB/CCL | W_A: -25.0% | W_B: 10.9% | Inno Z: 2.06 | Parametric Alpha: 0.4335
#       DELL/HPE | W_A: 24.8% | W_B: -23.9% | Inno Z: -0.64 | Parametric Alpha: 0.2579
#       ETN/FERG | W_A: -20.4% | W_B: 14.2% | Inno Z: 0.84 | Parametric Alpha: 0.6028
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-12 | Progress:  98.0% (490/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=87 | Promoted=3 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.52 | Port Vol=0.1436 | Turnover Drag=0.000415
#   --> Top Allocations :
#       LII/JBHT | W_A: 25.0% | W_B: -13.2% | Inno Z: -0.59 | Parametric Alpha: 0.1641
#       COHR/MPWR | W_A: -21.4% | W_B: 18.5% | Inno Z: 0.74 | Parametric Alpha: 0.3271
#       ALL/PFG | W_A: 5.6% | W_B: -3.5% | Inno Z: -0.54 | Parametric Alpha: 0.0366
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-13 | Progress:  98.2% (491/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=83 | Promoted=7 | Live=7
#   --> SLSQP Metrics   : Eff Gross=1.11 | Port Vol=0.1421 | Turnover Drag=0.000891
#   --> Top Allocations :
#       KDP/MDLZ | W_A: -25.0% | W_B: 14.3% | Inno Z: 0.69 | Parametric Alpha: 0.4217
#       FOX/WBD | W_A: -25.0% | W_B: 5.9% | Inno Z: 0.69 | Parametric Alpha: 0.4148
#       XYZ/TROW | W_A: -23.4% | W_B: 22.3% | Inno Z: 0.98 | Parametric Alpha: 0.6627
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-14 | Progress:  98.4% (492/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=71 | Promoted=2 | Live=4
#   --> SLSQP Metrics   : Eff Gross=0.76 | Port Vol=0.2059 | Turnover Drag=0.000251
#   --> Top Allocations :
#       FOX/WBD | W_A: -25.0% | W_B: 6.2% | Inno Z: 0.69 | Parametric Alpha: 1.6462
#       AMAT/WDC | W_A: 23.1% | W_B: -12.4% | Inno Z: -0.80 | Parametric Alpha: 1.7000
#       AMAT/MPWR | W_A: 14.5% | W_B: -10.3% | Inno Z: -0.84 | Parametric Alpha: 0.6717
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-17 | Progress:  98.6% (493/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=68 | Promoted=3 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.51 | Port Vol=0.1030 | Turnover Drag=0.000412
#   --> Top Allocations :
#       MSCI/STT | W_A: 25.0% | W_B: -12.8% | Inno Z: -0.56 | Parametric Alpha: 0.0266
#       COHR/MPWR | W_A: -21.5% | W_B: 18.6% | Inno Z: 0.73 | Parametric Alpha: 0.3237
#       MSCI/NTRS | W_A: 5.0% | W_B: -2.7% | Inno Z: -0.50 | Parametric Alpha: 0.0029
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-18 | Progress:  98.8% (494/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=60 | Promoted=2 | Live=3
#   --> SLSQP Metrics   : Eff Gross=0.52 | Port Vol=0.1400 | Turnover Drag=0.000245
#   --> Top Allocations :
#       ETN/FERG | W_A: 25.0% | W_B: -17.3% | Inno Z: -0.73 | Parametric Alpha: 0.4133
#       COHR/MPWR | W_A: 22.0% | W_B: -19.0% | Inno Z: 0.73 | Parametric Alpha: 0.4110
#       APA/TRGP | W_A: 5.0% | W_B: -4.2% | Inno Z: -0.51 | Parametric Alpha: 0.0117
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-19 | Progress:  99.0% (495/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=53 | Promoted=4 | Live=5
#   --> SLSQP Metrics   : Eff Gross=0.96 | Port Vol=0.1370 | Turnover Drag=0.000700
#   --> Top Allocations :
#       ABNB/CCL | W_A: -25.0% | W_B: 11.1% | Inno Z: 0.64 | Parametric Alpha: 0.2158
#       LII/JCI | W_A: -24.0% | W_B: 14.1% | Inno Z: 0.59 | Parametric Alpha: 0.1907
#       AJG/CINF | W_A: -23.5% | W_B: 14.0% | Inno Z: 0.68 | Parametric Alpha: 0.4616
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-20 | Progress:  99.2% (496/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=55 | Promoted=1 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.26 | Port Vol=0.0484 | Turnover Drag=0.000330
#   --> Top Allocations :
#       HON/NDSN | W_A: 21.3% | W_B: -12.6% | Inno Z: -0.97 | Parametric Alpha: 1.2497
#       ABNB/CCL | W_A: -5.0% | W_B: 2.2% | Inno Z: 0.64 | Parametric Alpha: 0.0109
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-21 | Progress:  99.4% (497/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=58 | Promoted=1 | Live=1
#   --> SLSQP Metrics   : Eff Gross=0.25 | Port Vol=0.0503 | Turnover Drag=0.000200
#   --> Top Allocations :
#       GS/KEY | W_A: -25.0% | W_B: 18.1% | Inno Z: 0.62 | Parametric Alpha: 0.2631
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-24 | Progress:  99.6% (498/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=61 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.40 | Port Vol=0.0677 | Turnover Drag=0.000320
#   --> Top Allocations :
#       MA/USB | W_A: -23.8% | W_B: 10.2% | Inno Z: 0.57 | Parametric Alpha: 0.1072
#       MA/IVZ | W_A: -16.2% | W_B: 4.7% | Inno Z: 0.59 | Parametric Alpha: 0.0513
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-25 | Progress:  99.8% (499/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=67 | Promoted=2 | Live=2
#   --> SLSQP Metrics   : Eff Gross=0.38 | Port Vol=0.0771 | Turnover Drag=0.000306
#   --> Top Allocations :
#       AMD/INTC | W_A: -24.7% | W_B: 14.4% | Inno Z: 0.70 | Parametric Alpha: 0.1908
#       BXP/REG | W_A: -13.6% | W_B: 13.3% | Inno Z: 0.61 | Parametric Alpha: 0.0713
# ------------------------------------------------------------
#
# [Dynamic Rebalance @ 2026-08-26 | Progress: 100.0% (500/500)] Cause: SIGNAL_EXIT
#   --> Pipeline Funnel : Ghost=70 | Promoted=0 | Live=0
# ------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 932
#     928 # ==============================================================================
#     929 # MAIN EXECUTION ENTRY POINT
#     930 # ==============================================================================
#     931 if __name__ == "__main__":
# --> 932     committee_report, net_portfolio, metrics, moo_blotter, summary_data = run_unified_pipeline(params=run_params)
#     934     if metrics is not None and not metrics.empty:
#     935         print_execution_summary(
#     936             metrics_df=metrics,
#     937             committee_report=committee_report,
#     938             moo_blotter=moo_blotter,
#     939             **summary_data
#     940         )
#
# Cell In[2], line 739, in run_unified_pipeline(params)
#     736 ann_ret_promoted = (((1.0 + tot_ret_promoted) ** ann_factor) - 1.0) * 100.0
#     737 ann_ret_live = (((1.0 + tot_ret_live) ** ann_factor) - 1.0) * 100.0
# --> 739 sortino_ghost = compute_sortino_ratio(ret_ghost)
#     740 sortino_promoted = compute_sortino_ratio(ret_promoted)
#     741 sortino_live = compute_sortino_ratio(ret_live)
#
# NameError: name 'compute_sortino_ratio' is not defined
